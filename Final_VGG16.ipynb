# %% [markdown]
# # **Preprocessing**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/lab5/.local/lib/python3.10/site-packages (from opencv-python) (1.26.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# pip install tensorflow

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Define constants
data_path = r"/home/lab5/Desktop/tongue_diabetes_new"
target_size = (224, 224)  # Define the target size for resizing

# Load and preprocess data
images = []
labels = []

# Loop through each class (Normal and Tuberculosis)
for class_name in ['diabetes', 'non_diabetes']:
    class_path = os.path.join(data_path, class_name)
    # Iterate through each image in the class
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        # Read the image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        # Resize the image to the target size
        img = cv2.resize(img, target_size)
        # Normalize the pixel values to the range [0, 1]
        img = img.astype(np.float32) / 255.0
        # Append the preprocessed image to the images list
        images.append(img)
        # Append the label (0 for Normal, 1 for Tuberculosis) to the labels list
        labels.append(0 if class_name == 'diabetes' else 1)

# Convert images and labels to NumPy arrays
images = np.array(images)
labels = np.array(labels)

# Print class proportions
print("Class Proportions:")
print("diabetes:", np.sum(labels == 0), "non_diabetes:", np.sum(labels == 1))

# Plot histogram for class distribution
plt.figure(figsize=(8, 6))
plt.hist(labels, bins=2, color='skyblue', edgecolor='black', alpha=0.7)
plt.xticks([0.25, 0.75], ['diabetes', 'non_diabetes'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Data Distribution')
plt.show()
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Class Proportions:
# diabetes: 513 non_diabetes: 502

# %% [markdown]
# # Equal amount of data is taken

# %%
# Separate data for Normal and Tuberculosis classes
diabetes_images = images[labels == 0][:500]
non_diabetes_images = images[labels == 1][:500]
diabetes_labels = labels[labels == 0][:500]
non_diabetes_labels = labels[labels == 1][:500]

# Concatenate the data back together
balanced_images = np.concatenate([diabetes_images, non_diabetes_images])
balanced_labels = np.concatenate([diabetes_labels, non_diabetes_labels])

# Split the balanced dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(balanced_images, balanced_labels, test_size=0.2, random_state=42)

#print the balanced data
print("Balanced Images:",balanced_images.shape)
print("Balanced labels:",balanced_labels.shape)

#print the data seperately of each class
print("diabetes_images:",diabetes_images.shape)
print("non_diabetes_images:",non_diabetes_images.shape)


# Print the shapes of the training and testing sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# Balanced Images: (1000, 224, 224)
# Balanced labels: (1000,)
# diabetes_images: (500, 224, 224)
# non_diabetes_images: (500, 224, 224)
# X_train shape: (800, 224, 224)
# X_test shape: (200, 224, 224)
# y_train shape: (800,)
# y_test shape: (200,)

# %%
# Plot histogram for class distribution before splitting
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(labels, bins=2, color='skyblue', edgecolor='black', alpha=0.7)
plt.xticks([0.25, 0.75], ['diabetes', 'non_diabetes'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Data Distribution Before Splitting')

# Plot histogram for class distribution after splitting
plt.subplot(1, 2, 2)
plt.hist(y_train, bins=2, color='lightcoral', edgecolor='black', alpha=0.7, label='Train')
plt.hist(y_test, bins=2, color='mediumseagreen', edgecolor='black', alpha=0.7, label='Test')
plt.xticks([0.25, 0.75], ['diabetes', 'non_diabetes'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Data Distribution After Splitting')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Define the number of images to display
num_images_to_display = 10

# Select random indices for the images
indices = random.sample(range(len(balanced_images)), num_images_to_display)

# Create a figure to display the images
plt.figure(figsize=(15, 5))

# Loop over the selected indices and display the images
for i, idx in enumerate(indices):
    # Get the image and its corresponding label
    image = balanced_images[idx]
    label = balanced_labels[idx]

    # Add a subplot for the current image
    plt.subplot(2, 5, i % 5 + 1 + (i // 5) * 5)
    plt.imshow(image, cmap='gray')
    plt.title(f'Label: {label}')
    plt.axis('off')

# Adjust the layout of the subplots
plt.tight_layout()
plt.show()

# %%
images[0]
# Out:
# array([[0.6745098 , 0.68235296, 0.64705884, ..., 0.6666667 , 0.6627451 ,
#         0.65882355],
#        [0.67058825, 0.65882355, 0.64705884, ..., 0.67058825, 0.6627451 ,
#         0.654902  ],
#        [0.6666667 , 0.64705884, 0.6509804 , ..., 0.65882355, 0.64705884,
#         0.6313726 ],
#        ...,
#        [0.49411765, 0.49411765, 0.49411765, ..., 0.7254902 , 0.7254902 ,
#         0.72156864],
#        [0.5921569 , 0.5921569 , 0.5921569 , ..., 0.69803923, 0.7137255 ,
#         0.7254902 ],
#        [0.7019608 , 0.7019608 , 0.7019608 , ..., 0.6784314 , 0.6901961 ,
#         0.69803923]], dtype=float32)

# %% [markdown]
# Yes, you can add other layers or modify the architecture of the custom classification head in various ways, depending on the specific requirements of your task. Here are some common modifications:
#
# 1. **Dropout Layers**: Adding dropout layers can help prevent overfitting. Dropout layers randomly set a fraction of input units to 0 at each update during training, which helps prevent overfitting.
#
#    Example:
#    ```python
#    x = Dropout(0.5)(x)  # Add dropout with a dropout rate of 0.5
#    ```
#
# 2. **Batch Normalization**: Batch normalization normalizes the input layer by adjusting and scaling the activations. It can help with faster convergence and better generalization.
#
#    Example:
#    ```python
#    x = BatchNormalization()(x)
#    ```
#
# 3. **Additional Dense Layers**: Adding more dense layers can increase the model's capacity to learn complex patterns in the data. However, adding too many layers can lead to overfitting.
#
#    Example:
#    ```python
#    x = Dense(256, activation='relu')(x)
#    ```
#
# 4. **Different Activation Functions**: You can experiment with different activation functions in the dense layers. Common choices include `sigmoid`, `tanh`, and `relu`.
#
#    Example:
#    ```python
#    x = Dense(512, activation='tanh')(x)
#    ```
#
# 5. **Regularization**: You can add regularization to the dense layers to prevent overfitting. Common regularization techniques include L1 regularization, L2 regularization, and dropout.
#
#    Example:
#    ```python
#    from tensorflow.keras import regularizers
#    x = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
#    ```
#
# These modifications can be added to the custom classification head after the `GlobalAveragePooling2D` layer to customize the model according to your needs. The choice of layers and their configurations should be based on the specific requirements of your task and the characteristics of your dataset.

# %% [markdown]
# # OverFitting  and UnderFitting Identification
#
#
# Overfitting occurs when a machine learning model learns the training data too well, to the point that it negatively impacts its performance on unseen data. To identify overfitting, you can use several techniques:
#
# 1. **Validation Curve**: Plot the training and validation accuracies or losses against the number of epochs. If the training accuracy keeps increasing while the validation accuracy stagnates or starts decreasing, it indicates overfitting.
#
# 2. **Learning Curve**: Plot the training and validation accuracies or losses against the size of the training dataset. If the training and validation curves converge at a low error, the model is underfitting. If they diverge, the model may be overfitting.
#
# 3. **Validation Set Performance**: Evaluate the model on a separate validation set during training. If the validation accuracy starts to decrease while the training accuracy keeps increasing, the model is likely overfitting.
#
# 4. **Regularization Techniques**: Regularization techniques like L1 and L2 regularization, dropout, and early stopping can help prevent overfitting. If you observe a significant improvement in performance with these techniques, it indicates that overfitting was present.
#
# 5. **Cross-Validation**: Use k-fold cross-validation to assess the model's performance on different subsets of the data. If the model performs significantly better on the training data compared to the validation data, it suggests overfitting.
#
# 6. **Model Complexity**: If you have control over the model architecture, reducing the complexity (e.g., number of layers, number of units per layer) can help prevent overfitting.
#
# 7. **Data Augmentation**: If applicable, augmenting the training data can help improve the model's generalization performance by exposing it to more variations in the data.
#
# By monitoring these indicators, you can identify and mitigate overfitting in your machine learning models.

# %% [raw]
# pip install tensorflow

# %% [markdown]
# # VGG16(A) + Dense Layers (B):
#
# Base Model (A):VGG16 pre-trained on ImageNet.
#
# Main Model (B): Additional dense layers for classification.
#
# Explanation: Use VGG16 as the feature extractor and add dense layers on top to classify images based on the features extracted by VGG16.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create new model with VGG16 base and additional layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=20, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DENSE20',
    'Epochs': 20,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DENSE20_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model1_20_Epochs Training History")
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 37s 1s/step - loss: 1.4173 - accuracy: 0.6525 - precision_1: 0.6398 - recall_1: 0.6818 - auc_2: 0.6857 - auc_3: 0.6327 - true_negatives_1: 252.0000 - false_positives_1: 152.0000 - false_negatives_1: 126.0000 - true_positives_1: 270.0000 - val_loss: 0.8516 - val_accuracy: 0.6800 - val_precision_1: 0.9545 - val_recall_1: 0.4038 - val_auc_2: 0.8953 - val_auc_3: 0.8979 - val_true_negatives_1: 94.0000 - val_false_positives_1: 2.0000 - val_false_negatives_1: 62.0000 - val_true_positives_1: 42.0000
# Epoch 2/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.2903 - accuracy: 0.8775 - precision_1: 0.8652 - recall_1: 0.8914 - auc_2: 0.9486 - auc_3: 0.9472 - true_negatives_1: 349.0000 - false_positives_1: 55.0000 - false_negatives_1: 43.0000 - true_positives_1: 353.0000 - val_loss: 0.4401 - val_accuracy: 0.8400 - val_precision_1: 0.9286 - val_recall_1: 0.7500 - val_auc_2: 0.9195 - val_auc_3: 0.9349 - val_true_negatives_1: 90.0000 - val_false_positives_1: 6.0000 - val_false_negatives_1: 26.0000 - val_true_positives_1: 78.0000
# Epoch 3/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.2085 - accuracy: 0.9162 - precision_1: 0.9102 - recall_1: 0.9217 - auc_2: 0.9739 - auc_3: 0.9733 - true_negatives_1: 368.0000 - false_positives_1: 36.0000 - false_negatives_1: 31.0000 - true_positives_1: 365.0000 - val_loss: 0.4144 - val_accuracy: 0.8550 - val_precision_1: 0.8866 - val_recall_1: 0.8269 - val_auc_2: 0.9230 - val_auc_3: 0.9390 - val_true_negatives_1: 85.0000 - val_false_positives_1: 11.0000 - val_false_negatives_1: 18.0000 - val_true_positives_1: 86.0000
# Epoch 4/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.1724 - accuracy: 0.9262 - precision_1: 0.9309 - recall_1: 0.9192 - auc_2: 0.9824 - auc_3: 0.9819 - true_negatives_1: 377.0000 - false_positives_1: 27.0000 - false_negatives_1: 32.0000 - true_positives_1: 364.0000 - val_loss: 0.4399 - val_accuracy: 0.8500 - val_precision_1: 0.8304 - val_recall_1: 0.8942 - val_auc_2: 0.9235 - val_auc_3: 0.9313 - val_true_negatives_1: 77.0000 - val_false_positives_1: 19.0000 - val_false_negatives_1: 11.0000 - val_true_positives_1: 93.0000
# Epoch 5/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.2416 - accuracy: 0.8900 - precision_1: 0.8949 - recall_1: 0.8813 - auc_2: 0.9671 - auc_3: 0.9651 - true_negatives_1: 363.0000 - false_positives_1: 41.0000 - false_negatives_1: 47.0000 - true_positives_1: 349.0000 - val_loss: 0.4644 - val_accuracy: 0.8700 - val_precision_1: 0.8900 - val_recall_1: 0.8558 - val_auc_2: 0.9295 - val_auc_3: 0.9411 - val_true_negatives_1: 85.0000 - val_false_positives_1: 11.0000 - val_false_negatives_1: 15.0000 - val_true_positives_1: 89.0000
# Epoch 6/20
# 25/25 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9538 - precision_1: 0.9432 - recall_1: 0.9646 - auc_2: 0.9908 - auc_3: 0.9898 - true_negatives_1: 381.0000 - false_positives_1: 23.0000 - false_negatives_1: 14.0000 - true_positives_1: 382.0000Restoring model weights from the end of the best epoch: 3.
# 25/25 [==============================] - 39s 2s/step - loss: 0.1216 - accuracy: 0.9538 - precision_1: 0.9432 - recall_1: 0.9646 - auc_2: 0.9908 - auc_3: 0.9898 - true_negatives_1: 381.0000 - false_positives_1: 23.0000 - false_negatives_1: 14.0000 - true_positives_1: 382.0000 - val_loss: 1.0161 - val_accuracy: 0.7600 - val_precision_1: 0.9828 - val_recall_1: 0.5481 - val_auc_2: 0.9101 - val_auc_3: 0.9313 - val_true_negatives_1: 95.0000 - val_false_positives_1: 1.0000 - val_false_negatives_1: 47.0000 - val_true_positives_1: 57.0000
# Epoch 6: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4144 - accuracy: 0.8550 - precision_1: 0.8866 - recall_1: 0.8269 - auc_2: 0.9230 - auc_3: 0.9390 - true_negatives_1: 85.0000 - false_positives_1: 11.0000 - false_negatives_1: 18.0000 - true_positives_1: 86.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DENSE20
# Epochs: 20
# Test Accuracy: 0.8550000190734863
# Test Loss: 0.414373517036438
# Validation Accuracy: 0.7599999904632568
# Validation Loss: 1.0160778760910034
# Precision: 0.8865979381443299
# Recall: 0.8269230769230769
# AUC-ROC: 0.8561698717948718
# AUC-PR: 0.9017605075337033
# True Negatives: 85.0
# False Positives: 11.0
# False Negatives: 18.0
# True Positives: 86.0
# Error Rate: 0.5006
# F1 Score: 0.8557213930348259
# Cohen's Kappa: 0.7103475829005195
# Matthews Correlation Coefficient: 0.712090156365568
# Balanced Accuracy: 0.8561698717948718
# Time Taken (seconds): 248.98175954818726

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create new model with VGG16 base and additional layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=40, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DENSE40',
    'Epochs': 40,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DENSE40_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model1_40_Epochs Training History")
plt.show()
# Out:
# Epoch 1/40
# 25/25 [==============================] - 40s 2s/step - loss: 1.0815 - accuracy: 0.6500 - precision_2: 0.6465 - recall_2: 0.6465 - auc_4: 0.7080 - auc_5: 0.6405 - true_negatives_2: 264.0000 - false_positives_2: 140.0000 - false_negatives_2: 140.0000 - true_positives_2: 256.0000 - val_loss: 0.6281 - val_accuracy: 0.7450 - val_precision_2: 0.9344 - val_recall_2: 0.5481 - val_auc_4: 0.9031 - val_auc_5: 0.9128 - val_true_negatives_2: 92.0000 - val_false_positives_2: 4.0000 - val_false_negatives_2: 47.0000 - val_true_positives_2: 57.0000
# Epoch 2/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.2658 - accuracy: 0.8950 - precision_2: 0.8842 - recall_2: 0.9066 - auc_4: 0.9565 - auc_5: 0.9520 - true_negatives_2: 357.0000 - false_positives_2: 47.0000 - false_negatives_2: 37.0000 - true_positives_2: 359.0000 - val_loss: 0.4185 - val_accuracy: 0.8550 - val_precision_2: 0.9121 - val_recall_2: 0.7981 - val_auc_4: 0.9215 - val_auc_5: 0.9373 - val_true_negatives_2: 88.0000 - val_false_positives_2: 8.0000 - val_false_negatives_2: 21.0000 - val_true_positives_2: 83.0000
# Epoch 3/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.1640 - accuracy: 0.9463 - precision_2: 0.9380 - recall_2: 0.9545 - auc_4: 0.9845 - auc_5: 0.9854 - true_negatives_2: 379.0000 - false_positives_2: 25.0000 - false_negatives_2: 18.0000 - true_positives_2: 378.0000 - val_loss: 0.4800 - val_accuracy: 0.8400 - val_precision_2: 0.9500 - val_recall_2: 0.7308 - val_auc_4: 0.9289 - val_auc_5: 0.9416 - val_true_negatives_2: 92.0000 - val_false_positives_2: 4.0000 - val_false_negatives_2: 28.0000 - val_true_positives_2: 76.0000
# Epoch 4/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.0909 - accuracy: 0.9762 - precision_2: 0.9701 - recall_2: 0.9823 - auc_4: 0.9965 - auc_5: 0.9966 - true_negatives_2: 392.0000 - false_positives_2: 12.0000 - false_negatives_2: 7.0000 - true_positives_2: 389.0000 - val_loss: 0.4442 - val_accuracy: 0.8550 - val_precision_2: 0.9121 - val_recall_2: 0.7981 - val_auc_4: 0.9301 - val_auc_5: 0.9408 - val_true_negatives_2: 88.0000 - val_false_positives_2: 8.0000 - val_false_negatives_2: 21.0000 - val_true_positives_2: 83.0000
# Epoch 5/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9850 - precision_2: 0.9824 - recall_2: 0.9874 - auc_4: 0.9992 - auc_5: 0.9992 - true_negatives_2: 397.0000 - false_positives_2: 7.0000 - false_negatives_2: 5.0000 - true_positives_2: 391.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.0584 - accuracy: 0.9850 - precision_2: 0.9824 - recall_2: 0.9874 - auc_4: 0.9992 - auc_5: 0.9992 - true_negatives_2: 397.0000 - false_positives_2: 7.0000 - false_negatives_2: 5.0000 - true_positives_2: 391.0000 - val_loss: 0.5032 - val_accuracy: 0.8650 - val_precision_2: 0.8812 - val_recall_2: 0.8558 - val_auc_4: 0.9266 - val_auc_5: 0.9332 - val_true_negatives_2: 84.0000 - val_false_positives_2: 12.0000 - val_false_negatives_2: 15.0000 - val_true_positives_2: 89.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4185 - accuracy: 0.8550 - precision_2: 0.9121 - recall_2: 0.7981 - auc_4: 0.9215 - auc_5: 0.9373 - true_negatives_2: 88.0000 - false_positives_2: 8.0000 - false_negatives_2: 21.0000 - true_positives_2: 83.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DENSE40
# Epochs: 40
# Test Accuracy: 0.8550000190734863
# Test Loss: 0.41852089762687683
# Validation Accuracy: 0.8650000095367432
# Validation Loss: 0.5031548142433167
# Precision: 0.9120879120879121
# Recall: 0.7980769230769231
# AUC-ROC: 0.8573717948717949
# AUC-PR: 0.9075824175824175
# True Negatives: 88.0
# False Positives: 8.0
# False Negatives: 21.0
# True Positives: 83.0
# Error Rate: 0.5018
# F1 Score: 0.8512820512820513
# Cohen's Kappa: 0.7110402550817059
# Matthews Correlation Coefficient: 0.7170816515645981
# Balanced Accuracy: 0.8573717948717949
# Time Taken (seconds): 212.51876997947693

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create new model with VGG16 base and additional layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=60, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DENSE60',
    'Epochs': 60,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DENSE60_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model1_60_Epochs Training History")
plt.show()
# Out:
# Epoch 1/60
# 25/25 [==============================] - 40s 2s/step - loss: 1.0459 - accuracy: 0.6875 - precision_3: 0.6891 - recall_3: 0.6717 - auc_6: 0.7560 - auc_7: 0.6806 - true_negatives_3: 284.0000 - false_positives_3: 120.0000 - false_negatives_3: 130.0000 - true_positives_3: 266.0000 - val_loss: 0.4389 - val_accuracy: 0.8200 - val_precision_3: 0.8864 - val_recall_3: 0.7500 - val_auc_6: 0.9037 - val_auc_7: 0.9145 - val_true_negatives_3: 86.0000 - val_false_positives_3: 10.0000 - val_false_negatives_3: 26.0000 - val_true_positives_3: 78.0000
# Epoch 2/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2567 - accuracy: 0.8975 - precision_3: 0.8867 - recall_3: 0.9091 - auc_6: 0.9593 - auc_7: 0.9569 - true_negatives_3: 358.0000 - false_positives_3: 46.0000 - false_negatives_3: 36.0000 - true_positives_3: 360.0000 - val_loss: 0.3986 - val_accuracy: 0.8500 - val_precision_3: 0.8700 - val_recall_3: 0.8365 - val_auc_6: 0.9182 - val_auc_7: 0.9344 - val_true_negatives_3: 83.0000 - val_false_positives_3: 13.0000 - val_false_negatives_3: 17.0000 - val_true_positives_3: 87.0000
# Epoch 3/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.1594 - accuracy: 0.9450 - precision_3: 0.9422 - recall_3: 0.9470 - auc_6: 0.9850 - auc_7: 0.9854 - true_negatives_3: 381.0000 - false_positives_3: 23.0000 - false_negatives_3: 21.0000 - true_positives_3: 375.0000 - val_loss: 0.4035 - val_accuracy: 0.8600 - val_precision_3: 0.8585 - val_recall_3: 0.8750 - val_auc_6: 0.9241 - val_auc_7: 0.9378 - val_true_negatives_3: 81.0000 - val_false_positives_3: 15.0000 - val_false_negatives_3: 13.0000 - val_true_positives_3: 91.0000
# Epoch 4/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.1030 - accuracy: 0.9625 - precision_3: 0.9575 - recall_3: 0.9672 - auc_6: 0.9949 - auc_7: 0.9949 - true_negatives_3: 387.0000 - false_positives_3: 17.0000 - false_negatives_3: 13.0000 - true_positives_3: 383.0000 - val_loss: 0.4575 - val_accuracy: 0.8450 - val_precision_3: 0.8230 - val_recall_3: 0.8942 - val_auc_6: 0.9286 - val_auc_7: 0.9371 - val_true_negatives_3: 76.0000 - val_false_positives_3: 20.0000 - val_false_negatives_3: 11.0000 - val_true_positives_3: 93.0000
# Epoch 5/60
# 25/25 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9588 - precision_3: 0.9504 - recall_3: 0.9672 - auc_6: 0.9939 - auc_7: 0.9939 - true_negatives_3: 384.0000 - false_positives_3: 20.0000 - false_negatives_3: 13.0000 - true_positives_3: 383.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.1033 - accuracy: 0.9588 - precision_3: 0.9504 - recall_3: 0.9672 - auc_6: 0.9939 - auc_7: 0.9939 - true_negatives_3: 384.0000 - false_positives_3: 20.0000 - false_negatives_3: 13.0000 - true_positives_3: 383.0000 - val_loss: 0.5964 - val_accuracy: 0.8450 - val_precision_3: 0.8067 - val_recall_3: 0.9231 - val_auc_6: 0.9140 - val_auc_7: 0.9010 - val_true_negatives_3: 73.0000 - val_false_positives_3: 23.0000 - val_false_negatives_3: 8.0000 - val_true_positives_3: 96.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3986 - accuracy: 0.8500 - precision_3: 0.8700 - recall_3: 0.8365 - auc_6: 0.9182 - auc_7: 0.9344 - true_negatives_3: 83.0000 - false_positives_3: 13.0000 - false_negatives_3: 17.0000 - true_positives_3: 87.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DENSE60
# Epochs: 60
# Test Accuracy: 0.8500000238418579
# Test Loss: 0.39857059717178345
# Validation Accuracy: 0.8450000286102295
# Validation Loss: 0.596419095993042
# Precision: 0.87
# Recall: 0.8365384615384616
# AUC-ROC: 0.8505608974358976
# AUC-PR: 0.8957692307692309
# True Negatives: 83.0
# False Positives: 13.0
# False Negatives: 17.0
# True Positives: 87.0
# Error Rate: 0.5
# F1 Score: 0.8529411764705882
# Cohen's Kappa: 0.7
# Matthews Correlation Coefficient: 0.7005606728972562
# Balanced Accuracy: 0.8505608974358975
# Time Taken (seconds): 213.67218613624573

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create new model with VGG16 base and additional layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=80, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DENSE80',
    'Epochs': 80,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DENSE80_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model1_80_Epochs Training History")
plt.show()
# Out:
# Epoch 1/80
# 25/25 [==============================] - 40s 2s/step - loss: 1.5033 - accuracy: 0.6475 - precision_4: 0.6390 - recall_4: 0.6616 - auc_8: 0.6664 - auc_9: 0.6355 - true_negatives_4: 256.0000 - false_positives_4: 148.0000 - false_negatives_4: 134.0000 - true_positives_4: 262.0000 - val_loss: 0.8092 - val_accuracy: 0.6450 - val_precision_4: 0.9459 - val_recall_4: 0.3365 - val_auc_8: 0.8919 - val_auc_9: 0.8913 - val_true_negatives_4: 94.0000 - val_false_positives_4: 2.0000 - val_false_negatives_4: 69.0000 - val_true_positives_4: 35.0000
# Epoch 2/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2962 - accuracy: 0.8700 - precision_4: 0.8632 - recall_4: 0.8763 - auc_8: 0.9465 - auc_9: 0.9455 - true_negatives_4: 349.0000 - false_positives_4: 55.0000 - false_negatives_4: 49.0000 - true_positives_4: 347.0000 - val_loss: 0.3934 - val_accuracy: 0.8350 - val_precision_4: 0.8586 - val_recall_4: 0.8173 - val_auc_8: 0.9199 - val_auc_9: 0.9348 - val_true_negatives_4: 82.0000 - val_false_positives_4: 14.0000 - val_false_negatives_4: 19.0000 - val_true_positives_4: 85.0000
# Epoch 3/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2232 - accuracy: 0.9087 - precision_4: 0.9048 - recall_4: 0.9116 - auc_8: 0.9697 - auc_9: 0.9690 - true_negatives_4: 366.0000 - false_positives_4: 38.0000 - false_negatives_4: 35.0000 - true_positives_4: 361.0000 - val_loss: 0.4158 - val_accuracy: 0.8500 - val_precision_4: 0.8364 - val_recall_4: 0.8846 - val_auc_8: 0.9216 - val_auc_9: 0.9359 - val_true_negatives_4: 78.0000 - val_false_positives_4: 18.0000 - val_false_negatives_4: 12.0000 - val_true_positives_4: 92.0000
# Epoch 4/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.1890 - accuracy: 0.9112 - precision_4: 0.9135 - recall_4: 0.9066 - auc_8: 0.9782 - auc_9: 0.9775 - true_negatives_4: 370.0000 - false_positives_4: 34.0000 - false_negatives_4: 37.0000 - true_positives_4: 359.0000 - val_loss: 0.5220 - val_accuracy: 0.8400 - val_precision_4: 0.7903 - val_recall_4: 0.9423 - val_auc_8: 0.9230 - val_auc_9: 0.9329 - val_true_negatives_4: 70.0000 - val_false_positives_4: 26.0000 - val_false_negatives_4: 6.0000 - val_true_positives_4: 98.0000
# Epoch 5/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8700 - precision_4: 0.8632 - recall_4: 0.8763 - auc_8: 0.9425 - auc_9: 0.9314 - true_negatives_4: 349.0000 - false_positives_4: 55.0000 - false_negatives_4: 49.0000 - true_positives_4: 347.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.3547 - accuracy: 0.8700 - precision_4: 0.8632 - recall_4: 0.8763 - auc_8: 0.9425 - auc_9: 0.9314 - true_negatives_4: 349.0000 - false_positives_4: 55.0000 - false_negatives_4: 49.0000 - true_positives_4: 347.0000 - val_loss: 1.1699 - val_accuracy: 0.6450 - val_precision_4: 0.9714 - val_recall_4: 0.3269 - val_auc_8: 0.9114 - val_auc_9: 0.9296 - val_true_negatives_4: 95.0000 - val_false_positives_4: 1.0000 - val_false_negatives_4: 70.0000 - val_true_positives_4: 34.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3934 - accuracy: 0.8350 - precision_4: 0.8586 - recall_4: 0.8173 - auc_8: 0.9199 - auc_9: 0.9348 - true_negatives_4: 82.0000 - false_positives_4: 14.0000 - false_negatives_4: 19.0000 - true_positives_4: 85.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DENSE80
# Epochs: 80
# Test Accuracy: 0.8349999785423279
# Test Loss: 0.3934203088283539
# Validation Accuracy: 0.6449999809265137
# Validation Loss: 1.1699272394180298
# Precision: 0.8585858585858586
# Recall: 0.8173076923076923
# AUC-ROC: 0.8357371794871794
# AUC-PR: 0.8854467754467754
# True Negatives: 82.0
# False Positives: 14.0
# False Negatives: 19.0
# True Positives: 85.0
# Error Rate: 0.5002
# F1 Score: 0.8374384236453202
# Cohen's Kappa: 0.6701319472211116
# Matthews Correlation Coefficient: 0.6709705138077606
# Balanced Accuracy: 0.8357371794871795
# Time Taken (seconds): 213.51306533813477

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Create new model with VGG16 base and additional layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=100, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DENSE100',
    'Epochs': 100,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DENSE100_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model1_100_Epochs Training History")
plt.show()
# Out:
# Epoch 1/100
# 25/25 [==============================] - 40s 2s/step - loss: 1.0068 - accuracy: 0.6900 - precision_5: 0.6897 - recall_5: 0.6793 - auc_10: 0.7545 - auc_11: 0.6855 - true_negatives_5: 283.0000 - false_positives_5: 121.0000 - false_negatives_5: 127.0000 - true_positives_5: 269.0000 - val_loss: 0.4391 - val_accuracy: 0.8450 - val_precision_5: 0.8120 - val_recall_5: 0.9135 - val_auc_10: 0.9038 - val_auc_11: 0.9132 - val_true_negatives_5: 74.0000 - val_false_positives_5: 22.0000 - val_false_negatives_5: 9.0000 - val_true_positives_5: 95.0000
# Epoch 2/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.3301 - accuracy: 0.8625 - precision_5: 0.8540 - recall_5: 0.8712 - auc_10: 0.9388 - auc_11: 0.9323 - true_negatives_5: 345.0000 - false_positives_5: 59.0000 - false_negatives_5: 51.0000 - true_positives_5: 345.0000 - val_loss: 0.4071 - val_accuracy: 0.8650 - val_precision_5: 0.9053 - val_recall_5: 0.8269 - val_auc_10: 0.9210 - val_auc_11: 0.9386 - val_true_negatives_5: 87.0000 - val_false_positives_5: 9.0000 - val_false_negatives_5: 18.0000 - val_true_positives_5: 86.0000
# Epoch 3/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.1577 - accuracy: 0.9400 - precision_5: 0.9307 - recall_5: 0.9495 - auc_10: 0.9851 - auc_11: 0.9854 - true_negatives_5: 376.0000 - false_positives_5: 28.0000 - false_negatives_5: 20.0000 - true_positives_5: 376.0000 - val_loss: 0.4109 - val_accuracy: 0.8650 - val_precision_5: 0.8667 - val_recall_5: 0.8750 - val_auc_10: 0.9246 - val_auc_11: 0.9297 - val_true_negatives_5: 82.0000 - val_false_positives_5: 14.0000 - val_false_negatives_5: 13.0000 - val_true_positives_5: 91.0000
# Epoch 4/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.1181 - accuracy: 0.9525 - precision_5: 0.9453 - recall_5: 0.9596 - auc_10: 0.9922 - auc_11: 0.9920 - true_negatives_5: 382.0000 - false_positives_5: 22.0000 - false_negatives_5: 16.0000 - true_positives_5: 380.0000 - val_loss: 0.4585 - val_accuracy: 0.8550 - val_precision_5: 0.8440 - val_recall_5: 0.8846 - val_auc_10: 0.9247 - val_auc_11: 0.9322 - val_true_negatives_5: 79.0000 - val_false_positives_5: 17.0000 - val_false_negatives_5: 12.0000 - val_true_positives_5: 92.0000
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9337 - precision_5: 0.9386 - recall_5: 0.9268 - auc_10: 0.9877 - auc_11: 0.9874 - true_negatives_5: 380.0000 - false_positives_5: 24.0000 - false_negatives_5: 29.0000 - true_positives_5: 367.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.1396 - accuracy: 0.9337 - precision_5: 0.9386 - recall_5: 0.9268 - auc_10: 0.9877 - auc_11: 0.9874 - true_negatives_5: 380.0000 - false_positives_5: 24.0000 - false_negatives_5: 29.0000 - true_positives_5: 367.0000 - val_loss: 0.5061 - val_accuracy: 0.8600 - val_precision_5: 0.8519 - val_recall_5: 0.8846 - val_auc_10: 0.9237 - val_auc_11: 0.9243 - val_true_negatives_5: 80.0000 - val_false_positives_5: 16.0000 - val_false_negatives_5: 12.0000 - val_true_positives_5: 92.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4071 - accuracy: 0.8650 - precision_5: 0.9053 - recall_5: 0.8269 - auc_10: 0.9210 - auc_11: 0.9386 - true_negatives_5: 87.0000 - false_positives_5: 9.0000 - false_negatives_5: 18.0000 - true_positives_5: 86.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DENSE100
# Epochs: 100
# Test Accuracy: 0.8650000095367432
# Test Loss: 0.40708717703819275
# Validation Accuracy: 0.8600000143051147
# Validation Loss: 0.5061391592025757
# Precision: 0.9052631578947369
# Recall: 0.8269230769230769
# AUC-ROC: 0.8665865384615384
# AUC-PR: 0.9110931174089069
# True Negatives: 87.0
# False Positives: 9.0
# False Negatives: 18.0
# True Positives: 86.0
# Error Rate: 0.501
# F1 Score: 0.864321608040201
# Cohen's Kappa: 0.7305389221556886
# Matthews Correlation Coefficient: 0.7335037571219197
# Balanced Accuracy: 0.8665865384615384
# Time Taken (seconds): 212.48537516593933

# %%
num_training_records = X_train_resized.shape[0]
print("Number of training records:", num_training_records)
# Out:
# Number of training records: 800

# %% [markdown]
# # VGG16 (A) + Dropout + Dense Layers (B):
#
# Base Model (A): VGG16  pre-trained on ImageNet.
# Main Model (B): Dropout layer followed by dense layers for classification.
# Explanation: VGG16  extracts features from images, dropout helps prevent overfitting, and dense layers classify images based on the extracted features.

# %% [markdown]
# # Dropout
#
# Dropout is a regularization technique used to prevent overfitting in neural networks. It works by randomly setting a fraction of input units to zero during each training iteration, which helps to reduce the network's reliance on specific units and encourages the network to learn more robust features.
#
# The main purpose of dropout is to improve the generalization of the model by preventing it from memorizing the training data and instead encouraging it to learn more generalizable features. This can lead to better performance on unseen data and reduce the risk of overfitting, especially in deep neural networks with many parameters.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer with dropout rate of 0.5
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=20, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time
# Compile the model with Adam optimizer and additional metrics
model_details = {
    'Model': 'VGG16+DROPOUT+DENSE20',
    'Epochs': 20,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DROPOUT+DENSE20_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model2_20_Epochs Training History")
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 41s 2s/step - loss: 2.2460 - accuracy: 0.6687 - precision_6: 0.6693 - recall_6: 0.6540 - auc_12: 0.7142 - auc_13: 0.6763 - true_negatives_6: 276.0000 - false_positives_6: 128.0000 - false_negatives_6: 137.0000 - true_positives_6: 259.0000 - val_loss: 0.6696 - val_accuracy: 0.8250 - val_precision_6: 0.8710 - val_recall_6: 0.7788 - val_auc_12: 0.8959 - val_auc_13: 0.8966 - val_true_negatives_6: 84.0000 - val_false_positives_6: 12.0000 - val_false_negatives_6: 23.0000 - val_true_positives_6: 81.0000
# Epoch 2/20
# 25/25 [==============================] - 40s 2s/step - loss: 0.5904 - accuracy: 0.8438 - precision_6: 0.8281 - recall_6: 0.8636 - auc_12: 0.9027 - auc_13: 0.8801 - true_negatives_6: 333.0000 - false_positives_6: 71.0000 - false_negatives_6: 54.0000 - true_positives_6: 342.0000 - val_loss: 1.1466 - val_accuracy: 0.7050 - val_precision_6: 1.0000 - val_recall_6: 0.4327 - val_auc_12: 0.9007 - val_auc_13: 0.9279 - val_true_negatives_6: 96.0000 - val_false_positives_6: 0.0000e+00 - val_false_negatives_6: 59.0000 - val_true_positives_6: 45.0000
# 25/25 [==============================] - 40s 2s/step - loss: 0.0601 - accuracy: 0.9775 - precision_6: 0.9725 - recall_6: 0.9823 - auc_12: 0.9989 - auc_13: 0.9989 - true_negatives_6: 393.0000 - false_positives_6: 11.0000 - false_negatives_6: 7.0000 - true_positives_6: 389.0000 - val_loss: 0.4042 - val_accuracy: 0.8650 - val_precision_6: 0.8667 - val_recall_6: 0.8750 - val_auc_12: 0.9380 - val_auc_13: 0.9451 - val_true_negatives_6: 82.0000 - val_false_positives_6: 14.0000 - val_false_negatives_6: 13.0000 - val_true_positives_6: 91.0000
# Epoch 13: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3861 - accuracy: 0.8600 - precision_6: 0.8654 - recall_6: 0.8654 - auc_12: 0.9365 - auc_13: 0.9494 - true_negatives_6: 82.0000 - false_positives_6: 14.0000 - false_negatives_6: 14.0000 - true_positives_6: 90.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DROPOUT+DENSE20
# Epochs: 20
# Test Accuracy: 0.8600000143051147
# Test Loss: 0.3861454129219055
# Validation Accuracy: 0.8650000095367432
# Validation Loss: 0.4042171239852905
# Precision: 0.8653846153846154
# Recall: 0.8653846153846154
# AUC-ROC: 0.8597756410256411
# AUC-PR: 0.9003846153846153
# True Negatives: 82.0
# False Positives: 14.0
# False Negatives: 14.0
# True Positives: 90.0
# Error Rate: 0.4992
# F1 Score: 0.8653846153846154
# Cohen's Kappa: 0.719551282051282
# Matthews Correlation Coefficient: 0.719551282051282
# Balanced Accuracy: 0.859775641025641
# Time Taken (seconds): 530.471743106842

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer with dropout rate of 0.5
    Dense(1, activation='sigmoid')
])


# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=40, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DROPOUT+DENSE40',
    'Epochs': 40,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DROPOUT+DENSE40_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model2_40_Epochs Training History")
plt.show()
# Out:
# Epoch 1/40
# 25/25 [==============================] - 40s 2s/step - loss: 2.6358 - accuracy: 0.5850 - precision_7: 0.5804 - recall_7: 0.5833 - auc_14: 0.6134 - auc_15: 0.5875 - true_negatives_7: 237.0000 - false_positives_7: 167.0000 - false_negatives_7: 165.0000 - true_positives_7: 231.0000 - val_loss: 0.4839 - val_accuracy: 0.8000 - val_precision_7: 0.7667 - val_recall_7: 0.8846 - val_auc_14: 0.8863 - val_auc_15: 0.8933 - val_true_negatives_7: 68.0000 - val_false_positives_7: 28.0000 - val_false_negatives_7: 12.0000 - val_true_positives_7: 92.0000
# Epoch 2/40
# 25/25 [==============================] - 40s 2s/step - loss: 0.3975 - accuracy: 0.8238 - precision_7: 0.8278 - recall_7: 0.8131 - auc_14: 0.9076 - auc_15: 0.9075 - true_negatives_7: 337.0000 - false_positives_7: 67.0000 - false_negatives_7: 74.0000 - true_positives_7: 322.0000 - val_loss: 0.4056 - val_accuracy: 0.8200 - val_precision_7: 0.9146 - val_recall_7: 0.7212 - val_auc_14: 0.9189 - val_auc_15: 0.9331 - val_true_negatives_7: 89.0000 - val_false_positives_7: 7.0000 - val_false_negatives_7: 29.0000 - val_true_positives_7: 75.0000
# Epoch 3/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.2586 - accuracy: 0.8988 - precision_7: 0.8928 - recall_7: 0.9040 - auc_14: 0.9603 - auc_15: 0.9571 - true_negatives_7: 361.0000 - false_positives_7: 43.0000 - false_negatives_7: 38.0000 - true_positives_7: 358.0000 - val_loss: 0.4408 - val_accuracy: 0.8200 - val_precision_7: 0.9359 - val_recall_7: 0.7019 - val_auc_14: 0.9201 - val_auc_15: 0.9350 - val_true_negatives_7: 91.0000 - val_false_positives_7: 5.0000 - val_false_negatives_7: 31.0000 - val_true_positives_7: 73.0000
# Epoch 4/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.2246 - accuracy: 0.9087 - precision_7: 0.9027 - recall_7: 0.9141 - auc_14: 0.9714 - auc_15: 0.9705 - true_negatives_7: 365.0000 - false_positives_7: 39.0000 - false_negatives_7: 34.0000 - true_positives_7: 362.0000 - val_loss: 0.4164 - val_accuracy: 0.8450 - val_precision_7: 0.9398 - val_recall_7: 0.7500 - val_auc_14: 0.9232 - val_auc_15: 0.9381 - val_true_negatives_7: 91.0000 - val_false_positives_7: 5.0000 - val_false_negatives_7: 26.0000 - val_true_positives_7: 78.0000
# Epoch 5/40
# 25/25 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9125 - precision_7: 0.9158 - recall_7: 0.9066 - auc_14: 0.9707 - auc_15: 0.9663 - true_negatives_7: 371.0000 - false_positives_7: 33.0000 - false_negatives_7: 37.0000 - true_positives_7: 359.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.2189 - accuracy: 0.9125 - precision_7: 0.9158 - recall_7: 0.9066 - auc_14: 0.9707 - auc_15: 0.9663 - true_negatives_7: 371.0000 - false_positives_7: 33.0000 - false_negatives_7: 37.0000 - true_positives_7: 359.0000 - val_loss: 0.5045 - val_accuracy: 0.8100 - val_precision_7: 0.9714 - val_recall_7: 0.6538 - val_auc_14: 0.9272 - val_auc_15: 0.9423 - val_true_negatives_7: 94.0000 - val_false_positives_7: 2.0000 - val_false_negatives_7: 36.0000 - val_true_positives_7: 68.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4056 - accuracy: 0.8200 - precision_7: 0.9146 - recall_7: 0.7212 - auc_14: 0.9189 - auc_15: 0.9331 - true_negatives_7: 89.0000 - false_positives_7: 7.0000 - false_negatives_7: 29.0000 - true_positives_7: 75.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DROPOUT+DENSE40
# Epochs: 40
# Test Accuracy: 0.8199999928474426
# Test Loss: 0.40558570623397827
# Validation Accuracy: 0.8100000023841858
# Validation Loss: 0.504502534866333
# Precision: 0.9146341463414634
# Recall: 0.7211538461538461
# AUC-ROC: 0.8241185897435898
# AUC-PR: 0.8903939962476547
# True Negatives: 89.0
# False Positives: 7.0
# False Negatives: 29.0
# True Positives: 75.0
# Error Rate: 0.5036
# F1 Score: 0.8064516129032258
# Cohen's Kappa: 0.6425734710087371
# Matthews Correlation Coefficient: 0.6584734862733282
# Balanced Accuracy: 0.8241185897435898
# Time Taken (seconds): 213.2989730834961

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer with dropout rate of 0.5
    Dense(1, activation='sigmoid')
])


# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=60, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DROPOUT+DENSE60',
    'Epochs': 60,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DROPOUT+DENSE60_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model2_60_Epochs Training History")
plt.show()
# Out:
# Epoch 1/60
# 25/25 [==============================] - 40s 2s/step - loss: 1.9162 - accuracy: 0.6075 - precision_8: 0.6015 - recall_8: 0.6136 - auc_16: 0.6126 - auc_17: 0.5720 - true_negatives_8: 243.0000 - false_positives_8: 161.0000 - false_negatives_8: 153.0000 - true_positives_8: 243.0000 - val_loss: 0.4366 - val_accuracy: 0.8200 - val_precision_8: 0.8208 - val_recall_8: 0.8365 - val_auc_16: 0.8839 - val_auc_17: 0.8785 - val_true_negatives_8: 77.0000 - val_false_positives_8: 19.0000 - val_false_negatives_8: 17.0000 - val_true_positives_8: 87.0000
# Epoch 2/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.3803 - accuracy: 0.8263 - precision_8: 0.8253 - recall_8: 0.8232 - auc_16: 0.9135 - auc_17: 0.9130 - true_negatives_8: 335.0000 - false_positives_8: 69.0000 - false_negatives_8: 70.0000 - true_positives_8: 326.0000 - val_loss: 0.3945 - val_accuracy: 0.8250 - val_precision_8: 0.8791 - val_recall_8: 0.7692 - val_auc_16: 0.9081 - val_auc_17: 0.9170 - val_true_negatives_8: 85.0000 - val_false_positives_8: 11.0000 - val_false_negatives_8: 24.0000 - val_true_positives_8: 80.0000
# Epoch 3/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2933 - accuracy: 0.9025 - precision_8: 0.8936 - recall_8: 0.9116 - auc_16: 0.9467 - auc_17: 0.9416 - true_negatives_8: 361.0000 - false_positives_8: 43.0000 - false_negatives_8: 35.0000 - true_positives_8: 361.0000 - val_loss: 0.3942 - val_accuracy: 0.8350 - val_precision_8: 0.8989 - val_recall_8: 0.7692 - val_auc_16: 0.9171 - val_auc_17: 0.9298 - val_true_negatives_8: 87.0000 - val_false_positives_8: 9.0000 - val_false_negatives_8: 24.0000 - val_true_positives_8: 80.0000
# Epoch 4/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2753 - accuracy: 0.8950 - precision_8: 0.8881 - recall_8: 0.9015 - auc_16: 0.9559 - auc_17: 0.9522 - true_negatives_8: 359.0000 - false_positives_8: 45.0000 - false_negatives_8: 39.0000 - true_positives_8: 357.0000 - val_loss: 0.3709 - val_accuracy: 0.8500 - val_precision_8: 0.9022 - val_recall_8: 0.7981 - val_auc_16: 0.9232 - val_auc_17: 0.9356 - val_true_negatives_8: 87.0000 - val_false_positives_8: 9.0000 - val_false_negatives_8: 21.0000 - val_true_positives_8: 83.0000
# Epoch 5/60
# 25/25 [==============================] - 40s 2s/step - loss: 0.2447 - accuracy: 0.9150 - precision_8: 0.9121 - recall_8: 0.9167 - auc_16: 0.9655 - auc_17: 0.9605 - true_negatives_8: 369.0000 - false_positives_8: 35.0000 - false_negatives_8: 33.0000 - true_positives_8: 363.0000 - val_loss: 0.3587 - val_accuracy: 0.8750 - val_precision_8: 0.9158 - val_recall_8: 0.8365 - val_auc_16: 0.9274 - val_auc_17: 0.9415 - val_true_negatives_8: 88.0000 - val_false_positives_8: 8.0000 - val_false_negatives_8: 17.0000 - val_true_positives_8: 87.0000
# Epoch 6/60
# 25/25 [==============================] - 40s 2s/step - loss: 0.1973 - accuracy: 0.9350 - precision_8: 0.9236 - recall_8: 0.9470 - auc_16: 0.9802 - auc_17: 0.9799 - true_negatives_8: 373.0000 - false_positives_8: 31.0000 - false_negatives_8: 21.0000 - true_positives_8: 375.0000 - val_loss: 0.3598 - val_accuracy: 0.8650 - val_precision_8: 0.9053 - val_recall_8: 0.8269 - val_auc_16: 0.9265 - val_auc_17: 0.9412 - val_true_negatives_8: 87.0000 - val_false_positives_8: 9.0000 - val_false_negatives_8: 18.0000 - val_true_positives_8: 86.0000
# Epoch 7/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.1696 - accuracy: 0.9375 - precision_8: 0.9282 - recall_8: 0.9470 - auc_16: 0.9827 - auc_17: 0.9824 - true_negatives_8: 375.0000 - false_positives_8: 29.0000 - false_negatives_8: 21.0000 - true_positives_8: 375.0000 - val_loss: 0.3902 - val_accuracy: 0.8700 - val_precision_8: 0.9432 - val_recall_8: 0.7981 - val_auc_16: 0.9304 - val_auc_17: 0.9470 - val_true_negatives_8: 91.0000 - val_false_positives_8: 5.0000 - val_false_negatives_8: 21.0000 - val_true_positives_8: 83.0000
# Epoch 8/60
# 25/25 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9438 - precision_8: 0.9398 - recall_8: 0.9470 - auc_16: 0.9863 - auc_17: 0.9862 - true_negatives_8: 380.0000 - false_positives_8: 24.0000 - false_negatives_8: 21.0000 - true_positives_8: 375.0000Restoring model weights from the end of the best epoch: 5.
# 25/25 [==============================] - 39s 2s/step - loss: 0.1586 - accuracy: 0.9438 - precision_8: 0.9398 - recall_8: 0.9470 - auc_16: 0.9863 - auc_17: 0.9862 - true_negatives_8: 380.0000 - false_positives_8: 24.0000 - false_negatives_8: 21.0000 - true_positives_8: 375.0000 - val_loss: 0.3913 - val_accuracy: 0.8700 - val_precision_8: 0.9432 - val_recall_8: 0.7981 - val_auc_16: 0.9296 - val_auc_17: 0.9459 - val_true_negatives_8: 91.0000 - val_false_positives_8: 5.0000 - val_false_negatives_8: 21.0000 - val_true_positives_8: 83.0000
# Epoch 8: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3587 - accuracy: 0.8750 - precision_8: 0.9158 - recall_8: 0.8365 - auc_16: 0.9274 - auc_17: 0.9415 - true_negatives_8: 88.0000 - false_positives_8: 8.0000 - false_negatives_8: 17.0000 - true_positives_8: 87.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DROPOUT+DENSE60
# Epochs: 60
# Test Accuracy: 0.875
# Test Loss: 0.35866105556488037
# Validation Accuracy: 0.8700000047683716
# Validation Loss: 0.391274094581604
# Precision: 0.9157894736842105
# Recall: 0.8365384615384616
# AUC-ROC: 0.8766025641025642
# AUC-PR: 0.918663967611336
# True Negatives: 88.0
# False Positives: 8.0
# False Negatives: 17.0
# True Positives: 87.0
# Error Rate: 0.501
# F1 Score: 0.8743718592964824
# Cohen's Kappa: 0.750499001996008
# Matthews Correlation Coefficient: 0.7535448433820815
# Balanced Accuracy: 0.8766025641025641
# Time Taken (seconds): 331.7417559623718

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer with dropout rate of 0.5
    Dense(1, activation='sigmoid')
])


# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=80, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DROPOUT+DENSE80',
    'Epochs': 80,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DROPOUT+DENSE80_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model2_80_Epochs Training History")
plt.show()
# Out:
# Epoch 1/80
# 25/25 [==============================] - 40s 2s/step - loss: 2.4123 - accuracy: 0.6062 - precision_9: 0.6010 - recall_9: 0.6086 - auc_18: 0.6243 - auc_19: 0.5956 - true_negatives_9: 244.0000 - false_positives_9: 160.0000 - false_negatives_9: 155.0000 - true_positives_9: 241.0000 - val_loss: 0.6846 - val_accuracy: 0.7450 - val_precision_9: 0.9344 - val_recall_9: 0.5481 - val_auc_18: 0.8968 - val_auc_19: 0.9062 - val_true_negatives_9: 92.0000 - val_false_positives_9: 4.0000 - val_false_negatives_9: 47.0000 - val_true_positives_9: 57.0000
# Epoch 2/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.3802 - accuracy: 0.8400 - precision_9: 0.8472 - recall_9: 0.8258 - auc_18: 0.9157 - auc_19: 0.9226 - true_negatives_9: 345.0000 - false_positives_9: 59.0000 - false_negatives_9: 69.0000 - true_positives_9: 327.0000 - val_loss: 0.3765 - val_accuracy: 0.8650 - val_precision_9: 0.8667 - val_recall_9: 0.8750 - val_auc_18: 0.9171 - val_auc_19: 0.9282 - val_true_negatives_9: 82.0000 - val_false_positives_9: 14.0000 - val_false_negatives_9: 13.0000 - val_true_positives_9: 91.0000
# Epoch 3/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2603 - accuracy: 0.8963 - precision_9: 0.9003 - recall_9: 0.8889 - auc_18: 0.9592 - auc_19: 0.9590 - true_negatives_9: 365.0000 - false_positives_9: 39.0000 - false_negatives_9: 44.0000 - true_positives_9: 352.0000 - val_loss: 0.3878 - val_accuracy: 0.8450 - val_precision_9: 0.9011 - val_recall_9: 0.7885 - val_auc_18: 0.9215 - val_auc_19: 0.9344 - val_true_negatives_9: 87.0000 - val_false_positives_9: 9.0000 - val_false_negatives_9: 22.0000 - val_true_positives_9: 82.0000
# Epoch 4/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2316 - accuracy: 0.9075 - precision_9: 0.8985 - recall_9: 0.9167 - auc_18: 0.9669 - auc_19: 0.9625 - true_negatives_9: 363.0000 - false_positives_9: 41.0000 - false_negatives_9: 33.0000 - true_positives_9: 363.0000 - val_loss: 0.3996 - val_accuracy: 0.8550 - val_precision_9: 0.9412 - val_recall_9: 0.7692 - val_auc_18: 0.9244 - val_auc_19: 0.9380 - val_true_negatives_9: 91.0000 - val_false_positives_9: 5.0000 - val_false_negatives_9: 24.0000 - val_true_positives_9: 80.0000
# Epoch 5/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2014 - accuracy: 0.9287 - precision_9: 0.9227 - recall_9: 0.9343 - auc_18: 0.9758 - auc_19: 0.9757 - true_negatives_9: 373.0000 - false_positives_9: 31.0000 - false_negatives_9: 26.0000 - true_positives_9: 370.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.2014 - accuracy: 0.9287 - precision_9: 0.9227 - recall_9: 0.9343 - auc_18: 0.9758 - auc_19: 0.9757 - true_negatives_9: 373.0000 - false_positives_9: 31.0000 - false_negatives_9: 26.0000 - true_positives_9: 370.0000 - val_loss: 0.3836 - val_accuracy: 0.8550 - val_precision_9: 0.9412 - val_recall_9: 0.7692 - val_auc_18: 0.9298 - val_auc_19: 0.9453 - val_true_negatives_9: 91.0000 - val_false_positives_9: 5.0000 - val_false_negatives_9: 24.0000 - val_true_positives_9: 80.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3765 - accuracy: 0.8650 - precision_9: 0.8667 - recall_9: 0.8750 - auc_18: 0.9171 - auc_19: 0.9282 - true_negatives_9: 82.0000 - false_positives_9: 14.0000 - false_negatives_9: 13.0000 - true_positives_9: 91.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DROPOUT+DENSE80
# Epochs: 80
# Test Accuracy: 0.8650000095367432
# Test Loss: 0.37651270627975464
# Validation Accuracy: 0.8550000190734863
# Validation Loss: 0.38360974192619324
# Precision: 0.8666666666666667
# Recall: 0.875
# AUC-ROC: 0.8645833333333334
# AUC-PR: 0.9033333333333333
# True Negatives: 82.0
# False Positives: 14.0
# False Negatives: 13.0
# True Positives: 91.0
# Error Rate: 0.499
# F1 Score: 0.8708133971291866
# Cohen's Kappa: 0.7294589178356714
# Matthews Correlation Coefficient: 0.7294955398698875
# Balanced Accuracy: 0.8645833333333333
# Time Taken (seconds): 213.5837118625641

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)  # Repeat grayscale channel to 3 channels

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture
model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer with dropout rate of 0.5
    Dense(1, activation='sigmoid')
])


# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=100, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+DROPOUT+DENSE100',
    'Epochs': 100,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+DROPOUT+DENSE100_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model2_100_Epochs Training History")
plt.show()
# Out:
# Epoch 1/100
# 25/25 [==============================] - 40s 2s/step - loss: 2.3346 - accuracy: 0.6187 - precision_10: 0.6123 - recall_10: 0.6263 - auc_20: 0.6284 - auc_21: 0.5850 - true_negatives_10: 247.0000 - false_positives_10: 157.0000 - false_negatives_10: 148.0000 - true_positives_10: 248.0000 - val_loss: 0.6509 - val_accuracy: 0.7200 - val_precision_10: 0.9000 - val_recall_10: 0.5192 - val_auc_20: 0.8945 - val_auc_21: 0.9011 - val_true_negatives_10: 90.0000 - val_false_positives_10: 6.0000 - val_false_negatives_10: 50.0000 - val_true_positives_10: 54.0000
# Epoch 2/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.4028 - accuracy: 0.8400 - precision_10: 0.8367 - recall_10: 0.8409 - auc_20: 0.9082 - auc_21: 0.9043 - true_negatives_10: 339.0000 - false_positives_10: 65.0000 - false_negatives_10: 63.0000 - true_positives_10: 333.0000 - val_loss: 0.4039 - val_accuracy: 0.8250 - val_precision_10: 0.9059 - val_recall_10: 0.7404 - val_auc_20: 0.9145 - val_auc_21: 0.9276 - val_true_negatives_10: 88.0000 - val_false_positives_10: 8.0000 - val_false_negatives_10: 27.0000 - val_true_positives_10: 77.0000
# Epoch 3/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.2671 - accuracy: 0.8950 - precision_10: 0.8920 - recall_10: 0.8965 - auc_20: 0.9574 - auc_21: 0.9591 - true_negatives_10: 361.0000 - false_positives_10: 43.0000 - false_negatives_10: 41.0000 - true_positives_10: 355.0000 - val_loss: 0.4181 - val_accuracy: 0.8300 - val_precision_10: 0.9268 - val_recall_10: 0.7308 - val_auc_20: 0.9212 - val_auc_21: 0.9358 - val_true_negatives_10: 90.0000 - val_false_positives_10: 6.0000 - val_false_negatives_10: 28.0000 - val_true_positives_10: 76.0000
# Epoch 4/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.2425 - accuracy: 0.9013 - precision_10: 0.9033 - recall_10: 0.8965 - auc_20: 0.9637 - auc_21: 0.9583 - true_negatives_10: 366.0000 - false_positives_10: 38.0000 - false_negatives_10: 41.0000 - true_positives_10: 355.0000 - val_loss: 0.4880 - val_accuracy: 0.8200 - val_precision_10: 0.9359 - val_recall_10: 0.7019 - val_auc_20: 0.9222 - val_auc_21: 0.9353 - val_true_negatives_10: 91.0000 - val_false_positives_10: 5.0000 - val_false_negatives_10: 31.0000 - val_true_positives_10: 73.0000
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1950 - accuracy: 0.9388 - precision_10: 0.9415 - recall_10: 0.9343 - auc_20: 0.9766 - auc_21: 0.9738 - true_negatives_10: 381.0000 - false_positives_10: 23.0000 - false_negatives_10: 26.0000 - true_positives_10: 370.0000Restoring model weights from the end of the best epoch: 2.
# 25/25 [==============================] - 39s 2s/step - loss: 0.1950 - accuracy: 0.9388 - precision_10: 0.9415 - recall_10: 0.9343 - auc_20: 0.9766 - auc_21: 0.9738 - true_negatives_10: 381.0000 - false_positives_10: 23.0000 - false_negatives_10: 26.0000 - true_positives_10: 370.0000 - val_loss: 0.4223 - val_accuracy: 0.8450 - val_precision_10: 0.9398 - val_recall_10: 0.7500 - val_auc_20: 0.9227 - val_auc_21: 0.9369 - val_true_negatives_10: 91.0000 - val_false_positives_10: 5.0000 - val_false_negatives_10: 26.0000 - val_true_positives_10: 78.0000
# Epoch 5: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4039 - accuracy: 0.8250 - precision_10: 0.9059 - recall_10: 0.7404 - auc_20: 0.9145 - auc_21: 0.9276 - true_negatives_10: 88.0000 - false_positives_10: 8.0000 - false_negatives_10: 27.0000 - true_positives_10: 77.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+DROPOUT+DENSE100
# Epochs: 100
# Test Accuracy: 0.824999988079071
# Test Loss: 0.4038790762424469
# Validation Accuracy: 0.8450000286102295
# Validation Loss: 0.4223156273365021
# Precision: 0.9058823529411765
# Recall: 0.7403846153846154
# AUC-ROC: 0.828525641025641
# AUC-PR: 0.890633484162896
# True Negatives: 88.0
# False Positives: 8.0
# False Negatives: 27.0
# True Positives: 77.0
# Error Rate: 0.503
# F1 Score: 0.8148148148148148
# Cohen's Kappa: 0.6520874751491054
# Matthews Correlation Coefficient: 0.6640383628532385
# Balanced Accuracy: 0.828525641025641
# Time Taken (seconds): 212.79401516914368

# %% [markdown]
# # VGG16 (A) + GlobalAveragePooling2D + Dense Layers (B):
#
# Base Model (A): VGG16 pre-trained on ImageNet.
# Main Model (B): GlobalAveragePooling2D layer followed by dense layers for classification.
# Explanation: VGG16 extracts features, GlobalAveragePooling2D reduces spatial dimensions, and dense layers classify images.

# %% [markdown]
# Removing the dropout layer and adjusting the dense layer accordingly can be beneficial in certain cases. Dropout is a regularization technique used to prevent overfitting by randomly setting a fraction of input units to zero during training, which helps to reduce the model's reliance on specific weights and improves generalization.
#
# However, in some cases, using dropout may not be necessary or may not provide significant benefits. If the model is not overfitting or if there are other regularization techniques in place, such as early stopping or weight decay, the dropout layer may not be needed.
#
# Adjusting the dense layer accordingly means that you may need to modify the number of units or other parameters in the dense layer to compensate for the removal of the dropout layer. This adjustment ensures that the model still has enough capacity to learn from the data and make accurate predictions.
#
# In summary, removing the dropout layer and adjusting the dense layer can be useful when dropout is not providing significant benefits or when the model is not overfitting. It allows for a simpler model architecture without sacrificing performance.
#
# # GlobalAveragePooling2D
#
# GlobalAveragePooling2D is used to reduce the spatial dimensions (height and width) of a 3D tensor and convert it into a 2D tensor by taking the average of all values in each channel.
#
# In the context of convolutional neural networks (CNNs) for image classification, GlobalAveragePooling2D is often used as an alternative to Flatten followed by Dense layers. It helps in reducing the number of parameters in the model and controlling overfitting. Here's why it's commonly used:
#
# 1. **Reduction in Parameters**: GlobalAveragePooling2D reduces the spatial dimensions of the input, which in turn reduces the number of parameters in the model. This can help prevent overfitting, especially in models with a large number of parameters.
#
# 2. **Translation Invariance**: By taking the average of all values in each channel, GlobalAveragePooling2D makes the model more robust to translations in the input image. This means that the model can still recognize objects in an image even if they are in slightly different positions.
#
# 3. **Spatial Hierarchy**: GlobalAveragePooling2D captures the spatial hierarchy of features in an image. Features at higher spatial resolutions (closer to the input) represent more detailed information, while features at lower resolutions represent more abstract information. By taking the average, GlobalAveragePooling2D retains this hierarchy.
#
# 4. **Computationally Efficient**: Compared to Flatten followed by Dense layers, GlobalAveragePooling2D is computationally more efficient. It reduces the computational load of the model, making it faster to train and evaluate.
#
# Overall, GlobalAveragePooling2D is a simple yet effective way to reduce the spatial dimensions of an input tensor in a CNN, leading to a more efficient and potentially more effective model.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture with VGG16
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Global average pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=20, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+GLOBALAVGPOOL+DENSE20',
    'Epochs': 20,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+GLOBALAVGPOOL+DENSE20_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model3_20_Epochs Training History")
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 31s 1s/step - loss: 0.6353 - accuracy: 0.6538 - precision_12: 0.6434 - recall_12: 0.6742 - auc_24: 0.6997 - auc_25: 0.6816 - true_negatives_12: 256.0000 - false_positives_12: 148.0000 - false_negatives_12: 129.0000 - true_positives_12: 267.0000 - val_loss: 0.5423 - val_accuracy: 0.7550 - val_precision_12: 0.8313 - val_recall_12: 0.6635 - val_auc_24: 0.8601 - val_auc_25: 0.8589 - val_true_negatives_12: 82.0000 - val_false_positives_12: 14.0000 - val_false_negatives_12: 35.0000 - val_true_positives_12: 69.0000
# Epoch 2/20
# 25/25 [==============================] - 34s 1s/step - loss: 0.4706 - accuracy: 0.7837 - precision_12: 0.7794 - recall_12: 0.7854 - auc_24: 0.8666 - auc_25: 0.8693 - true_negatives_12: 316.0000 - false_positives_12: 88.0000 - false_negatives_12: 85.0000 - true_positives_12: 311.0000 - val_loss: 0.4901 - val_accuracy: 0.7850 - val_precision_12: 0.8352 - val_recall_12: 0.7308 - val_auc_24: 0.8659 - val_auc_25: 0.8652 - val_true_negatives_12: 81.0000 - val_false_positives_12: 15.0000 - val_false_negatives_12: 28.0000 - val_true_positives_12: 76.0000
# Epoch 3/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.4197 - accuracy: 0.8138 - precision_12: 0.8191 - recall_12: 0.8005 - auc_24: 0.8943 - auc_25: 0.8828 - true_negatives_12: 334.0000 - false_positives_12: 70.0000 - false_negatives_12: 79.0000 - true_positives_12: 317.0000 - val_loss: 0.4574 - val_accuracy: 0.7900 - val_precision_12: 0.8039 - val_recall_12: 0.7885 - val_auc_24: 0.8721 - val_auc_25: 0.8740 - val_true_negatives_12: 76.0000 - val_false_positives_12: 20.0000 - val_false_negatives_12: 22.0000 - val_true_positives_12: 82.0000
# Epoch 4/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.4035 - accuracy: 0.8188 - precision_12: 0.8130 - recall_12: 0.8232 - auc_24: 0.8982 - auc_25: 0.8848 - true_negatives_12: 329.0000 - false_positives_12: 75.0000 - false_negatives_12: 70.0000 - true_positives_12: 326.0000 - val_loss: 0.4680 - val_accuracy: 0.7900 - val_precision_12: 0.8444 - val_recall_12: 0.7308 - val_auc_24: 0.8756 - val_auc_25: 0.8780 - val_true_negatives_12: 82.0000 - val_false_positives_12: 14.0000 - val_false_negatives_12: 28.0000 - val_true_positives_12: 76.0000
# Epoch 5/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.4087 - accuracy: 0.8325 - precision_12: 0.8227 - recall_12: 0.8434 - auc_24: 0.8944 - auc_25: 0.8837 - true_negatives_12: 332.0000 - false_positives_12: 72.0000 - false_negatives_12: 62.0000 - true_positives_12: 334.0000 - val_loss: 0.4534 - val_accuracy: 0.7950 - val_precision_12: 0.8316 - val_recall_12: 0.7596 - val_auc_24: 0.8789 - val_auc_25: 0.8827 - val_true_negatives_12: 80.0000 - val_false_positives_12: 16.0000 - val_false_negatives_12: 25.0000 - val_true_positives_12: 79.0000
# Epoch 6/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3726 - accuracy: 0.8487 - precision_12: 0.8429 - recall_12: 0.8535 - auc_24: 0.9142 - auc_25: 0.9011 - true_negatives_12: 341.0000 - false_positives_12: 63.0000 - false_negatives_12: 58.0000 - true_positives_12: 338.0000 - val_loss: 0.4399 - val_accuracy: 0.8050 - val_precision_12: 0.8155 - val_recall_12: 0.8077 - val_auc_24: 0.8818 - val_auc_25: 0.8880 - val_true_negatives_12: 77.0000 - val_false_positives_12: 19.0000 - val_false_negatives_12: 20.0000 - val_true_positives_12: 84.0000
# Epoch 7/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3717 - accuracy: 0.8512 - precision_12: 0.8420 - recall_12: 0.8611 - auc_24: 0.9135 - auc_25: 0.9058 - true_negatives_12: 340.0000 - false_positives_12: 64.0000 - false_negatives_12: 55.0000 - true_positives_12: 341.0000 - val_loss: 0.4409 - val_accuracy: 0.8150 - val_precision_12: 0.8384 - val_recall_12: 0.7981 - val_auc_24: 0.8840 - val_auc_25: 0.8918 - val_true_negatives_12: 80.0000 - val_false_positives_12: 16.0000 - val_false_negatives_12: 21.0000 - val_true_positives_12: 83.0000
# Epoch 8/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3700 - accuracy: 0.8500 - precision_12: 0.8350 - recall_12: 0.8687 - auc_24: 0.9142 - auc_25: 0.9060 - true_negatives_12: 336.0000 - false_positives_12: 68.0000 - false_negatives_12: 52.0000 - true_positives_12: 344.0000 - val_loss: 0.4349 - val_accuracy: 0.8150 - val_precision_12: 0.8384 - val_recall_12: 0.7981 - val_auc_24: 0.8870 - val_auc_25: 0.8954 - val_true_negatives_12: 80.0000 - val_false_positives_12: 16.0000 - val_false_negatives_12: 21.0000 - val_true_positives_12: 83.0000
# Epoch 9/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3556 - accuracy: 0.8525 - precision_12: 0.8564 - recall_12: 0.8434 - auc_24: 0.9213 - auc_25: 0.9145 - true_negatives_12: 348.0000 - false_positives_12: 56.0000 - false_negatives_12: 62.0000 - true_positives_12: 334.0000 - val_loss: 0.4379 - val_accuracy: 0.8150 - val_precision_12: 0.8384 - val_recall_12: 0.7981 - val_auc_24: 0.8896 - val_auc_25: 0.8980 - val_true_negatives_12: 80.0000 - val_false_positives_12: 16.0000 - val_false_negatives_12: 21.0000 - val_true_positives_12: 83.0000
# Epoch 10/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3418 - accuracy: 0.8612 - precision_12: 0.8484 - recall_12: 0.8763 - auc_24: 0.9277 - auc_25: 0.9235 - true_negatives_12: 342.0000 - false_positives_12: 62.0000 - false_negatives_12: 49.0000 - true_positives_12: 347.0000 - val_loss: 0.4300 - val_accuracy: 0.8150 - val_precision_12: 0.8317 - val_recall_12: 0.8077 - val_auc_24: 0.8910 - val_auc_25: 0.9003 - val_true_negatives_12: 79.0000 - val_false_positives_12: 17.0000 - val_false_negatives_12: 20.0000 - val_true_positives_12: 84.0000
# Epoch 11/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3494 - accuracy: 0.8600 - precision_12: 0.8498 - recall_12: 0.8712 - auc_24: 0.9237 - auc_25: 0.9184 - true_negatives_12: 343.0000 - false_positives_12: 61.0000 - false_negatives_12: 51.0000 - true_positives_12: 345.0000 - val_loss: 0.4364 - val_accuracy: 0.8200 - val_precision_12: 0.8542 - val_recall_12: 0.7885 - val_auc_24: 0.8911 - val_auc_25: 0.9010 - val_true_negatives_12: 82.0000 - val_false_positives_12: 14.0000 - val_false_negatives_12: 22.0000 - val_true_positives_12: 82.0000
# Epoch 12/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3528 - accuracy: 0.8550 - precision_12: 0.8483 - recall_12: 0.8611 - auc_24: 0.9223 - auc_25: 0.9151 - true_negatives_12: 343.0000 - false_positives_12: 61.0000 - false_negatives_12: 55.0000 - true_positives_12: 341.0000 - val_loss: 0.4281 - val_accuracy: 0.8200 - val_precision_12: 0.8400 - val_recall_12: 0.8077 - val_auc_24: 0.8909 - val_auc_25: 0.8997 - val_true_negatives_12: 80.0000 - val_false_positives_12: 16.0000 - val_false_negatives_12: 20.0000 - val_true_positives_12: 84.0000
# Epoch 13/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3306 - accuracy: 0.8700 - precision_12: 0.8632 - recall_12: 0.8763 - auc_24: 0.9326 - auc_25: 0.9266 - true_negatives_12: 349.0000 - false_positives_12: 55.0000 - false_negatives_12: 49.0000 - true_positives_12: 347.0000 - val_loss: 0.4318 - val_accuracy: 0.8200 - val_precision_12: 0.8542 - val_recall_12: 0.7885 - val_auc_24: 0.8919 - val_auc_25: 0.8997 - val_true_negatives_12: 82.0000 - val_false_positives_12: 14.0000 - val_false_negatives_12: 22.0000 - val_true_positives_12: 82.0000
# Epoch 14/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3205 - accuracy: 0.8650 - precision_12: 0.8547 - recall_12: 0.8763 - auc_24: 0.9369 - auc_25: 0.9312 - true_negatives_12: 345.0000 - false_positives_12: 59.0000 - false_negatives_12: 49.0000 - true_positives_12: 347.0000 - val_loss: 0.4367 - val_accuracy: 0.8200 - val_precision_12: 0.8778 - val_recall_12: 0.7596 - val_auc_24: 0.8936 - val_auc_25: 0.9011 - val_true_negatives_12: 85.0000 - val_false_positives_12: 11.0000 - val_false_negatives_12: 25.0000 - val_true_positives_12: 79.0000
# Epoch 15/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3151 - accuracy: 0.8650 - precision_12: 0.8582 - recall_12: 0.8712 - auc_24: 0.9393 - auc_25: 0.9375 - true_negatives_12: 347.0000 - false_positives_12: 57.0000 - false_negatives_12: 51.0000 - true_positives_12: 345.0000 - val_loss: 0.4252 - val_accuracy: 0.8400 - val_precision_12: 0.8529 - val_recall_12: 0.8365 - val_auc_24: 0.8953 - val_auc_25: 0.9037 - val_true_negatives_12: 81.0000 - val_false_positives_12: 15.0000 - val_false_negatives_12: 17.0000 - val_true_positives_12: 87.0000
# Epoch 16/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3270 - accuracy: 0.8800 - precision_12: 0.8750 - recall_12: 0.8838 - auc_24: 0.9327 - auc_25: 0.9242 - true_negatives_12: 354.0000 - false_positives_12: 50.0000 - false_negatives_12: 46.0000 - true_positives_12: 350.0000 - val_loss: 0.4366 - val_accuracy: 0.8250 - val_precision_12: 0.8791 - val_recall_12: 0.7692 - val_auc_24: 0.8966 - val_auc_25: 0.9065 - val_true_negatives_12: 85.0000 - val_false_positives_12: 11.0000 - val_false_negatives_12: 24.0000 - val_true_positives_12: 80.0000
# Epoch 17/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3143 - accuracy: 0.8750 - precision_12: 0.8663 - recall_12: 0.8838 - auc_24: 0.9389 - auc_25: 0.9336 - true_negatives_12: 350.0000 - false_positives_12: 54.0000 - false_negatives_12: 46.0000 - true_positives_12: 350.0000 - val_loss: 0.4245 - val_accuracy: 0.8550 - val_precision_12: 0.8788 - val_recall_12: 0.8365 - val_auc_24: 0.8973 - val_auc_25: 0.9079 - val_true_negatives_12: 84.0000 - val_false_positives_12: 12.0000 - val_false_negatives_12: 17.0000 - val_true_positives_12: 87.0000
# Epoch 18/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3058 - accuracy: 0.8737 - precision_12: 0.8697 - recall_12: 0.8763 - auc_24: 0.9421 - auc_25: 0.9399 - true_negatives_12: 352.0000 - false_positives_12: 52.0000 - false_negatives_12: 49.0000 - true_positives_12: 347.0000 - val_loss: 0.4252 - val_accuracy: 0.8500 - val_precision_12: 0.8776 - val_recall_12: 0.8269 - val_auc_24: 0.8979 - val_auc_25: 0.9091 - val_true_negatives_12: 84.0000 - val_false_positives_12: 12.0000 - val_false_negatives_12: 18.0000 - val_true_positives_12: 86.0000
# Epoch 19/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.3041 - accuracy: 0.8800 - precision_12: 0.8713 - recall_12: 0.8889 - auc_24: 0.9427 - auc_25: 0.9391 - true_negatives_12: 352.0000 - false_positives_12: 52.0000 - false_negatives_12: 44.0000 - true_positives_12: 352.0000 - val_loss: 0.4255 - val_accuracy: 0.8400 - val_precision_12: 0.8830 - val_recall_12: 0.7981 - val_auc_24: 0.8982 - val_auc_25: 0.9093 - val_true_negatives_12: 85.0000 - val_false_positives_12: 11.0000 - val_false_negatives_12: 21.0000 - val_true_positives_12: 83.0000
# Epoch 20/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.2964 - accuracy: 0.8825 - precision_12: 0.8813 - recall_12: 0.8813 - auc_24: 0.9465 - auc_25: 0.9401 - true_negatives_12: 357.0000 - false_positives_12: 47.0000 - false_negatives_12: 47.0000 - true_positives_12: 349.0000 - val_loss: 0.4209 - val_accuracy: 0.8500 - val_precision_12: 0.8854 - val_recall_12: 0.8173 - val_auc_24: 0.8987 - val_auc_25: 0.9108 - val_true_negatives_12: 85.0000 - val_false_positives_12: 11.0000 - val_false_negatives_12: 19.0000 - val_true_positives_12: 85.0000
# 7/7 [==============================] - 8s 1s/step - loss: 0.4209 - accuracy: 0.8500 - precision_12: 0.8854 - recall_12: 0.8173 - auc_24: 0.8987 - auc_25: 0.9108 - true_negatives_12: 85.0000 - false_positives_12: 11.0000 - false_negatives_12: 19.0000 - true_positives_12: 85.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GLOBALAVGPOOL+DENSE20
# Epochs: 20
# Test Accuracy: 0.8500000238418579
# Test Loss: 0.4209041893482208
# Validation Accuracy: 0.8500000238418579
# Validation Loss: 0.4209041893482208
# Precision: 0.8854166666666666
# Recall: 0.8173076923076923
# AUC-ROC: 0.8513621794871794
# AUC-PR: 0.8988621794871794
# True Negatives: 85.0
# False Positives: 11.0
# False Negatives: 19.0
# True Positives: 85.0
# Error Rate: 0.5008
# F1 Score: 0.85
# Cohen's Kappa: 0.700479233226837
# Matthews Correlation Coefficient: 0.7027243589743589
# Balanced Accuracy: 0.8513621794871795
# Time Taken (seconds): 762.7161002159119

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture with VGG16
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Global average pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=40, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+GLOBALAVGPOOL+DENSE40',
    'Epochs': 40,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+GLOBALAVGPOOL+DENSE40_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model3_40_Epochs Training History")
plt.show()
# Out:
# Epoch 1/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.6145 - accuracy: 0.6600 - precision_13: 0.6550 - recall_13: 0.6616 - auc_26: 0.7192 - auc_27: 0.7119 - true_negatives_13: 266.0000 - false_positives_13: 138.0000 - false_negatives_13: 134.0000 - true_positives_13: 262.0000 - val_loss: 0.5565 - val_accuracy: 0.7200 - val_precision_13: 0.8636 - val_recall_13: 0.5481 - val_auc_26: 0.8615 - val_auc_27: 0.8649 - val_true_negatives_13: 87.0000 - val_false_positives_13: 9.0000 - val_false_negatives_13: 47.0000 - val_true_positives_13: 57.0000
# Epoch 2/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.4766 - accuracy: 0.7775 - precision_13: 0.7766 - recall_13: 0.7727 - auc_26: 0.8594 - auc_27: 0.8404 - true_negatives_13: 316.0000 - false_positives_13: 88.0000 - false_negatives_13: 90.0000 - true_positives_13: 306.0000 - val_loss: 0.4719 - val_accuracy: 0.8000 - val_precision_13: 0.8077 - val_recall_13: 0.8077 - val_auc_26: 0.8679 - val_auc_27: 0.8702 - val_true_negatives_13: 76.0000 - val_false_positives_13: 20.0000 - val_false_negatives_13: 20.0000 - val_true_positives_13: 84.0000
# Epoch 3/40
# 25/25 [==============================] - 38s 2s/step - loss: 0
40
# 25/25 [==============================] - 38s 2s/step - loss: 0.3236 - accuracy: 0.8625 - precision_13: 0.8522 - recall_13: 0.8737 - auc_26: 0.9353 - auc_27: 0.9311 - true_negatives_13: 344.0000 - false_positives_13: 60.0000 - false_negatives_13: 50.0000 - true_positives_13: 346.0000 - val_loss: 0.4344 - val_accuracy: 0.8300 - val_precision_13: 0.8646 - val_recall_13: 0.7981 - val_auc_26: 0.8953 - val_auc_27: 0.9049 - val_true_negatives_13: 83.0000 - val_false_positives_13: 13.0000 - val_false_negatives_13: 21.0000 - val_true_positives_13: 83.0000
# Epoch 15/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.3244 - accuracy: 0.8662 - precision_13: 0.8550 - recall_13: 0.8788 - auc_26: 0.9345 - auc_27: 0.9314 - true_negatives_13: 345.0000 - false_positives_13: 59.0000 - false_negatives_13: 48.0000 - true_positives_13: 348.0000 - val_loss: 0.4249 - val_accuracy: 0.8450 - val_precision_13: 0.8614 - val_recall_13: 0.8365 - val_auc_26: 0.8960 - val_auc_27: 0.9060 - val_true_negatives_13: 82.0000 - val_false_positives_13: 14.0000 - val_false_negatives_13: 17.0000 - val_true_positives_13: 87.0000
# Epoch 16/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.3145 - accuracy: 0.8750 - precision_13: 0.8682 - recall_13: 0.8813 - auc_26: 0.9397 - auc_27: 0.9345 - true_negatives_13: 351.0000 - false_positives_13: 53.0000 - false_negatives_13: 47.0000 - true_positives_13: 349.0000 - val_loss: 0.4265 - val_accuracy: 0.8450 - val_precision_13: 0.8763 - val_recall_13: 0.8173 - val_auc_26: 0.8979 - val_auc_27: 0.9082 - val_true_negatives_13: 84.0000 - val_false_positives_13: 12.0000 - val_false_negatives_13: 19.0000 - val_true_positives_13: 85.0000
# Epoch 17/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.3235 - accuracy: 0.8725 - precision_13: 0.8639 - recall_13: 0.8813 - auc_26: 0.9351 - auc_27: 0.9300 - true_negatives_13: 349.0000 - false_positives_13: 55.0000 - false_negatives_13: 47.0000 - true_positives_13: 349.0000 - val_loss: 0.4269 - val_accuracy: 0.8450 - val_precision_13: 0.8842 - val_recall_13: 0.8077 - val_auc_26: 0.8985 - val_auc_27: 0.9086 - val_true_negatives_13: 85.0000 - val_false_positives_13: 11.0000 - val_false_negatives_13: 20.0000 - val_true_positives_13: 84.0000
# Epoch 18/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.3058 - accuracy: 0.8875 - precision_13: 0.8768 - recall_13: 0.8990 - auc_26: 0.9419 - auc_27: 0.9379 - true_negatives_13: 354.0000 - false_positives_13: 50.0000 - false_negatives_13: 40.0000 - true_positives_13: 356.0000 - val_loss: 0.4243 - val_accuracy: 0.8500 - val_precision_13: 0.8854 - val_recall_13: 0.8173 - val_auc_26: 0.8991 - val_auc_27: 0.9105 - val_true_negatives_13: 85.0000 - val_false_positives_13: 11.0000 - val_false_negatives_13: 19.0000 - val_true_positives_13: 85.0000
# Epoch 19/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.3040 - accuracy: 0.8712 - precision_13: 0.8600 - recall_13: 0.8838 - auc_26: 0.9427 - auc_27: 0.9414 - true_negatives_13: 347.0000 - false_positives_13: 57.0000 - false_negatives_13: 46.0000 - true_positives_13: 350.0000 - val_loss: 0.4175 - val_accuracy: 0.8550 - val_precision_13: 0.8788 - val_recall_13: 0.8365 - val_auc_26: 0.8992 - val_auc_27: 0.9098 - val_true_negatives_13: 84.0000 - val_false_positives_13: 12.0000 - val_false_negatives_13: 17.0000 - val_true_positives_13: 87.0000
# Epoch 20/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.2988 - accuracy: 0.8737 - precision_13: 0.8660 - recall_13: 0.8813 - auc_26: 0.9454 - auc_27: 0.9415 - true_negatives_13: 350.0000 - false_positives_13: 54.0000 - false_negatives_13: 47.0000 - true_positives_13: 349.0000 - val_loss: 0.4211 - val_accuracy: 0.8500 - val_precision_13: 0.8854 - val_recall_13: 0.8173 - val_auc_26: 0.9004 - val_auc_27: 0.9113 - val_true_negatives_13: 85.0000 - val_false_positives_13: 11.0000 - val_false_negatives_13: 19.0000 - val_true_positives_13: 85.0000
# Epoch 21/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.2866 - accuracy: 0.8875 - precision_13: 0.8825 - recall_13: 0.8914 - auc_26: 0.9498 - auc_27: 0.9454 - true_negatives_13: 357.0000 - false_positives_13: 47.0000 - false_negatives_13: 43.0000 - true_positives_13: 353.0000 - val_loss: 0.4188 - val_accuracy: 0.8550 - val_precision_13: 0.8866 - val_recall_13: 0.8269 - val_auc_26: 0.9009 - val_auc_27: 0.9123 - val_true_negatives_13: 85.0000 - val_false_positives_13: 11.0000 - val_false_negatives_13: 18.0000 - val_true_positives_13: 86.0000
# Epoch 22/40
# 25/25 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.8875 - precision_13: 0.8732 - recall_13: 0.9040 - auc_26: 0.9512 - auc_27: 0.9463 - true_negatives_13: 352.0000 - false_positives_13: 52.0000 - false_negatives_13: 38.0000 - true_positives_13: 358.0000Restoring model weights from the end of the best epoch: 19.
# 25/25 [==============================] - 38s 2s/step - loss: 0.2841 - accuracy: 0.8875 - precision_13: 0.8732 - recall_13: 0.9040 - auc_26: 0.9512 - auc_27: 0.9463 - true_negatives_13: 352.0000 - false_positives_13: 52.0000 - false_negatives_13: 38.0000 - true_positives_13: 358.0000 - val_loss: 0.4274 - val_accuracy: 0.8350 - val_precision_13: 0.8901 - val_recall_13: 0.7788 - val_auc_26: 0.9013 - val_auc_27: 0.9131 - val_true_negatives_13: 86.0000 - val_false_positives_13: 10.0000 - val_false_negatives_13: 23.0000 - val_true_positives_13: 81.0000
# Epoch 22: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4175 - accuracy: 0.8550 - precision_13: 0.8788 - recall_13: 0.8365 - auc_26: 0.8992 - auc_27: 0.9098 - true_negatives_13: 84.0000 - false_positives_13: 12.0000 - false_negatives_13: 17.0000 - true_positives_13: 87.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GLOBALAVGPOOL+DENSE40
# Epochs: 40
# Test Accuracy: 0.8550000190734863
# Test Loss: 0.41749849915504456
# Validation Accuracy: 0.8349999785423279
# Validation Loss: 0.42735588550567627
# Precision: 0.8787878787878788
# Recall: 0.8365384615384616
# AUC-ROC: 0.8557692307692308
# AUC-PR: 0.9001631701631703
# True Negatives: 84.0
# False Positives: 12.0
# False Negatives: 17.0
# True Positives: 87.0
# Error Rate: 0.5002
# F1 Score: 0.8571428571428571
# Cohen's Kappa: 0.7101159536185526
# Matthews Correlation Coefficient: 0.7110045540110876
# Balanced Accuracy: 0.8557692307692308
# Time Taken (seconds): 851.8201665878296

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architec
60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3133 - accuracy: 0.8750 - precision_14: 0.8682 - recall_14: 0.8813 - auc_28: 0.9395 - auc_29: 0.9371 - true_negatives_14: 351.0000 - false_positives_14: 53.0000 - false_negatives_14: 47.0000 - true_positives_14: 349.0000 - val_loss: 0.4262 - val_accuracy: 0.8500 - val_precision_14: 0.8700 - val_recall_14: 0.8365 - val_auc_28: 0.8966 - val_auc_29: 0.9079 - val_true_negatives_14: 83.0000 - val_false_positives_14: 13.0000 - val_false_negatives_14: 17.0000 - val_true_positives_14: 87.0000
# Epoch 18/60
# 25/25 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.8788 - precision_14: 0.8728 - recall_14: 0.8838 - auc_28: 0.9423 - auc_29: 0.9404 - true_negatives_14: 353.0000 - false_positives_14: 51.0000 - false_negatives_14: 46.0000 - true_positives_14: 350.0000Restoring model weights from the end of the best epoch: 15.
# 25/25 [==============================] - 38s 2s/step - loss: 0.3058 - accuracy: 0.8788 - precision_14: 0.8728 - recall_14: 0.8838 - auc_28: 0.9423 - auc_29: 0.9404 - true_negatives_14: 353.0000 - false_positives_14: 51.0000 - false_negatives_14: 46.0000 - true_positives_14: 350.0000 - val_loss: 0.4281 - val_accuracy: 0.8450 - val_precision_14: 0.8687 - val_recall_14: 0.8269 - val_auc_28: 0.8971 - val_auc_29: 0.9087 - val_true_negatives_14: 83.0000 - val_false_positives_14: 13.0000 - val_false_negatives_14: 18.0000 - val_true_positives_14: 86.0000
# Epoch 18: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4243 - accuracy: 0.8400 - precision_14: 0.8462 - recall_14: 0.8462 - auc_28: 0.8949 - auc_29: 0.9061 - true_negatives_14: 80.0000 - false_positives_14: 16.0000 - false_negatives_14: 16.0000 - true_positives_14: 88.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GLOBALAVGPOOL+DENSE60
# Epochs: 60
# Test Accuracy: 0.8399999737739563
# Test Loss: 0.4243379533290863
# Validation Accuracy: 0.8450000286102295
# Validation Loss: 0.4280725419521332
# Precision: 0.8461538461538461
# Recall: 0.8461538461538461
# AUC-ROC: 0.8397435897435898
# AUC-PR: 0.8861538461538462
# True Negatives: 80.0
# False Positives: 16.0
# False Negatives: 16.0
# True Positives: 88.0
# Error Rate: 0.4992
# F1 Score: 0.8461538461538461
# Cohen's Kappa: 0.6794871794871795
# Matthews Correlation Coefficient: 0.6794871794871795
# Balanced Accuracy: 0.8397435897435898
# Time Taken (seconds): 699.1630692481995

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture with VGG16
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Global average pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=80, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+GLOBALAVGPOOL+DENSE80',
    'Epochs': 80,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+GLOBALAVGPOOL+DENSE80_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model3_80_Epochs Training History")
plt.show()
# Out:
# Epoch 1/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.6401 - accuracy: 0.6275 - precision_15: 0.6244 - recall_15: 0.6212 - auc_30: 0.6858 - auc_31: 0.6739 - true_negatives_15: 256.0000 - false_positives_15: 148.0000 - false_negatives_15: 150.0000 - true_positives_15: 246.0000 - val_loss: 0.5295 - val_accuracy: 0.7700 - val_precision_15: 0.8372 - val_recall_15: 0.6923 - val_auc_30: 0.8595 - val_auc_31: 0.8587 - val_true_negatives_15: 82.0000 - val_false_positives_15: 14.0000 - val_false_negatives_15: 32.0000 - val_true_positives_15: 72.0000
# Epoch 2/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.4690 - accuracy: 0.7912 - precision_15: 0.7928 - recall_15: 0.7828 - auc_30: 0.8674 - auc_31: 0.8549 - true_negatives_15: 323.0000 - false_positives_15: 81.0000 - false_negatives_15: 86.0000 - true_positives_15: 310.0000 - val_loss: 0.4694 - val_accuracy: 0.7800 - val_precision_15: 0.8061 - val_recall_15: 0.7596 - val_auc_30: 0.8684 - val_auc_31: 0.8695 - val_true_negatives_15: 77.0000 - val_false_positives_15: 19.0000 - val_false_negatives_15: 25.0000 - val_true_positives_15: 79.0000
# Epoch 3/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.4232 - accuracy: 0.8213 - precision_15: 0.8155 - recall_15: 0.8258 - auc_30: 0.8888 - auc_31: 0.8784 - true_negatives_15: 330.0000 - false_positives_15: 74.0000 - false_negatives_15: 69.0000 - true_positives_15: 327.0000 - val_loss: 0.4533 - val_accuracy: 0.8000 - val_precision_15: 0.8200 - val_recall_15: 0.7885 - val_auc_30: 0.8752 - val_auc_31: 0.8784 - val_true_negatives_15: 78.0000 - val_false_positives_15: 18.0000 - val_false_negatives_15: 22.0000 - val_true_positives_15: 82.0000
# Epoch 4/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3998 - accuracy: 0.8275 - precision_15: 0.8209 - recall_15: 0.8333 - auc_30: 0.9003 - auc_31: 0.8881 - true_negatives_15: 332.0000 - false_positives_15: 72.0000 - false_negatives_15: 66.0000 - true_positives_15: 330.0000 - val_loss: 0.4488 - val_accuracy: 0.8100 - val_precision_15: 0.8367 - val_recall_15: 0.7885 - val_auc_30: 0.8785 - val_auc_31: 0.8816 - val_true_negatives_15: 80.0000 - val_false_positives_15: 16.0000 - val_false_negatives_15: 22.0000 - val_true_positives_15: 82.0000
# Epoch 5/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3898 - accuracy: 0.8325 - precision_15: 0.8227 - recall_15: 0.8434 - auc_30: 0.9056 - auc_31: 0.8976 - true_negatives_15: 332.0000 - false_positives_15: 72.0000 - false_negatives_15: 62.0000 - true_positives_15: 334.0000 - val_loss: 0.4410 - val_accuracy: 0.8100 - val_precision_15: 0.8173 - val_recall_15: 0.8173 - val_auc_30: 0.8812 - val_auc_31: 0.8854 - val_true_negatives_15: 77.0000 - val_false_positives_15: 19.0000 - val_false_negatives_15: 19.0000 - val_true_positives_15: 85.0000
# Epoch 6/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3844 - accuracy: 0.8438 - precision_15: 0.8313 - recall_15: 0.8586 - auc_30: 0.9074 - auc_31: 0.9008 - true_negatives_15: 335.0000 - false_positives_15: 69.0000 - false_negatives_15: 56.0000 - true_positives_15: 340.0000 - val_loss: 0.4374 - val_accuracy: 0.8150 - val_precision_15: 0.8317 - val_recall_15: 0.8077 - val_auc_30: 0.8852 - val_auc_31: 0.8923 - val_true_negatives_15: 79.0000 - val_false_positives_15: 17.0000 - val_false_negatives_15: 20.0000 - val_true_positives_15: 84.0000
# Epoch 7/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3809 - accuracy: 0.8413 - precision_15: 0.8289 - recall_15: 0.8561 - auc_30: 0.9089 - auc_31: 0.8986 - true_negatives_15: 334.0000 - false_positives_15: 70.0000 - false_negatives_15: 57.0000 - true_positives_15: 339.0000 - val_loss: 0.4421 - val_accuracy: 0.8150 - val_precision_15: 0.8454 - val_recall_15: 0.7885 - val_auc_30: 0.8876 - val_auc_31: 0.8950 - val_true_negatives_15: 81.0000 - val_false_positives_15: 15.0000 - val_false_negatives_15: 22.0000 - val_true_positives_15: 82.0000
# Epoch 8/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3642 - accuracy: 0.8575 - precision_15: 0.8507 - recall_15: 0.8636 - auc_30: 0.9171 - auc_31: 0.9094 - true_negatives_15: 344.0000 - false_positives_15: 60.0000 - false_negatives_15: 54.0000 - true_positives_15: 342.0000 - val_loss: 0.4331 - val_accuracy: 0.8150 - val_precision_15: 0.8317 - val_recall_15: 0.8077 - val_auc_30: 0.8886 - val_auc_31: 0.8959 - val_true_negatives_15: 79.0000 - val_false_positives_15: 17.0000 - val_false_negatives_15: 20.0000 - val_true_positives_15: 84.0000
# Epoch 9/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3558 - accuracy: 0.8562 - precision_15: 0.8504 - recall_15: 0.8611 - auc_30: 0.9201 - auc_31: 0.9107 - true_negatives_15: 344.0000 - false_positives_15: 60.0000 - false_negatives_15: 55.0000 - true_positives_15: 341.0000 - val_loss: 0.4354 - val_accuracy: 0.8200 - val_precision_15: 0.8469 - val_recall_15: 0.7981 - val_auc_30: 0.8901 - val_auc_31: 0.8974 - val_true_negatives_15: 81.0000 - val_false_positives_15: 15.0000 - val_false_negatives_15: 21.0000 - val_true_positives_15: 83.0000
# Epoch 10/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3407 - accuracy: 0.8550 - precision_15: 0.8415 - recall_15: 0.8712 - auc_30: 0.9276 - auc_31: 0.9190 - true_negatives_15: 339.0000 - false_positives_15: 65.0000 - false_negatives_15: 51.0000 - true_positives_15: 345.0000 - val_loss: 0.4304 - val_accuracy: 0.8150 - val_precision_15: 0.8384 - val_recall_15: 0.7981 - val_auc_30: 0.8909 - val_auc_31: 0.8986 - val_true_negatives_15: 80.0000 - val_false_positives_15: 16.0000 - val_false_negatives_15: 21.0000 - val_true_positives_15: 83.0000
# Epoch 11/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3407 - accuracy: 0.8625 - precision_15: 0.8575 - recall_15: 0.8662 - auc_30: 0.9278 - auc_31: 0.9218 - true_negatives_15: 347.0000 - false_positives_15: 57.0000 - false_negatives_15: 53.0000 - true_positives_15: 343.0000 - val_loss: 0.4261 - val_accuracy: 0.8350 - val_precision_15: 0.8318 - val_recall_15: 0.8558 - val_auc_30: 0.8923 - val_auc_31: 0.8996 - val_true_negatives_15: 78.0000 - val_false_positives_15: 18.0000 - val_false_negatives_15: 15.0000 - val_true_positives_15: 89.0000
# Epoch 12/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3357 - accuracy: 0.8737 - precision_15: 0.8678 - recall_15: 0.8788 - auc_30: 0.9307 - auc_31: 0.9253 - true_negatives_15: 351.0000 - false_positives_15: 53.0000 - false_negatives_15: 48.0000 - true_positives_15: 348.0000 - val_loss: 0.4384 - val_accuracy: 0.8250 - val_precision_15: 0.8791 - val_recall_15: 0.7692 - val_auc_30: 0.8936 - val_auc_31: 0.9023 - val_true_negatives_15: 85.0000 - val_false_positives_15: 11.0000 - val_false_negatives_15: 24.0000 - val_true_positives_15: 80.0000
# Epoch 13/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3226 - accuracy: 0.8725 - precision_15: 0.8657 - recall_15: 0.8788 - auc_30: 0.9357 - auc_31: 0.9309 - true_negatives_15: 350.0000 - false_positives_15: 54.0000 - false_negatives_15: 48.0000 - true_positives_15: 348.0000 - val_loss: 0.4317 - val_accuracy: 0.8300 - val_precision_15: 0.8646 - val_recall_15: 0.7981 - val_auc_30: 0.8935 - val_auc_31: 0.9017 - val_true_negatives_15: 83.0000 - val_false_positives_15: 13.0000 - val_false_negatives_15: 21.0000 - val_true_positives_15: 83.0000
# Epoch 14/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8612 - precision_15: 0.8554 - recall_15: 0.8662 - auc_30: 0.9339 - auc_31: 0.9272 - true_negatives_15: 346.0000 - false_positives_15: 58.0000 - false_negatives_15: 53.0000 - true_positives_15: 343.0000Restoring model weights from the end of the best epoch: 11.
# 25/25 [==============================] - 38s 2s/step - loss: 0.3265 - accuracy: 0.8612 - precision_15: 0.8554 - recall_15: 0.8662 - auc_30: 0.9339 - auc_31: 0.9272 - true_negatives_15: 346.0000 - false_positives_15: 58.0000 - false_negatives_15: 53.0000 - true_positives_15: 343.0000 - val_loss: 0.4282 - val_accuracy: 0.8500 - val_precision_15: 0.8854 - val_recall_15: 0.8173 - val_auc_30: 0.8958 - val_auc_31: 0.9044 - val_true_negatives_15: 85.0000 - val_false_positives_15: 11.0000 - val_false_negatives_15: 19.0000 - val_true_positives_15: 85.0000
# Epoch 14: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4261 - accuracy: 0.8350 - precision_15: 0.8318 - recall_15: 0.8558 - auc_30: 0.8923 - auc_31: 0.8996 - true_negatives_15: 78.0000 - false_positives_15: 18.0000 - false_negatives_15: 15.0000 - true_positives_15: 89.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GLOBALAVGPOOL+DENSE80
# Epochs: 80
# Test Accuracy: 0.8349999785423279
# Test Loss: 0.42607495188713074
# Validation Accuracy: 0.8500000238418579
# Validation Loss: 0.4281971752643585
# Precision: 0.8317757009345794
# Recall: 0.8557692307692307
# AUC-ROC: 0.8341346153846154
# AUC-PR: 0.8812724658519051
# True Negatives: 78.0
# False Positives: 18.0
# False Negatives: 15.0
# True Positives: 89.0
# Error Rate: 0.4986
# F1 Score: 0.8436018957345972
# Cohen's Kappa: 0.6690734055354994
# Matthews Correlation Coefficient: 0.6693763874193654
# Balanced Accuracy: 0.8341346153846154
# Time Taken (seconds): 546.7190899848938

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define new model architecture with VGG16
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Global average pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=100, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+GLOBALAVGPOOL+DENSE100',
    'Epochs': 100,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+GLOBALAVGPOOL+DENSE100_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model3_100_Epochs Training History")
plt.show()
# Out:
# Epoch 1/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.5938 - accuracy: 0.6963 - precision_16: 0.6852 - recall_16: 0.7146 - auc_32: 0.7468 - auc_33: 0.7369 - true_negatives_16: 274.0000 - false_positives_16: 130.0000 - false_negatives_16: 113.0000 - true_positives_16: 283.0000 - val_loss: 0.5553 - val_accuracy: 0.7200 - val_precision_16: 0.8529 - val_recall_16: 0.5577 - val_auc_32: 0.8589 - val_auc_33: 0.8609 - val_true_negatives_16: 86.0000 - val_false_positives_16: 10.0000 - val_false_negatives_16: 46.0000 - val_true_positives_16: 58.0000
# Epoch 2/100
# 25/25 [==============================] - 38s 2s/step - loss: 0
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8637 - precision_16: 0.8561 - recall_16: 0.8712 - auc_32: 0.9311 - auc_33: 0.9275 - true_negatives_16: 346.0000 - false_positives_16: 58.0000 - false_negatives_16: 51.0000 - true_positives_16: 345.0000Restoring model weights from the end of the best epoch: 10.
# 25/25 [==============================] - 38s 2s/step - loss: 0.3329 - accuracy: 0.8637 - precision_16: 0.8561 - recall_16: 0.8712 - auc_32: 0.9311 - auc_33: 0.9275 - true_negatives_16: 346.0000 - false_positives_16: 58.0000 - false_negatives_16: 51.0000 - true_positives_16: 345.0000 - val_loss: 0.4324 - val_accuracy: 0.8150 - val_precision_16: 0.8526 - val_recall_16: 0.7788 - val_auc_32: 0.8936 - val_auc_33: 0.9037 - val_true_negatives_16: 82.0000 - val_false_positives_16: 14.0000 - val_false_negatives_16: 23.0000 - val_true_positives_16: 81.0000
# Epoch 13: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4302 - accuracy: 0.8200 - precision_16: 0.8333 - recall_16: 0.8173 - auc_32: 0.8902 - auc_33: 0.9004 - true_negatives_16: 79.0000 - false_positives_16: 17.0000 - false_negatives_16: 19.0000 - true_positives_16: 85.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GLOBALAVGPOOL+DENSE100
# Epochs: 100
# Test Accuracy: 0.8199999928474426
# Test Loss: 0.4302043914794922
# Validation Accuracy: 0.8149999976158142
# Validation Loss: 0.4324367940425873
# Precision: 0.8333333333333334
# Recall: 0.8173076923076923
# AUC-ROC: 0.8201121794871794
# AUC-PR: 0.8728205128205129
# True Negatives: 79.0
# False Positives: 17.0
# False Negatives: 19.0
# True Positives: 85.0
# Error Rate: 0.4996
# F1 Score: 0.8252427184466019
# Cohen's Kappa: 0.6397117694155324
# Matthews Correlation Coefficient: 0.6398399552417305
# Balanced Accuracy: 0.8201121794871795
# Time Taken (seconds): 508.7335124015808

# %% [markdown]
# # VGG16 (A) + Conv2D + GlobalAveragePooling2D +Dropout+ Dense Layers (B):
# Base Model (A): VGG16  pre-trained on ImageNet.
# Main Model (B): Conv2D layer, GlobalAveragePooling2D layer, and dense layers for classification.
# Explanation: VGG16 extracts features, Conv2D further processes features, GlobalAveragePooling2D reduces dimensions, and dense layers classify images.

# %% [markdown]
# # Conv2D
# The Conv2D layer in a convolutional neural network (CNN) is used for applying convolutional operations to the input data. It performs a 2D convolution over an input image, which involves sliding a small window (kernel) over the input image and performing element-wise multiplication with the kernel weights. This operation helps in extracting features from the input image.
#
# In the modified model, the Conv2D layer is used after the base ResNet-50 model to further process the features extracted by ResNet-50. It helps in learning higher-level features from the lower-level features extracted by the base model, which can improve the model's performance in classification tasks.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define custom CNN architecture with VGG16 and additional layers
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=20, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+Conv2D+GLOBALAVGPOOL+DENSE20',
    'Epochs': 20,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+Conv2D+GLOBALAVGPOOL+DENSE20_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("
# 25/25 [==============================] - 38s 2s/step - loss: 0.3567 - accuracy: 0.8537 - precision_18: 0.8462 - recall_18: 0.8611 - auc_36: 0.9233 - auc_37: 0.9187 - true_negatives_18: 342.0000 - false_positives_18: 62.0000 - false_negatives_18: 55.0000 - true_positives_18: 341.0000 - val_loss: 0.4267 - val_accuracy: 0.8350 - val_precision_18: 0.8447 - val_recall_18: 0.8365 - val_auc_36: 0.9030 - val_auc_37: 0.9179 - val_true_negatives_18: 80.0000 - val_false_positives_18: 16.0000 - val_false_negatives_18: 17.0000 - val_true_positives_18: 87.0000
# Epoch 11: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4170 - accuracy: 0.8450 - precision_18: 0.8476 - recall_18: 0.8558 - auc_36: 0.8988 - auc_37: 0.9111 - true_negatives_18: 80.0000 - false_positives_18: 16.0000 - false_negatives_18: 15.0000 - true_positives_18: 89.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+Conv2D+GLOBALAVGPOOL+DENSE20
# Epochs: 20
# Test Accuracy: 0.8450000286102295
# Test Loss: 0.4170018434524536
# Validation Accuracy: 0.8349999785423279
# Validation Loss: 0.42665234208106995
# Precision: 0.8476190476190476
# Recall: 0.8557692307692307
# AUC-ROC: 0.844551282051282
# AUC-PR: 0.8891941391941391
# True Negatives: 80.0
# False Positives: 16.0
# False Negatives: 15.0
# True Positives: 89.0
# Error Rate: 0.499
# F1 Score: 0.8516746411483254
# Cohen's Kappa: 0.6893787575150301
# Matthews Correlation Coefficient: 0.6894133673495639
# Balanced Accuracy: 0.844551282051282
# Time Taken (seconds): 423.53343534469604

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define custom CNN architecture with VGG16 and additional layers
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=40, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+Conv2D+GLOBALAVGPOOL+DENSE40',
    'Epochs': 40,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+Conv2D+GLOBALAVGPOOL+DENSE40_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model4_40_Epochs Training History")
plt.show()
# Out:
# Epoch 1/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.6321 - accuracy: 0.6350 - precision_19: 0.6340 - recall_19: 0.6212 - auc_38: 0.6979 - auc_39: 0.6847 - true_negatives_19: 262.0000 - false_positives_19: 142.0000 - false_negatives_19: 150.0000 - true_positives_19: 246.0000 - val_loss: 0.6762 - val_accuracy: 0.6050 - val_precision_19: 0.9310 - val_recall_19: 0.2596 - val_auc_38: 0.8494 - val_auc_39: 0.8559 - val_true_negatives_19: 94.0000 - val_false_positives_19: 2.0000 - val_false_negatives_19: 77.0000 - val_true_positives_19: 27.0000
# Epoch 2/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.4767 - accuracy: 0.7750 - precision_19: 0.7812 - recall_19: 0.7576 - auc_38: 0.8557 - auc_39: 0.8327 - true_negatives_19: 320.0000 - false_positives_19: 84.0000 - false_negatives_19: 96.0000 - true_positives_19: 300.0000 - val_loss: 0.5990 - val_accuracy: 0.7000 - val_precision_19: 0.8793 - val_recall_19: 0.4904 - val_auc_38: 0.8731 - val_auc_39: 0.8823 - val_true_negatives_19: 89.0000 - val_false_positives_19: 7.0000 - val_false_negatives_19: 53.0000 - val_true_positives_19: 51.0000
# Epoch 3/40
# 25/25 [==============================] - 38s 2s/step - loss: 0
early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4252 - accuracy: 0.8100 - precision_19: 0.8056 - recall_19: 0.8365 - auc_38: 0.8889 - auc_39: 0.9013 - true_negatives_19: 75.0000 - false_positives_19: 21.0000 - false_negatives_19: 17.0000 - true_positives_19: 87.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+Conv2D+GLOBALAVGPOOL+DENSE40
# Epochs: 40
# Test Accuracy: 0.8100000023841858
# Test Loss: 0.42519041895866394
# Validation Accuracy: 0.8199999928474426
# Validation Loss: 0.4386056661605835
# Precision: 0.8055555555555556
# Recall: 0.8365384615384616
# AUC-ROC: 0.8088942307692308
# AUC-PR: 0.8635470085470086
# True Negatives: 75.0
# False Positives: 21.0
# False Negatives: 17.0
# True Positives: 87.0
# Error Rate: 0.4984
# F1 Score: 0.8207547169811321
# Cohen's Kappa: 0.6187800963081862
# Matthews Correlation Coefficient: 0.619278906313849
# Balanced Accuracy: 0.8088942307692308
# Time Taken (seconds): 282.5400273799896

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define custom CNN architecture with VGG16 and additional layers
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=60, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+Conv2D+GLOBALAVGPOOL+DENSE60',
    'Epochs': 60,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+Conv2D+GLOBALAVGPOOL+DENSE60_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model4_60_Epochs Training History")
plt.show()
# Out:
# Epoch 1/60
# 25/25 [==============================] - 33s 1s/step - loss: 0.6215 - accuracy: 0.6587 - precision_22: 0.6732 - recall_22: 0.6035 - auc_44: 0.7096 - auc_45: 0.7092 - true_negatives_22: 288.0000 - false_positives_22: 116.0000 - false_negatives_22: 157.0000 - true_positives_22: 239.0000 - val_loss: 0.5811 - val_accuracy: 0.6850 - val_precision_22: 0.8596 - val_recall_22: 0.4712 - val_auc_44: 0.8588 - val_auc_45: 0.8710 - val_true_negatives_22: 88.0000 - val_false_positives_22: 8.0000 - val_false_negatives_22: 55.0000 - val_true_positives_22: 49.0000
# Epoch 2/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.4560 - accuracy: 0.7962 - precision_22: 0.7949 - recall_22: 0.7929 - auc_44: 0.8686 - auc_45: 0.8601 - true_negatives_22: 323.0000 - false_positives_22: 81.0000 - false_negatives_22: 82.0000 - true_positives_22: 314.0000 - val_loss: 0.5550 - val_accuracy: 0.7400 - val_precision_22: 0.8824 - val_recall_22: 0.5769 - val_auc_44: 0.8752 - val_auc_45: 0.8864 - val_true_negatives_22: 88.0000 - val_false_positives_22: 8.0000 - val_false_negatives_22: 44.0000 - val_true_positives_22: 60.0000
# Epoch 3/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.4289 - accuracy: 0.8087 - precision_22: 0.7985 - recall_22: 0.8207 - auc_44: 0.8878 - auc_45: 0.8806 - true_negatives_22: 322.0000 - false_positives_22: 82.0000 - false_negatives_22: 71.0000 - true_positives_22: 325.0000 - val_loss: 0.4425 - val_accuracy: 0.8150 - val_precision_22: 0.8454 - val_recall_22: 0.7885 - val_auc_44: 0.8815 - val_auc_45: 0.8943 - val_true_negatives_22: 81.0000 - val_false_positives_22: 15.0000 - val_false_negatives_22: 22.0000 - val_true_positives_22: 82.0000
# Epoch 4/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.4228 - accuracy: 0.8425 - precision_22: 0.8358 - recall_22: 0.8485 - auc_44: 0.8918 - auc_45: 0.8699 - true_negatives_22: 338.0000 - false_positives_22: 66.0000 - false_negatives_22: 60.0000 - true_positives_22: 336.0000 - val_loss: 0.4279 - val_accuracy: 0.8100 - val_precision_22: 0.8300 - val_recall_22: 0.7981 - val_auc_44: 0.8903 - val_auc_45: 0.9040 - val_true_negatives_22: 79.0000 - val_false_positives_22: 17.0000 - val_false_negatives_22: 21.0000 - val_true_positives_22: 83.0000
# Epoch 5/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.4097 - accuracy: 0.8288 - precision_22: 0.8120 - recall_22: 0.8510 - auc_44: 0.8979 - auc_45: 0.8883 - true_negatives_22: 326.0000 - false_positives_22: 78.0000 - false_negatives_22: 59.0000 - true_positives_22: 337.0000 - val_loss: 0.4434 - val_accuracy: 0.8050 - val_precision_22: 0.8495 - val_recall_22: 0.7596 - val_auc_44: 0.8936 - val_auc_45: 0.9081 - val_true_negatives_22: 82.0000 - val_false_positives_22: 14.0000 - val_false_negatives_22: 25.0000 - val_true_positives_22: 79.0000
# Epoch 6/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3884 - accuracy: 0.8325 - precision_22: 0.8195 - recall_22: 0.8485 - auc_44: 0.9062 - auc_45: 0.9004 - true_negatives_22: 330.0000 - false_positives_22: 74.0000 - false_negatives_22: 60.0000 - true_positives_22: 336.0000 - val_loss: 0.4163 - val_accuracy: 0.8300 - val_precision_22: 0.8365 - val_recall_22: 0.8365 - val_auc_44: 0.8948 - val_auc_45: 0.9110 - val_true_negatives_22: 79.0000 - val_false_positives_22: 17.0000 - val_false_negatives_22: 17.0000 - val_true_positives_22: 87.0000
# Epoch 7/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3626 - accuracy: 0.8462 - precision_22: 0.8404 - recall_22: 0.8510 - auc_44: 0.9196 - auc_45: 0.9182 - true_negatives_22: 340.0000 - false_positives_22: 64.0000 - false_negatives_22: 59.0000 - true_positives_22: 337.0000 - val_loss: 0.4162 - val_accuracy: 0.8400 - val_precision_22: 0.8273 - val_recall_22: 0.8750 - val_auc_44: 0.8967 - val_auc_45: 0.9116 - val_true_negatives_22: 77.0000 - val_false_positives_22: 19.0000 - val_false_negatives_22: 13.0000 - val_true_positives_22: 91.0000
# Epoch 8/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3495 - accuracy: 0.8550 - precision_22: 0.8500 - recall_22: 0.8586 - auc_44: 0.9256 - auc_45: 0.9145 - true_negatives_22: 344.0000 - false_positives_22: 60.0000 - false_negatives_22: 56.0000 - true_positives_22: 340.0000 - val_loss: 0.4101 - val_accuracy: 0.8350 - val_precision_22: 0.8447 - val_recall_22: 0.8365 - val_auc_44: 0.9028 - val_auc_45: 0.9195 - val_true_negatives_22: 80.0000 - val_false_positives_22: 16.0000 - val_false_negatives_22: 17.0000 - val_true_positives_22: 87.0000
# Epoch 9/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3283 - accuracy: 0.8637 - precision_22: 0.8475 - recall_22: 0.8838 - auc_44: 0.9355 - auc_45: 0.9330 - true_negatives_22: 341.0000 - false_positives_22: 63.0000 - false_negatives_22: 46.0000 - true_positives_22: 350.0000 - val_loss: 0.4021 - val_accuracy: 0.8300 - val_precision_22: 0.8431 - val_recall_22: 0.8269 - val_auc_44: 0.9044 - val_auc_45: 0.9224 - val_true_negatives_22: 80.0000 - val_false_positives_22: 16.0000 - val_false_negatives_22: 18.0000 - val_true_positives_22: 86.0000
# Epoch 10/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3417 - accuracy: 0.8537 - precision_22: 0.8378 - recall_22: 0.8737 - auc_44: 0.9303 - auc_45: 0.9323 - true_negatives_22: 337.0000 - false_positives_22: 67.0000 - false_negatives_22: 50.0000 - true_positives_22: 346.0000 - val_loss: 0.4154 - val_accuracy: 0.8300 - val_precision_22: 0.8431 - val_recall_22: 0.8269 - val_auc_44: 0.9022 - val_auc_45: 0.9193 - val_true_negatives_22: 80.0000 - val_false_positives_22: 16.0000 - val_false_negatives_22: 18.0000 - val_true_positives_22: 86.0000
# Epoch 11/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3131 - accuracy: 0.8662 - precision_22: 0.8568 - recall_22: 0.8763 - auc_44: 0.9399 - auc_45: 0.9429 - true_negatives_22: 346.0000 - false_positives_22: 58.0000 - false_negatives_22: 49.0000 - true_positives_22: 347.0000 - val_loss: 0.4100 - val_accuracy: 0.8350 - val_precision_22: 0.8515 - val_recall_22: 0.8269 - val_auc_44: 0.9057 - val_auc_45: 0.9233 - val_true_negatives_22: 81.0000 - val_false_positives_22: 15.0000 - val_false_negatives_22: 18.0000 - val_true_positives_22: 86.0000
# Epoch 12/60
# 25/25 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.8662 - precision_22: 0.8586 - recall_22: 0.8737 - auc_44: 0.9364 - auc_45: 0.9320 - true_negatives_22: 347.0000 - false_positives_22: 57.0000 - false_negatives_22: 50.0000 - true_positives_22: 346.0000Restoring model weights from the end of the best epoch: 9.
# 25/25 [==============================] - 38s 2s/step - loss: 0.3244 - accuracy: 0.8662 - precision_22: 0.8586 - recall_22: 0.8737 - auc_44: 0.9364 - auc_45: 0.9320 - true_negatives_22: 347.0000 - false_positives_22: 57.0000 - false_negatives_22: 50.0000 - true_positives_22: 346.0000 - val_loss: 0.4211 - val_accuracy: 0.8450 - val_precision_22: 0.8763 - val_recall_22: 0.8173 - val_auc_44: 0.9067 - val_auc_45: 0.9248 - val_true_negatives_22: 84.0000 - val_false_positives_22: 12.0000 - val_false_negatives_22: 19.0000 - val_true_positives_22: 85.0000
# Epoch 12: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.4021 - accuracy: 0.8300 - precision_22: 0.8431 - recall_22: 0.8269 - auc_44: 0.9044 - auc_45: 0.9224 - true_negatives_22: 80.0000 - false_positives_22: 16.0000 - false_negatives_22: 18.0000 - true_positives_22: 86.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+Conv2D+GLOBALAVGPOOL+DENSE60
# Epochs: 60
# Test Accuracy: 0.8299999833106995
# Test Loss: 0.4021117091178894
# Validation Accuracy: 0.8450000286102295
# Validation Loss: 0.42110052704811096
# Precision: 0.8431372549019608
# Recall: 0.8269230769230769
# AUC-ROC: 0.8301282051282051
# AUC-PR: 0.8800301659125188
# True Negatives: 80.0
# False Positives: 16.0
# False Negatives: 18.0
# True Positives: 86.0
# Error Rate: 0.4996
# F1 Score: 0.8349514563106796
# Cohen's Kappa: 0.6597277822257807
# Matthews Correlation Coefficient: 0.6598599788725732
# Balanced Accuracy: 0.8301282051282051
# Time Taken (seconds): 466.90919947624207

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define custom CNN architecture with VGG16 and additional layers
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=80, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+Conv2D+GLOBALAVGPOOL+DENSE80',
    'Epochs': 80,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+Conv2D+GLOBALAVGPOOL+DENSE80_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model4_80_Epochs Training History")
plt.show()
# Out:
# Epoch 1/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.6523 - accuracy: 0.6237 - precision_23: 0.6221 - recall_23: 0.6111 - auc_46: 0.6680 - auc_47: 0.6408 - true_negatives_23: 257.0000 - false_positives_23: 147.0000 - false_negatives_23: 154.0000 - true_positives_23: 242.0000 - val_loss: 0.6114 - val_accuracy: 0.6400 - val_precision_23: 0.9000 - val_recall_23: 0.3462 - val_auc_46: 0.8519 - val_auc_47: 0.8572 - val_true_negatives_23: 92.0000 - val_false_positives_23: 4.0000 - val_false_negatives_23: 68.0000 - val_true_positives_23: 36.0000
# Epoch 2/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.4978 - accuracy: 0.7650 - precision_23: 0.7708 - recall_23: 0.7475 - auc_46: 0.8434 - auc_47: 0.8235 - true_negatives_23: 316.0000 - false_positives_23: 88.0000 - false_negatives_23: 100.0000 - true_positives_23: 296.0000 - val_loss: 0.5683 - val_accuracy: 0.7200 - val_precision_23: 0.8636 - val_recall_23: 0.5481 - val_auc_46: 0.8711 - val_auc_47: 0.8794 - val_true_negatives_23: 87.0000 - val_false_positives_23: 9.0000 - val_false_negatives_23: 47.0000 - val_true_positives_23: 57.0000
# Epoch 3/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.4523 - accuracy: 0.8012 - precision_23: 0.7897 - recall_23: 0.8157 - auc_46: 0.8711 - auc_47: 0.8573 - true_negatives_23: 318.0000 - false_positives_23: 86.0000 - false_negatives_23: 73.0000 - true_positives_23: 323.0000 - val_loss: 0.4508 - val_accuracy: 0.8150 - val_precision_23: 0.8384 - val_recall_23: 0.7981 - val_auc_46: 0.8780 - val_auc_47: 0.8874 - val_true_negatives_23: 80.0000 - val_false_positives_23: 16.0000 - val_false_negatives_23: 21.0000 - val_true_positives_23: 83.0000
# Epoch 4/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.4135 - accuracy: 0.8275 - precision_23: 0.8258 - recall_23: 0.8258 - auc_46: 0.8953 - auc_47: 0.8740 - true_negatives_23: 335.0000 - false_positives_23: 69.0000 - false_negatives_23: 69.0000 - true_positives_23: 327.0000 - val_loss: 0.4318 - val_accuracy: 0.8000 - val_precision_23: 0.8019 - val_recall_23: 0.8173 - val_auc_46: 0.8860 - val_auc_47: 0.8969 - val_true_negatives_23: 75.0000 - val_false_positives_23: 21.0000 - val_false_negatives_23: 19.0000 - val_true_positives_23: 85.0000
# Epoch 5/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.4022 - accuracy: 0.8288 - precision_23: 0.8106 - recall_23: 0.8535 - auc_46: 0.9026 - auc_47: 0.8944 - true_negatives_23: 325.0000 - false_positives_23: 79.0000 - false_negatives_23: 58.0000 - true_positives_23: 338.0000 - val_loss: 0.4416 - val_accuracy: 0.8200 - val_precision_23: 0.8617 - val_recall_23: 0.7788 - val_auc_46: 0.8907 - val_auc_47: 0.9032 - val_true_negatives_23: 83.0000 - val_false_positives_23: 13.0000 - val_false_negatives_23: 23.0000 - val_true_positives_23: 81.0000
# Epoch 6/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.
# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()
# Assume X_train and y_train are the original splits
# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define custom CNN architecture with VGG16 and additional layers
model = Sequential([
    base_model,
    Conv2D(64, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=100, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+Conv2D+GLOBALAVGPOOL+DENSE100',
    'Epochs': 100,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+Conv2D+GLOBALAVGPOOL+DENSE100_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model4_100_Epochs Training History")
plt.show()
# Out:
# 2024-03-21 16:08:54.323902: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-21 16:08:54.520337: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-21 16:08:54.520357: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-21 16:08:54.521401: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-21 16:08:54.611961: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-21 16:08:55.273664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/100
# 25/25 [==============================] - 31s 1s/step - loss: 0.6622 - accuracy: 0.5962 - precision: 0.6357 - recall: 0.4318 - auc: 0.6571 - auc_1: 0.6048 - true_negatives: 306.0000 - false_positives: 98.0000 - false_negatives: 225.0000 - true_positives: 171.0000 - val_loss: 0.6133 - val_accuracy: 0.6100 - val_precision: 0.8824 - val_recall: 0.2885 - val_auc: 0.8559 - val_auc_1: 0.8612 - val_true_negatives: 92.0000 - val_false_positives: 4.0000 - val_false_negatives: 74.0000 - val_true_positives: 30.0000
# Epoch 2/100
# 25/25 [==============================] - 34s 1s/step - loss: 0.4947 - accuracy: 0.7600 - precision: 0.7642 - recall: 0.7449 - auc: 0.8451 - auc_1: 0.8203 - true_negatives: 313.0000 - false_positives: 91.0000 - false_negatives: 101.0000 - true_positives: 295.0000 - val_loss: 0.5130 - val_accuracy: 0.7850 - val_precision: 0.8765 - val_recall: 0.6827 - val_auc: 0.8656 - val_auc_1: 0.8711 - val_true_negatives: 86.0000 - val_false_positives: 10.0000 - val_false_negatives: 33.0000 - val_true_positives: 71.0000
# Epoch 3/100
# 25/25 [==============================] - 37s 1s/step - loss: 0.4546 - accuracy: 0.7862 - precision: 0.7792 - recall: 0.7929 - auc: 0.8661 - auc_1: 0.8453 - true_negatives: 315.0000 - false_positives: 89.0000 - false_negatives: 82.0000 - true_positives: 314.0000 - val_loss: 0.5720 - val_accuracy: 0.7200 - val_precision: 0.8871 - val_recall: 0.5288 - val_auc: 0.8793 - val_auc_1: 0.8866 - val_true_negatives: 89.0000 - val_false_positives: 7.0000 - val_false_negatives: 49.0000 - val_true_positives: 55.0000
# Epoch 4/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.4304 - accuracy: 0.8200 - precision: 0.8103 - recall: 0.8308 - auc: 0.8872 - auc_1: 0.8827 - true_negatives: 327.0000 - false_positives: 77.0000 - false_negatives: 67.0000 - true_positives: 329.0000 - val_loss: 0.4387 - val_accuracy: 0.8050 - val_precision: 0.8218 - val_recall: 0.7981 - val_auc: 0.8832 - val_auc_1: 0.8904 - val_true_negatives: 78.0000 - val_false_positives: 18.0000 - val_false_negatives: 21.0000 - val_true_positives: 83.0000
# Epoch 5/100
# 25/25 [==============================] - 37s 2s/step - loss: 0.3946 - accuracy: 0.8338 - precision: 0.8215 - recall: 0.8485 - auc: 0.9017 - auc_1: 0.8856 - true_negatives: 331.0000 - false_positives: 73.0000 - false_negatives: 60.0000 - true_positives: 336.0000 - val_loss: 0.4251 - val_accuracy: 0.8150 - val_precision: 0.8131 - val_recall: 0.8365 - val_auc: 0.8902 - val_auc_1: 0.8998 - val_true_negatives: 76.0000 - val_false_positives: 20.0000 - val_false_negatives: 17.0000 - val_true_positives: 87.0000
# Epoch 6/100
# 25/25 [==============================] - 37s 2s/step - loss: 0.4111 - accuracy: 0.8225 - precision: 0.8038 - recall: 0.8485 - auc: 0.8959 - auc_1: 0.8886 - true_negatives: 322.0000 - false_positives: 82.0000 - false_negatives: 60.0000 - true_positives: 336.0000 - val_loss: 0.4262 - val_accuracy: 0.8150 - val_precision: 0.8190 - val_recall: 0.8269 - val_auc: 0.8945 - val_auc_1: 0.9062 - val_true_negatives: 77.0000 - val_false_positives: 19.0000 - val_false_negatives: 18.0000 - val_true_positives: 86.0000
# Epoch 7/100
# 25/25 [==============================] - 37s 2s/step - loss: 0.3777 - accuracy: 0.8612 - precision: 0.8450 - recall: 0.8813 - auc: 0.9129 - auc_1: 0.9050 - true_negatives: 340.0000 - false_positives: 64.0000 - false_negatives: 47.0000 - true_positives: 349.0000 - val_loss: 0.4227 - val_accuracy: 0.8250 - val_precision: 0.8224 - val_recall: 0.8462 - val_auc: 0.8944 - val_auc_1: 0.9068 - val_true_negatives: 77.0000 - val_false_positives: 19.0000 - val_false_negatives: 16.0000 - val_true_positives: 88.0000
# Epoch 8/100
# 25/25 [==============================] - 37s 2s/step - loss: 0.3504 - accuracy: 0.8475 - precision: 0.8425 - recall: 0.8510 - auc: 0.9240 - auc_1: 0.9203 - true_negatives: 341.0000 - false_positives: 63.0000 - false_negatives: 59.0000 - true_positives: 337.0000 - val_loss: 0.4179 - val_accuracy: 0.8250 - val_precision: 0.8108 - val_recall: 0.8654 - val_auc: 0.9013 - val_auc_1: 0.9137 - val_true_negatives: 75.0000 - val_false_positives: 21.0000 - val_false_negatives: 14.0000 - val_true_positives: 90.0000
# Epoch 9/100
# 25/25 [==============================] - 37s 2s/step - loss: 0.3637 - accuracy: 0.8438 - precision: 0.8129 - recall: 0.8889 - auc: 0.9201 - auc_1: 0.9119 - true_negatives: 323.0000 - false_positives: 81.0000 - false_negatives: 44.0000 - true_positives: 352.0000 - val_loss: 0.4236 - val_accuracy: 0.8250 - val_precision: 0.8350 - val_recall: 0.8269 - val_auc: 0.9018 - val_auc_1: 0.9150 - val_true_negatives: 79.0000 - val_false_positives: 17.0000 - val_false_negatives: 18.0000 - val_true_positives: 86.0000
# Epoch 10/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.3365 - accuracy: 0.8600 - precision: 0.8515 - recall: 0.8687 - auc: 0.9300 - auc_1: 0.9268 - true_negatives: 344.0000 - false_positives: 60.0000 - false_negatives: 52.0000 - true_positives: 344.0000 - val_loss: 0.4192 - val_accuracy: 0.8350 - val_precision: 0.8381 - val_recall: 0.8462 - val_auc: 0.9023 - val_auc_1: 0.9173 - val_true_negatives: 79.0000 - val_false_positives: 17.0000 - val_false_negatives: 16.0000 - val_true_positives: 88.0000
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8637 - precision: 0.8543 - recall: 0.8737 - auc: 0.9381 - auc_1: 0.9348 - true_negatives: 345.0000 - false_positives: 59.0000 - false_negatives: 50.0000 - true_positives: 346.0000Restoring model weights from the end of the best epoch: 8.
# 25/25 [==============================] - 37s 2s/step - loss: 0.3155 - accuracy: 0.8637 - precision: 0.8543 - recall: 0.8737 - auc: 0.9381 - auc_1: 0.9348 - true_negatives: 345.0000 - false_positives: 59.0000 - false_negatives: 50.0000 - true_positives: 346.0000 - val_loss: 0.4339 - val_accuracy: 0.8400 - val_precision: 0.8673 - val_recall: 0.8173 - val_auc: 0.9045 - val_auc_1: 0.9176 - val_true_negatives: 83.0000 - val_false_positives: 13.0000 - val_false_negatives: 19.0000 - val_true_positives: 85.0000
# Epoch 11: early stopping
# 7/7 [==============================] - 7s 1s/step - loss: 0.4179 - accuracy: 0.8250 - precision: 0.8108 - recall: 0.8654 - auc: 0.9013 - auc_1: 0.9137 - true_negatives: 75.0000 - false_positives: 21.0000 - false_negatives: 14.0000 - true_positives: 90.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+Conv2D+GLOBALAVGPOOL+DENSE100
# Epochs: 100
# Test Accuracy: 0.824999988079071
# Test Loss: 0.41792580485343933
# Validation Accuracy: 0.8399999737739563
# Validation Loss: 0.4338908791542053
# Precision: 0.8108108108108109
# Recall: 0.8653846153846154
# AUC-ROC: 0.8233173076923077
# AUC-PR: 0.8730977130977132
# True Negatives: 75.0
# False Positives: 21.0
# False Negatives: 14.0
# True Positives: 90.0
# Error Rate: 0.4978
# F1 Score: 0.8372093023255814
# Cohen's Kappa: 0.648453194053837
# Matthews Correlation Coefficient: 0.650061944841485
# Balanced Accuracy: 0.8233173076923077
# Time Taken (seconds): 417.5409097671509

# %% [markdown]
# # VGG16 (A) + LSTM + Dense Layers (B):
#
# Base Model (A): Pre-trained VGG16.
# Main Model (B): LSTM layer followed by dense layers.
# Explanation: Use the pre-trained VGG16 for feature extraction, pass the features to an LSTM layer for sequential processing, and add dense layers for classification.

# %% [markdown]
# # LSTM
#
# Long Short-Term Memory (LSTM) is a type of recurrent neural network (RNN) architecture designed to handle long-term dependencies in sequence prediction problems. Unlike traditional RNNs, which can struggle to learn and retain information over long sequences, LSTMs are capable of learning and remembering information over extended time intervals.
#
# LSTMs are particularly useful in various sequential data tasks, such as natural language processing (NLP), speech recognition, time series forecasting, and more. They are effective because they can selectively remember or forget information based on the context, thanks to their specialized architecture.
#
# The key components of an LSTM cell are:
#
# 1. **Forget Gate**: Determines which information from the previous cell state should be discarded or forgotten.
# 2. **Input Gate**: Determines which new information should be stored in the cell state.
# 3. **Cell State**: Represents the internal memory of the cell and can pass along information to future time steps.
# 4. **Output Gate**: Determines the output based on the cell state, considering the input and the memory.
#
# LSTMs are useful because they can effectively handle vanishing and exploding gradient problems often encountered in training deep neural networks. They can also capture long-range dependencies in data, making them well-suited for tasks that require understanding context over long sequences.
#
# Overall, LSTMs are a powerful tool for modeling sequential data and have been instrumental in advancing the state-of-the-art in various fields, including natural language processing, speech recognition, and more.
#
# In the context of the combination provided, using ResNet-50 as the base model and LSTM in the main model, the workflow would typically involve the following steps:
#
# 1. **Feature Extraction**: The pre-trained ResNet-50 model is used to extract features from the input images. These features represent high-level representations of the images learned by the ResNet-50 model during training on the ImageNet dataset.
#
# 2. **Sequence Modeling**: The extracted features are then passed to the LSTM layer. In this step, the LSTM layer processes the sequence of features extracted from the images. Each feature vector extracted by ResNet-50 at a particular time step is treated as an input to the LSTM. The LSTM layer processes these inputs sequentially, taking into account the temporal dependencies between them.
#
# 3. **Classification**: After processing the sequence of feature vectors using the LSTM layer, the output is passed through one or more dense layers for classification. These dense layers perform the final classification task based on the processed features. In the case of binary classification (as indicated by the use of a sigmoid activation function in the output layer), a single dense layer with a sigmoid activation function is typically used to output a probability score for the positive class.
#
# 4. **Training and Evaluation**: The model is trained using labeled data, where the input images are paired with their corresponding class labels. During training, the model learns to map input images to their correct class labels by adjusting its parameters (weights) based on the optimization of a loss function. After training, the model's performance is evaluated using a separate validation or test dataset to assess its accuracy, typically using metrics such as accuracy, precision, recall, F1 score, and area under the ROC curve (AUC).
#
# Overall, combining ResNet-50 with LSTM allows for the incorporation of both spatial and temporal information in the model, making it suitable for tasks where both aspects are relevant, such as video classification, action recognition, and sequential data analysis in domains like healthcare and finance.

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Define the input shape
input_shape = (224, 224, 3)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN base model
input_layer = Input(shape=input_shape)
vgg16_output = base_model(input_layer, training=False)
flatten = Flatten()(vgg16_output)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=20, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+LSTM+DENSE20',
    'Epochs': 20,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+LSTM+DENSE20_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model5_20_Epochs Training History")
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 40s 2s/step - loss: 0.6868 - accuracy: 0.7038 - precision_1: 0.7359 - recall_1: 0.6263 - auc_2: 0.7675 - auc_3: 0.6602 - true_negatives_1: 315.0000 - false_positives_1: 89.0000 - false_negatives_1: 148.0000 - true_positives_1: 248.0000 - val_loss: 0.6041 - val_accuracy: 0.7200 - val_precision_1: 0.9138 - val_recall_1: 0.5096 - val_auc_2: 0.8975 - val_auc_3: 0.8973 - val_true_negatives_1: 91.0000 - val_false_positives_1: 5.0000 - val_false_negatives_1: 51.0000 - val_true_positives_1: 53.0000
# Epoch 2/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.4967 - accuracy: 0.8838 - precision_1: 0.8741 - recall_1: 0.8939 - auc_2: 0.9384 - auc_3: 0.9296 - true_negatives_1: 353.0000 - false_positives_1: 51.0000 - false_negatives_1: 42.0000 - true_positives_1: 354.0000 - val_loss: 0.4880 - val_accuracy: 0.8250 - val_precision_1: 0.8966 - val_recall_1: 0.7500 - val_auc_2: 0.9176 - val_auc_3: 0.9269 - val_true_negatives_1: 87.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 26.0000 - val_true_positives_1: 78.0000
# Epoch 3/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.3732 - accuracy: 0.9175 - precision_1: 0.9104 - recall_1: 0.9242 - auc_2: 0.9658 - auc_3: 0.9633 - true_negatives_1: 368.0000 - false_positives_1: 36.0000 - false_negatives_1: 30.0000 - true_positives_1: 366.0000 - val_loss: 0.3993 - val_accuracy: 0.8600 - val_precision_1: 0.9043 - val_recall_1: 0.8173 - val_auc_2: 0.9217 - val_auc_3: 0.9355 - val_true_negatives_1: 87.0000 - val_false_positives_1: 9.0000 - val_false_negatives_1: 19.0000 - val_true_positives_1: 85.0000
# Epoch 4/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.3042 - accuracy: 0.9237 - precision_1: 0.9095 - recall_1: 0.9394 - auc_2: 0.9655 - auc_3: 0.9642 - true_negatives_1: 367.0000 - false_positives_1: 37.0000 - false_negatives_1: 24.0000 - true_positives_1: 372.0000 - val_loss: 0.4658 - val_accuracy: 0.7950 - val_precision_1: 0.9437 - val_recall_1: 0.6442 - val_auc_2: 0.9232 - val_auc_3: 0.9368 - val_true_negatives_1: 92.0000 - val_false_positives_1: 4.0000 - val_false_negatives_1: 37.0000 - val_true_positives_1: 67.0000
# Epoch 5/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.2605 - accuracy: 0.9225 - precision_1: 0.9093 - recall_1: 0.9369 - auc_2: 0.9663 - auc_3: 0.9609 - true_negatives_1: 367.0000 - false_positives_1: 37.0000 - false_negatives_1: 25.0000 - true_positives_1: 371.0000 - val_loss: 0.5418 - val_accuracy: 0.7750 - val_precision_1: 0.9683 - val_recall_1: 0.5865 - val_auc_2: 0.9174 - val_auc_3: 0.9363 - val_true_negatives_1: 94.0000 - val_false_positives_1: 2.0000 - val_false_negatives_1: 43.0000 - val_true_positives_1: 61.0000
# Epoch 6/20
# 25/25 [==============================] - ETA: 0s - loss: 0.2491 - accuracy: 0.9225 - precision_1: 0.9073 - recall_1: 0.9394 - auc_2: 0.9697 - auc_3: 0.9687 - true_negatives_1: 366.0000 - false_positives_1: 38.0000 - false_negatives_1: 24.0000 - true_positives_1: 372.0000Restoring model weights from the end of the best epoch: 3.
# 25/25 [==============================] - 39s 2s/step - loss: 0.2491 - accuracy: 0.9225 - precision_1: 0.9073 - recall_1: 0.9394 - auc_2: 0.9697 - auc_3: 0.9687 - true_negatives_1: 366.0000 - false_positives_1: 38.0000 - false_negatives_1: 24.0000 - true_positives_1: 372.0000 - val_loss: 0.4113 - val_accuracy: 0.8200 - val_precision_1: 0.9474 - val_recall_1: 0.6923 - val_auc_2: 0.9246 - val_auc_3: 0.9414 - val_true_negatives_1: 92.0000 - val_false_positives_1: 4.0000 - val_false_negatives_1: 32.0000 - val_true_positives_1: 72.0000
# Epoch 6: early stopping
# 7/7 [==============================] - 7s 1s/step - loss: 0.3993 - accuracy: 0.8600 - precision_1: 0.9043 - recall_1: 0.8173 - auc_2: 0.9217 - auc_3: 0.9355 - true_negatives_1: 87.0000 - false_positives_1: 9.0000 - false_negatives_1: 19.0000 - true_positives_1: 85.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+LSTM+DENSE20
# Epochs: 20
# Test Accuracy: 0.8600000143051147
# Test Loss: 0.39934489130973816
# Validation Accuracy: 0.8199999928474426
# Validation Loss: 0.4112710952758789
# Precision: 0.9042553191489362
# Recall: 0.8173076923076923
# AUC-ROC: 0.861778846153846
# AUC-PR: 0.9082815057283142
# True Negatives: 87.0
# False Positives: 9.0
# False Negatives: 19.0
# True Positives: 85.0
# Error Rate: 0.5012
# F1 Score: 0.8585858585858586
# Cohen's Kappa: 0.7206703910614525
# Matthews Correlation Coefficient: 0.7242835001863489
# Balanced Accuracy: 0.8617788461538461
# Time Taken (seconds): 250.77496147155762

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Define the input shape
input_shape = (224, 224, 3)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN base model
input_layer = Input(shape=input_shape)
vgg16_output = base_model(input_layer, training=False)
flatten = Flatten()(vgg16_output)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=40, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+LSTM+DENSE40',
    'Epochs': 40,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+LSTM+DENSE40_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model5_40_Epochs Training History")
plt.show()
# Out:
# Epoch 1/40
# 25/25 [==============================] - 40s 2s/step - loss: 0.6204 - accuracy: 0.6612 - precision_2: 0.7395 - recall_2: 0.4874 - auc_4: 0.7842 - auc_5: 0.6914 - true_negatives_2: 336.0000 - false_positives_2: 68.0000 - false_negatives_2: 203.0000 - true_positives_2: 193.0000 - val_loss: 0.5400 - val_accuracy: 0.7650 - val_precision_2: 0.8904 - val_recall_2: 0.6250 - val_auc_4: 0.8920 - val_auc_5: 0.8956 - val_true_negatives_2: 88.0000 - val_false_positives_2: 8.0000 - val_false_negatives_2: 39.0000 - val_true_positives_2: 65.0000
# Epoch 2/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.3843 - accuracy: 0.8838 - precision_2: 0.8797 - recall_2: 0.8864 - auc_4: 0.9472 - auc_5: 0.9391 - true_negatives_2: 356.0000 - false_positives_2: 48.0000 - false_negatives_2: 45.0000 - true_positives_2: 351.0000 - val_loss: 0.3975 - val_accuracy: 0.8350 - val_precision_2: 0.9080 - val_recall_2: 0.7596 - val_auc_4: 0.9186 - val_auc_5: 0.9300 - val_true_negatives_2: 88.0000 - val_false_positives_2: 8.0000 - val_false_negatives_2: 25.0000 - val_true_positives_2: 79.0000
# Epoch 3/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.2528 - accuracy: 0.9312 - precision_2: 0.9189 - recall_2: 0.9444 - auc_4: 0.9698 - auc_5: 0.9685 - true_negatives_2: 371.0000 - false_positives_2: 33.0000 - false_negatives_2: 22.0000 - true_positives_2: 374.0000 - val_loss: 0.3420 - val_accuracy: 0.8650 - val_precision_2: 0.8889 - val_recall_2: 0.8462 - val_auc_4: 0.9243 - val_auc_5: 0.9388 - val_true_negatives_2: 85.0000 - val_false_positives_2: 11.0000 - val_false_negatives_2: 16.0000 - val_true_positives_2: 88.0000
# Epoch 4/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.2119 - accuracy: 0.9350 - precision_2: 0.9257 - recall_2: 0.9444 - auc_4: 0.9749 - auc_5: 0.9750 - true_negatives_2: 374.0000 - false_positives_2: 30.0000 - false_negatives_2: 22.0000 - true_positives_2: 374.0000 - val_loss: 0.3880 - val_accuracy: 0.8400 - val_precision_2: 0.9390 - val_recall_2: 0.7404 - val_auc_4: 0.9284 - val_auc_5: 0.9426 - val_true_negatives_2: 91.0000 - val_false_positives_2: 5.0000 - val_false_negatives_2: 27.0000 - val_true_positives_2: 77.0000
# Epoch 5/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.1838 - accuracy: 0.9400 - precision_2: 0.9286 - recall_2: 0.9520 - auc_4: 0.9797 - auc_5: 0.9768 - true_negatives_2: 375.0000 - false_positives_2: 29.0000 - false_negatives_2: 19.0000 - true_positives_2: 377.0000 - val_loss: 0.7158 - val_accuracy: 0.6400 - val_precision_2: 1.0000 - val_recall_2: 0.3077 - val_auc_4: 0.9280 - val_auc_5: 0.9433 - val_true_negatives_2: 96.0000 - val_false_positives_2: 0.0000e+00 - val_false_negatives_2: 72.0000 - val_true_positives_2: 32.0000
# Epoch 6/40
# 25/25 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.9275 - precision_2: 0.9356 - recall_2: 0.9167 - auc_4: 0.9758 - auc_5: 0.9717 - true_negatives_2: 379.0000 - false_positives_2: 25.0000 - false_negatives_2: 33.0000 - true_positives_2: 363.0000Restoring model weights from the end of the best epoch: 3.
# 25/25 [==============================] - 39s 2s/step - loss: 0.2103 - accuracy: 0.9275 - precision_2: 0.9356 - recall_2: 0.9167 - auc_4: 0.9758 - auc_5: 0.9717 - true_negatives_2: 379.0000 - false_positives_2: 25.0000 - false_negatives_2: 33.0000 - true_positives_2: 363.0000 - val_loss: 0.5788 - val_accuracy: 0.7450 - val_precision_2: 0.9649 - val_recall_2: 0.5288 - val_auc_4: 0.9295 - val_auc_5: 0.9424 - val_true_negatives_2: 94.0000 - val_false_positives_2: 2.0000 - val_false_negatives_2: 49.0000 - val_true_positives_2: 55.0000
# Epoch 6: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3420 - accuracy: 0.8650 - precision_2: 0.8889 - recall_2: 0.8462 - auc_4: 0.9243 - auc_5: 0.9388 - true_negatives_2: 85.0000 - false_positives_2: 11.0000 - false_negatives_2: 16.0000 - true_positives_2: 88.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+LSTM+DENSE40
# Epochs: 40
# Test Accuracy: 0.8650000095367432
# Test Loss: 0.34203025698661804
# Validation Accuracy: 0.7450000047683716
# Validation Loss: 0.5788307785987854
# Precision: 0.8888888888888888
# Recall: 0.8461538461538461
# AUC-ROC: 0.8657852564102564
# AUC-PR: 0.9075213675213675
# True Negatives: 85.0
# False Positives: 11.0
# False Negatives: 16.0
# True Positives: 88.0
# Error Rate: 0.5002
# F1 Score: 0.8669950738916257
# Cohen's Kappa: 0.730107956817273
# Matthews Correlation Coefficient: 0.7310215741127511
# Balanced Accuracy: 0.8657852564102564
# Time Taken (seconds): 250.24628925323486

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Define the input shape
input_shape = (224, 224, 3)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN base model
input_layer = Input(shape=input_shape)
vgg16_output = base_model(input_layer, training=False)
flatten = Flatten()(vgg16_output)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=60, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+LSTM+DENSE60',
    'Epochs': 60,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+LSTM+DENSE60_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model5_60_Epochs Training History")
plt.show()
# Out:
# Epoch 1/60
# 25/25 [==============================] - 40s 2s/step - loss: 0.6606 - accuracy: 0.6800 - precision_3: 0.7288 - recall_3: 0.5631 - auc_6: 0.7569 - auc_7: 0.6584 - true_negatives_3: 321.0000 - false_positives_3: 83.0000 - false_negatives_3: 173.0000 - true_positives_3: 223.0000 - val_loss: 0.5458 - val_accuracy: 0.8200 - val_precision_3: 0.8696 - val_recall_3: 0.7692 - val_auc_6: 0.8953 - val_auc_7: 0.8991 - val_true_negatives_3: 84.0000 - val_false_positives_3: 12.0000 - val_false_negatives_3: 24.0000 - val_true_positives_3: 80.0000
# Epoch 2/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.4347 - accuracy: 0.8950 - precision_3: 0.8861 - recall_3: 0.9040 - auc_6: 0.9495 - auc_7: 0.9443 - true_negatives_3: 358.0000 - false_positives_3: 46.0000 - false_negatives_3: 38.0000 - true_positives_3: 358.0000 - val_loss: 0.4244 - val_accuracy: 0.8650 - val_precision_3: 0.9053 - val_recall_3: 0.8269 - val_auc_6: 0.9171 - val_auc_7: 0.9232 - val_true_negatives_3: 87.0000 - val_false_positives_3: 9.0000 - val_false_negatives_3: 18.0000 - val_true_positives_3: 86.0000
# Epoch 3/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2850 - accuracy: 0.9300 - precision_3: 0.9250 - recall_3: 0.9343 - auc_6: 0.9707 - auc_7: 0.9681 - true_negatives_3: 374.0000 - false_positives_3: 30.0000 - false_negatives_3: 26.0000 - true_positives_3: 370.0000 - val_loss: 0.3698 - val_accuracy: 0.8550 - val_precision_3: 0.9032 - val_recall_3: 0.8077 - val_auc_6: 0.9230 - val_auc_7: 0.9376 - val_true_negatives_3: 87.0000 - val_false_positives_3: 9.0000 - val_false_negatives_3: 20.0000 - val_true_positives_3: 84.0000
# Epoch 4/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2097 - accuracy: 0.9525 - precision_3: 0.9475 - recall_3: 0.9571 - auc_6: 0.9763 - auc_7: 0.9744 - true_negatives_3: 383.0000 - false_positives_3: 21.0000 - false_negatives_3: 17.0000 - true_positives_3: 379.0000 - val_loss: 0.3544 - val_accuracy: 0.8700 - val_precision_3: 0.8679 - val_recall_3: 0.8846 - val_auc_6: 0.9232 - val_auc_7: 0.9371 - val_true_negatives_3: 82.0000 - val_false_positives_3: 14.0000 - val_false_negatives_3: 12.0000 - val_true_positives_3: 92.0000
# Epoch 5/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2143 - accuracy: 0.9312 - precision_3: 0.9273 - recall_3: 0.9343 - auc_6: 0.9753 - auc_7: 0.9741 - true_negatives_3: 375.0000 - false_positives_3: 29.0000 - false_negatives_3: 26.0000 - true_positives_3: 370.0000 - val_loss: 0.4733 - val_accuracy: 0.7800 - val_precision_3: 0.9412 - val_recall_3: 0.6154 - val_auc_6: 0.9216 - val_auc_7: 0.9377 - val_true_negatives_3: 92.0000 - val_false_positives_3: 4.0000 - val_false_negatives_3: 40.0000 - val_true_positives_3: 64.0000
# Epoch 6/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.1769 - accuracy: 0.9475 - precision_3: 0.9338 - recall_3: 0.9621 - auc_6: 0.9855 - auc_7: 0.9858 - true_negatives_3: 377.0000 - false_positives_3: 27.0000 - false_negatives_3: 15.0000 - true_positives_3: 381.0000 - val_loss: 0.7512 - val_accuracy: 0.6150 - val_precision_3: 1.0000 - val_recall_3: 0.2596 - val_auc_6: 0.9289 - val_auc_7: 0.9426 - val_true_negatives_3: 96.0000 - val_false_positives_3: 0.0000e+00 - val_false_negatives_3: 77.0000 - val_true_positives_3: 27.0000
# Epoch 7/60
# 25/25 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9162 - precision_3: 0.9318 - recall_3: 0.8965 - auc_6: 0.9700 - auc_7: 0.9662 - true_negatives_3: 378.0000 - false_positives_3: 26.0000 - false_negatives_3: 41.0000 - true_positives_3: 355.0000Restoring model weights from the end of the best epoch: 4.
# 25/25 [==============================] - 39s 2s/step - loss: 0.2396 - accuracy: 0.9162 - precision_3: 0.9318 - recall_3: 0.8965 - auc_6: 0.9700 - auc_7: 0.9662 - true_negatives_3: 378.0000 - false_positives_3: 26.0000 - false_negatives_3: 41.0000 - true_positives_3: 355.0000 - val_loss: 0.5064 - val_accuracy: 0.7250 - val_precision_3: 0.9804 - val_recall_3: 0.4808 - val_auc_6: 0.9289 - val_auc_7: 0.9420 - val_true_negatives_3: 95.0000 - val_false_positives_3: 1.0000 - val_false_negatives_3: 54.0000 - val_true_positives_3: 50.0000
# Epoch 7: early stopping
# 7/7 [==============================] - 7s 1s/step - loss: 0.3544 - accuracy: 0.8700 - precision_3: 0.8679 - recall_3: 0.8846 - auc_6: 0.9232 - auc_7: 0.9371 - true_negatives_3: 82.0000 - false_positives_3: 14.0000 - false_negatives_3: 12.0000 - true_positives_3: 92.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+LSTM+DENSE60
# Epochs: 60
# Test Accuracy: 0.8700000047683716
# Test Loss: 0.35443541407585144
# Validation Accuracy: 0.7250000238418579
# Validation Loss: 0.5064014196395874
# Precision: 0.8679245283018868
# Recall: 0.8846153846153846
# AUC-ROC: 0.8693910256410257
# AUC-PR: 0.9062699564586357
# True Negatives: 82.0
# False Positives: 14.0
# False Negatives: 12.0
# True Positives: 92.0
# Error Rate: 0.4988
# F1 Score: 0.8761904761904762
# Cohen's Kappa: 0.7393744987971131
# Matthews Correlation Coefficient: 0.7395231308657959
# Balanced Accuracy: 0.8693910256410255
# Time Taken (seconds): 289.2844889163971

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Define the input shape
input_shape = (224, 224, 3)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN base model
input_layer = Input(shape=input_shape)
vgg16_output = base_model(input_layer, training=False)
flatten = Flatten()(vgg16_output)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=80, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+LSTM+DENSE80',
    'Epochs': 80,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+LSTM+DENSE80_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model5_80_Epochs Training History")
plt.show()
# Out:
# Epoch 1/80
# 25/25 [==============================] - 40s 2s/step - loss: 0.6915 - accuracy: 0.6650 - precision_4: 0.7119 - recall_4: 0.5429 - auc_8: 0.7136 - auc_9: 0.6336 - true_negatives_4: 317.0000 - false_positives_4: 87.0000 - false_negatives_4: 181.0000 - true_positives_4: 215.0000 - val_loss: 0.6232 - val_accuracy: 0.7800 - val_precision_4: 0.8947 - val_recall_4: 0.6538 - val_auc_8: 0.8890 - val_auc_9: 0.8894 - val_true_negatives_4: 88.0000 - val_false_positives_4: 8.0000 - val_false_negatives_4: 36.0000 - val_true_positives_4: 68.0000
# Epoch 2/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.5500 - accuracy: 0.8850 - precision_4: 0.8707 - recall_4: 0.9015 - auc_8: 0.9355 - auc_9: 0.9271 - true_negatives_4: 351.0000 - false_positives_4: 53.0000 - false_negatives_4: 39.0000 - true_positives_4: 357.0000 - val_loss: 0.5301 - val_accuracy: 0.8450 - val_precision_4: 0.8925 - val_recall_4: 0.7981 - val_auc_8: 0.9120 - val_auc_9: 0.9230 - val_true_negatives_4: 86.0000 - val_false_positives_4: 10.0000 - val_false_negatives_4: 21.0000 - val_true_positives_4: 83.0000
# Epoch 3/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.4369 - accuracy: 0.9125 - precision_4: 0.9055 - recall_4: 0.9192 - auc_8: 0.9584 - auc_9: 0.9510 - true_negatives_4: 366.0000 - false_positives_4: 38.0000 - false_negatives_4: 32.0000 - true_positives_4: 364.0000 - val_loss: 0.4644 - val_accuracy: 0.8350 - val_precision_4: 0.9277 - val_recall_4: 0.7404 - val_auc_8: 0.9198 - val_auc_9: 0.9315 - val_true_negatives_4: 90.0000 - val_false_positives_4: 6.0000 - val_false_negatives_4: 27.0000 - val_true_positives_4: 77.0000
# Epoch 4/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.3333 - accuracy: 0.9337 - precision_4: 0.9235 - recall_4: 0.9444 - auc_8: 0.9686 - auc_9: 0.9634 - true_negatives_4: 373.0000 - false_positives_4: 31.0000 - false_negatives_4: 22.0000 - true_positives_4: 374.0000 - val_loss: 0.3991 - val_accuracy: 0.8400 - val_precision_4: 0.9286 - val_recall_4: 0.7500 - val_auc_8: 0.9269 - val_auc_9: 0.9387 - val_true_negatives_4: 90.0000 - val_false_positives_4: 6.0000 - val_false_negatives_4: 26.0000 - val_true_positives_4: 78.0000
# Epoch 5/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2508 - accuracy: 0.9475 - precision_4: 0.9403 - recall_4: 0.9545 - auc_8: 0.9756 - auc_9: 0.9711 - true_negatives_4: 380.0000 - false_positives_4: 24.0000 - false_negatives_4: 18.0000 - true_positives_4: 378.0000 - val_loss: 0.4641 - val_accuracy: 0.8050 - val_precision_4: 0.9577 - val_recall_4: 0.6538 - val_auc_8: 0.9306 - val_auc_9: 0.9450 - val_true_negatives_4: 93.0000 - val_false_positives_4: 3.0000 - val_false_negatives_4: 36.0000 - val_true_positives_4: 68.0000
# Epoch 6/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2244 - accuracy: 0.9413 - precision_4: 0.9287 - recall_4: 0.9545 - auc_8: 0.9726 - auc_9: 0.9672 - true_negatives_4: 375.0000 - false_positives_4: 29.0000 - false_negatives_4: 18.0000 - true_positives_4: 378.0000 - val_loss: 0.5979 - val_accuracy: 0.7050 - val_precision_4: 0.9787 - val_recall_4: 0.4423 - val_auc_8: 0.9246 - val_auc_9: 0.9410 - val_true_negatives_4: 95.0000 - val_false_positives_4: 1.0000 - val_false_negatives_4: 58.0000 - val_true_positives_4: 46.0000
# Epoch 7/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2311 - accuracy: 0.9312 - precision_4: 0.9338 - recall_4: 0.9268 - auc_8: 0.9710 - auc_9: 0.9679 - true_negatives_4: 378.0000 - false_positives_4: 26.0000 - false_negatives_4: 29.0000 - true_positives_4: 367.0000 - val_loss: 0.3519 - val_accuracy: 0.8700 - val_precision_4: 0.9239 - val_recall_4: 0.8173 - val_auc_8: 0.9308 - val_auc_9: 0.9431 - val_true_negatives_4: 89.0000 - val_false_positives_4: 7.0000 - val_false_negatives_4: 19.0000 - val_true_positives_4: 85.0000
# Epoch 8/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.2358 - accuracy: 0.9237 - precision_4: 0.9241 - recall_4: 0.9217 - auc_8: 0.9726 - auc_9: 0.9736 - true_negatives_4: 374.0000 - false_positives_4: 30.0000 - false_negatives_4: 31.0000 - true_positives_4: 365.0000 - val_loss: 0.3415 - val_accuracy: 0.8650 - val_precision_4: 0.8532 - val_recall_4: 0.8942 - val_auc_8: 0.9262 - val_auc_9: 0.9419 - val_true_negatives_4: 80.0000 - val_false_positives_4: 16.0000 - val_false_negatives_4: 11.0000 - val_true_positives_4: 93.0000
# Epoch 9/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.1720 - accuracy: 0.9550 - precision_4: 0.9569 - recall_4: 0.9520 - auc_8: 0.9851 - auc_9: 0.9859 - true_negatives_4: 387.0000 - false_positives_4: 17.0000 - false_negatives_4: 19.0000 - true_positives_4: 377.0000 - val_loss: 0.3314 - val_accuracy: 0.8750 - val_precision_4: 0.8911 - val_recall_4: 0.8654 - val_auc_8: 0.9311 - val_auc_9: 0.9442 - val_true_negatives_4: 85.0000 - val_false_positives_4: 11.0000 - val_false_negatives_4: 14.0000 - val_true_positives_4: 90.0000
# Epoch 10/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.1571 - accuracy: 0.9650 - precision_4: 0.9670 - recall_4: 0.9621 - auc_8: 0.9848 - auc_9: 0.9878 - true_negatives_4: 391.0000 - false_positives_4: 13.0000 - false_negatives_4: 15.0000 - true_positives_4: 381.0000 - val_loss: 0.3362 - val_accuracy: 0.8800 - val_precision_4: 0.9000 - val_recall_4: 0.8654 - val_auc_8: 0.9288 - val_auc_9: 0.9459 - val_true_negatives_4: 86.0000 - val_false_positives_4: 10.0000 - val_false_negatives_4: 14.0000 - val_true_positives_4: 90.0000
# Epoch 11/80
# 25/25 [==============================] - 39s 2s/step - loss: 0.1125 - accuracy: 0.9725 - precision_4: 0.9770 - recall_4: 0.9672 - auc_8: 0.9905 - auc_9: 0.9921 - true_negatives_4: 395.0000 - false_positives_4: 9.0000 - false_negatives_4: 13.0000 - true_positives_4: 383.0000 - val_loss: 0.3656 - val_accuracy: 0.8450 - val_precision_4: 0.8288 - val_recall_4: 0.8846 - val_auc_8: 0.9321 - val_auc_9: 0.9441 - val_true_negatives_4: 77.0000 - val_false_positives_4: 19.0000 - val_false_negatives_4: 12.0000 - val_true_positives_4: 92.0000
# Epoch 12/80
# 25/25 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9750 - precision_4: 0.9700 - recall_4: 0.9798 - auc_8: 0.9933 - auc_9: 0.9947 - true_negatives_4: 392.0000 - false_positives_4: 12.0000 - false_negatives_4: 8.0000 - true_positives_4: 388.0000Restoring model weights from the end of the best epoch: 9.
# 25/25 [==============================] - 39s 2s/step - loss: 0.0969 - accuracy: 0.9750 - precision_4: 0.9700 - recall_4: 0.9798 - auc_8: 0.9933 - auc_9: 0.9947 - true_negatives_4: 392.0000 - false_positives_4: 12.0000 - false_negatives_4: 8.0000 - true_positives_4: 388.0000 - val_loss: 0.3590 - val_accuracy: 0.8750 - val_precision_4: 0.9540 - val_recall_4: 0.7981 - val_auc_8: 0.9353 - val_auc_9: 0.9495 - val_true_negatives_4: 92.0000 - val_false_positives_4: 4.0000 - val_false_negatives_4: 21.0000 - val_true_positives_4: 83.0000
# Epoch 12: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3314 - accuracy: 0.8750 - precision_4: 0.8911 - recall_4: 0.8654 - auc_8: 0.9311 - auc_9: 0.9442 - true_negatives_4: 85.0000 - false_positives_4: 11.0000 - false_negatives_4: 14.0000 - true_positives_4: 90.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+LSTM+DENSE80
# Epochs: 80
# Test Accuracy: 0.875
# Test Loss: 0.3314369320869446
# Validation Accuracy: 0.875
# Validation Loss: 0.3589511513710022
# Precision: 0.8910891089108911
# Recall: 0.8653846153846154
# AUC-ROC: 0.875400641025641
# AUC-PR: 0.9132368621477531
# True Negatives: 85.0
# False Positives: 11.0
# False Negatives: 14.0
# True Positives: 90.0
# Error Rate: 0.4998
# F1 Score: 0.8780487804878049
# Cohen's Kappa: 0.7498999599839935
# Matthews Correlation Coefficient: 0.7502379134103481
# Balanced Accuracy: 0.875400641025641
# Time Taken (seconds): 482.52933621406555

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.repeat(X_train_resized[..., np.newaxis], 3, -1)

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.repeat(X_test_resized[..., np.newaxis], 3, -1)

# Define the input shape
input_shape = (224, 224, 3)

# Load pre-trained VGG16 model without top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the layers of the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN base model
input_layer = Input(shape=input_shape)
vgg16_output = base_model(input_layer, training=False)
flatten = Flatten()(vgg16_output)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model for 20 epochs
history = model.fit(X_train_resized, y_train, epochs=100, shuffle=False, validation_data=(X_test_resized, y_test), callbacks=[early_stopping], verbose=1)

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)

# Calculate other metrics
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
classification_rep = classification_report(y_test, test_predictions, output_dict=True)
error_rate = np.mean(test_predictions != y_test)
roc_auc = roc_auc_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()
time_taken = end_time - start_time

# Create a dictionary to store model details and metrics
model_details = {
    'Model': 'VGG16+LSTM+DENSE100',
    'Epochs': 100,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision_score(y_test, test_predictions),
    'Recall': recall_score(y_test, test_predictions),
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16+LSTM+DENSE100_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model5_100_Epochs Training History")
plt.show()
# Out:
# Epoch 1/100
# 25/25 [==============================] - 40s 2s/step - loss: 0.6495 - accuracy: 0.6300 - precision_5: 0.7083 - recall_5: 0.4293 - auc_10: 0.7453 - auc_11: 0.6523 - true_negatives_5: 334.0000 - false_positives_5: 70.0000 - false_negatives_5: 226.0000 - true_positives_5: 170.0000 - val_loss: 0.5451 - val_accuracy: 0.7900 - val_precision_5: 0.9079 - val_recall_5: 0.6635 - val_auc_10: 0.8950 - val_auc_11: 0.8971 - val_true_negatives_5: 89.0000 - val_false_positives_5: 7.0000 - val_false_negatives_5: 35.0000 - val_true_positives_5: 69.0000
# Epoch 2/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.4147 - accuracy: 0.8813 - precision_5: 0.8698 - recall_5: 0.8939 - auc_10: 0.9467 - auc_11: 0.9366 - true_negatives_5: 351.0000 - false_positives_5: 53.0000 - false_negatives_5: 42.0000 - true_positives_5: 354.0000 - val_loss: 0.4200 - val_accuracy: 0.8400 - val_precision_5: 0.9186 - val_recall_5: 0.7596 - val_auc_10: 0.9220 - val_auc_11: 0.9311 - val_true_negatives_5: 89.0000 - val_false_positives_5: 7.0000 - val_false_negatives_5: 25.0000 - val_true_positives_5: 79.0000
# Epoch 3/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.2760 - accuracy: 0.9337 - precision_5: 0.9256 - recall_5: 0.9419 - auc_10: 0.9721 - auc_11: 0.9682 - true_negatives_5: 374.0000 - false_positives_5: 30.0000 - false_negatives_5: 23.0000 - true_positives_5: 373.0000 - val_loss: 0.4000 - val_accuracy: 0.8250 - val_precision_5: 0.9367 - val_recall_5: 0.7115 - val_auc_10: 0.9321 - val_auc_11: 0.9416 - val_true_negatives_5: 91.0000 - val_false_positives_5: 5.0000 - val_false_negatives_5: 30.0000 - val_true_positives_5: 74.0000
# Epoch 4/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.2059 - accuracy: 0.9550 - precision_5: 0.9500 - recall_5: 0.9596 - auc_10: 0.9793 - auc_11: 0.9795 - true_negatives_5: 384.0000 - false_positives_5: 20.0000 - false_negatives_5: 16.0000 - true_positives_5: 380.0000 - val_loss: 0.3551 - val_accuracy: 0.8650 - val_precision_5: 0.9053 - val_recall_5: 0.8269 - val_auc_10: 0.9299 - val_auc_11: 0.9385 - val_true_negatives_5: 87.0000 - val_false_positives_5: 9.0000 - val_false_negatives_5: 18.0000 - val_true_positives_5: 86.0000
# Epoch 5/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.2165 - accuracy: 0.9350 - precision_5: 0.9365 - recall_5: 0.9318 - auc_10: 0.9744 - auc_11: 0.9737 - true_negatives_5: 379.0000 - false_positives_5: 25.0000 - false_negatives_5: 27.0000 - true_positives_5: 369.0000 - val_loss: 0.4036 - val_accuracy: 0.8100 - val_precision_5: 0.9459 - val_recall_5: 0.6731 - val_auc_10: 0.9342 - val_auc_11: 0.9476 - val_true_negatives_5: 92.0000 - val_false_positives_5: 4.0000 - val_false_negatives_5: 34.0000 - val_true_positives_5: 70.0000
# Epoch 6/100
# 25/25 [==============================] - 39s 2s/step - loss: 0.2011 - accuracy: 0.9350 - precision_5: 0.9195 - recall_5: 0.9520 - auc_10: 0.9789 - auc_11: 0.9783 - true_negatives_5: 371.0000 - false_positives_5: 33.0000 - false_negatives_5: 19.0000 - true_positives_5: 377.0000 - val_loss: 0.5207 - val_accuracy: 0.7850 - val_precision_5: 0.9692 - val_recall_5: 0.6058 - val_auc_10: 0.9248 - val_auc_11: 0.9395 - val_true_negatives_5: 94.0000 - val_false_positives_5: 2.0000 - val_false_negatives_5: 41.0000 - val_true_positives_5: 63.0000
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9463 - precision_5: 0.9446 - recall_5: 0.9470 - auc_10: 0.9788 - auc_11: 0.9771 - true_negatives_5: 382.0000 - false_positives_5: 22.0000 - false_negatives_5: 21.0000 - true_positives_5: 375.0000Restoring model weights from the end of the best epoch: 4.
# 25/25 [==============================] - 39s 2s/step - loss: 0.2016 - accuracy: 0.9463 - precision_5: 0.9446 - recall_5: 0.9470 - auc_10: 0.9788 - auc_11: 0.9771 - true_negatives_5: 382.0000 - false_positives_5: 22.0000 - false_negatives_5: 21.0000 - true_positives_5: 375.0000 - val_loss: 0.3764 - val_accuracy: 0.8350 - val_precision_5: 0.9277 - val_recall_5: 0.7404 - val_auc_10: 0.9264 - val_auc_11: 0.9404 - val_true_negatives_5: 90.0000 - val_false_positives_5: 6.0000 - val_false_negatives_5: 27.0000 - val_true_positives_5: 77.0000
# Epoch 7: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3551 - accuracy: 0.8650 - precision_5: 0.9053 - recall_5: 0.8269 - auc_10: 0.9299 - auc_11: 0.9385 - true_negatives_5: 87.0000 - false_positives_5: 9.0000 - false_negatives_5: 18.0000 - true_positives_5: 86.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+LSTM+DENSE100
# Epochs: 100
# Test Accuracy: 0.8650000095367432
# Test Loss: 0.3550513982772827
# Validation Accuracy: 0.8349999785423279
# Validation Loss: 0.37639233469963074
# Precision: 0.9052631578947369
# Recall: 0.8269230769230769
# AUC-ROC: 0.8665865384615384
# AUC-PR: 0.9110931174089069
# True Negatives: 87.0
# False Positives: 9.0
# False Negatives: 18.0
# True Positives: 86.0
# Error Rate: 0.501
# F1 Score: 0.864321608040201
# Cohen's Kappa: 0.7305389221556886
# Matthews Correlation Coefficient: 0.7335037571219197
# Balanced Accuracy: 0.8665865384615384
# Time Taken (seconds): 288.98848009109497

# %% [markdown]
# # VGG16 (A) + GRU + Dense Layers (B):
#
# Base Model (A): Pre-trained CNN.
# Main Model (B): GRU layer followed by dense layers.
# Explanation: Use the pre-trained CNN for feature extraction, pass the features to an GRU layer for sequential processing, and add dense layers for classification.

# %% [markdown]
# # GRU
#
# **GRU (Gated Recurrent Unit)** is another type of recurrent neural network (RNN) that can be used in place of LSTM in certain scenarios. GRU is designed to be simpler than LSTM while still capturing long-term dependencies in sequential data. It has fewer parameters and is often more computationally efficient than LSTM.
#
# In the context of the combination provided (ResNet-50 + GRU + Dense Layers), the workflow would be similar to using LSTM:
#
# 1. **Feature Extraction**: Use the pre-trained ResNet-50 model to extract features from input images. These features represent high-level representations of the images learned by the ResNet-50 model.
#
# 2. **Sequence Modeling**: Pass the extracted features to the GRU layer. GRU processes the sequence of features extracted from the images, considering the temporal dependencies between them. Each feature vector extracted by ResNet-50 at a particular time step is treated as an input to the GRU.
#
# 3. **Classification**: After processing the sequence of feature vectors using the GRU layer, the output is passed through one or more dense layers for classification. These dense layers perform the final classification based on the processed features.
#
# 4. **Training and Evaluation**: Train the model using labeled data, where the input images are paired with their corresponding class labels. The model learns to map input images to their correct class labels by adjusting its parameters based on the optimization of a loss function. Evaluate the model's performance using a separate validation or test dataset to assess its accuracy.
#
# GRU can be a suitable choice when working with sequential data and can offer advantages in terms of computational efficiency compared to LSTM. However, the choice between LSTM and GRU often depends on the specific task and the characteristics of the dataset.

# %% [raw]
# Feature Extraction: Use the pre-trained ResNet-50 model to extract features from input images. These features represent high-level representations of the images learned by the ResNet-50 model.
#
# Sequence Modeling: Pass the extracted features to the GRU layer. GRU processes the sequence of features extracted from the images, considering the temporal dependencies between them. Each feature vector extracted by ResNet-50 at a particular time step is treated as an input to the GRU.
#
# Classification: After processing the sequence of feature vectors using the GRU layer, the output is passed through one or more dense layers for classification. These dense layers perform the final classification based on the processed features.

# %%
import numpy as np
from tensorflow.keras.layers import GRU, Dense, Reshape, Flatten  # Import Flatten layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import cv2
import pandas as pd
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_train_resized])  # Convert to RGB

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_test_resized])  # Convert to RGB


# Load pre-trained VGG16 model without the top layer
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in VGG16
for layer in vgg_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG16
model = Sequential([
    vgg_base,
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(100, activation='relu'),  # Dense layer with 100 units
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=20, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# End time
end_time = time.time()

# Calculate time taken
time_taken = end_time - start_time

# Additional Metrics
pr_auc = auc_pr
error_rate = (fp + fn) / (tp + tn + fp + fn)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# Model details dictionary
model_details = {
    'Model': 'VGG16+GRU+DENSE',
    'Epochs': len(history.history['loss']),
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("Model6(20)_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model6_20_Epochs Training History")
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  reshape_1 (Reshape)         (None, 1, 25088)          0
#
#  gru_1 (GRU)                 (None, 128)               9683712
#
#  dense_2 (Dense)             (None, 100)               12900
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 24411401 (93.12 MB)
# Trainable params: 9696713 (36.99 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/20
# 25/25 [==============================] - 33s 1s/step - loss: 0.5244 - accuracy: 0.7575 - precision_1: 0.7686 - recall_1: 0.7298 - auc_2: 0.8262 - auc_3: 0.8317 - true_positives_1: 289.0000 - false_positives_1: 87.0000 - true_negatives_1: 317.0000 - false_negatives_1: 107.0000 - val_loss: 0.4497 - val_accuracy: 0.8000 - val_precision_1: 0.9000 - val_recall_1: 0.6923 - val_auc_2: 0.8998 - val_auc_3: 0.9041 - val_true_positives_1: 72.0000 - val_false_positives_1: 8.0000 - val_true_negatives_1: 88.0000 - val_false_negatives_1: 32.0000
# Epoch 2/20
# 25/25 [==============================] - 35s 1s/step - loss: 0.3102 - accuracy: 0.8775 - precision_1: 0.8782 - recall_1: 0.8737 - auc_2: 0.9437 - auc_3: 0.9414 - true_positives_1: 346.0000 - false_positives_1: 48.0000 - true_negatives_1: 356.0000 - false_negatives_1: 50.0000 - val_loss: 0.3383 - val_accuracy: 0.8550 - val_precision_1: 0.9032 - val_recall_1: 0.8077 - val_auc_2: 0.9284 - val_auc_3: 0.9456 - val_true_positives_1: 84.0000 - val_false_positives_1: 9.0000 - val_true_negatives_1: 87.0000 - val_false_negatives_1: 20.0000
# Epoch 3/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.2088 - accuracy: 0.9250 - precision_1: 0.9179 - recall_1: 0.9318 - auc_2: 0.9743 - auc_3: 0.9758 - true_positives_1: 369.0000 - false_positives_1: 33.0000 - true_negatives_1: 371.0000 - false_negatives_1: 27.0000 - val_loss: 0.3748 - val_accuracy: 0.8400 - val_precision_1: 0.9186 - val_recall_1: 0.7596 - val_auc_2: 0.9272 - val_auc_3: 0.9454 - val_true_positives_1: 79.0000 - val_false_positives_1: 7.0000 - val_true_negatives_1: 89.0000 - val_false_negatives_1: 25.0000
# Epoch 4/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.1466 - accuracy: 0.9550 - precision_1: 0.9500 - recall_1: 0.9596 - auc_2: 0.9864 - auc_3: 0.9842 - true_positives_1: 380.0000 - false_positives_1: 20.0000 - true_negatives_1: 384.0000 - false_negatives_1: 16.0000 - val_loss: 0.3235 - val_accuracy: 0.8700 - val_precision_1: 0.8679 - val_recall_1: 0.8846 - val_auc_2: 0.9351 - val_auc_3: 0.9497 - val_true_positives_1: 92.0000 - val_false_positives_1: 14.0000 - val_true_negatives_1: 82.0000 - val_false_negatives_1: 12.0000
# Epoch 5/20
# 25/25 [==============================] - 38s 2s/step - loss: 0.0913 - accuracy: 0.9737 - precision_1: 0.9723 - recall_1: 0.9747 - auc_2: 0.9951 - auc_3: 0.9950 - true_positives_1: 386.0000 - false_positives_1: 11.0000 - true_negatives_1: 393.0000 - false_negatives_1: 10.0000 - val_loss: 0.3793 - val_accuracy: 0.8700 - val_precision_1: 0.8421 - val_recall_1: 0.9231 - val_auc_2: 0.9341 - val_auc_3: 0.9481 - val_true_positives_1: 96.0000 - val_false_positives_1: 18.0000 - val_true_negatives_1: 78.0000 - val_false_negatives_1: 8.0000
# Epoch 6/20
# 25/25 [==============================] - 39s 2s/step - loss: 0.0690 - accuracy: 0.9762 - precision_1: 0.9748 - recall_1: 0.9773 - auc_2: 0.9976 - auc_3: 0.9977 - true_positives_1: 387.0000 - false_positives_1: 10.0000 - true_negatives_1: 394.0000 - false_negatives_1: 9.0000 - val_loss: 0.4858 - val_accuracy: 0.8500 - val_precision_1: 0.8033 - val_recall_1: 0.9423 - val_auc_2: 0.9328 - val_auc_3: 0.9469 - val_true_positives_1: 98.0000 - val_false_positives_1: 24.0000 - val_true_negatives_1: 72.0000 - val_false_negatives_1: 6.0000
# Epoch 7/20
# 25/25 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9650 - precision_1: 0.9600 - recall_1: 0.9697 - auc_2: 0.9966 - auc_3: 0.9966 - true_positives_1: 384.0000 - false_positives_1: 16.0000 - true_negatives_1: 388.0000 - false_negatives_1: 12.0000Restoring model weights from the end of the best epoch: 4.
# 25/25 [==============================] - 39s 2s/step - loss: 0.0840 - accuracy: 0.9650 - precision_1: 0.9600 - recall_1: 0.9697 - auc_2: 0.9966 - auc_3: 0.9966 - true_positives_1: 384.0000 - false_positives_1: 16.0000 - true_negatives_1: 388.0000 - false_negatives_1: 12.0000 - val_loss: 0.3715 - val_accuracy: 0.8750 - val_precision_1: 0.8692 - val_recall_1: 0.8942 - val_auc_2: 0.9293 - val_auc_3: 0.9338 - val_true_positives_1: 93.0000 - val_false_positives_1: 14.0000 - val_true_negatives_1: 82.0000 - val_false_negatives_1: 11.0000
# Epoch 7: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3235 - accuracy: 0.8700 - precision_1: 0.8679 - recall_1: 0.8846 - auc_2: 0.9351 - auc_3: 0.9497 - true_positives_1: 92.0000 - false_positives_1: 14.0000 - true_negatives_1: 82.0000 - false_negatives_1: 12.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GRU+DENSE
# Epochs: 7
# Test Accuracy: 0.8700000047683716
# Test Loss: 0.3235289752483368
# Validation Accuracy: 0.875
# Validation Loss: 0.3714519739151001
# Precision: 0.8679245283018868
# Recall: 0.8846153846153846
# AUC-ROC: 0.8693910256410257
# AUC-PR: 0.949665904045105
# True Negatives: 82.0
# False Positives: 14.0
# False Negatives: 12.0
# True Positives: 92.0
# Error Rate: 0.13
# F1 Score: 0.8761904761904762
# Cohen's Kappa: 0.7393744987971131
# Matthews Correlation Coefficient: 0.7395231308657959
# Balanced Accuracy: 0.8693910256410255
# Time Taken (seconds): 275.61955761909485

# %%
import numpy as np
from tensorflow.keras.layers import GRU, Dense, Reshape, Flatten  # Import Flatten layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import cv2
import time
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_train_resized])  # Convert to RGB

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_test_resized])  # Convert to RGB


# Load pre-trained VGG16 model without the top layer
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in VGG16
for layer in vgg_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG16
model = Sequential([
    vgg_base,
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(100, activation='relu'),  # Dense layer with 100 units
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=40, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# End time
end_time = time.time()

# Calculate time taken
time_taken = end_time - start_time

# Additional Metrics
pr_auc = auc_pr
error_rate = (fp + fn) / (tp + tn + fp + fn)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# Model details dictionary
model_details = {
    'Model': 'VGG16+GRU+DENSE',
    'Epochs': len(history.history['loss']),
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("Model6(40)_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model6_40_Epochs Training History")
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  reshape_2 (Reshape)         (None, 1, 25088)          0
#
#  gru_2 (GRU)                 (None, 128)               9683712
#
#  dense_4 (Dense)             (None, 100)               12900
#
#  dense_5 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 24411401 (93.12 MB)
# Trainable params: 9696713 (36.99 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/40
# 25/25 [==============================] - 41s 2s/step - loss: 0.5212 - accuracy: 0.7450 - precision_2: 0.7652 - recall_2: 0.6995 - auc_4: 0.8289 - auc_5: 0.7890 - true_positives_2: 277.0000 - false_positives_2: 85.0000 - true_negatives_2: 319.0000 - false_negatives_2: 119.0000 - val_loss: 0.4280 - val_accuracy: 0.8300 - val_precision_2: 0.9070 - val_recall_2: 0.7500 - val_auc_4: 0.9019 - val_auc_5: 0.9096 - val_true_positives_2: 78.0000 - val_false_positives_2: 8.0000 - val_true_negatives_2: 88.0000 - val_false_negatives_2: 26.0000
# Epoch 2/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.3279 - accuracy: 0.8712 - precision_2: 0.8582 - recall_2: 0.8864 - auc_4: 0.9387 - auc_5: 0.9331 - true_positives_2: 351.0000 - false_positives_2: 58.0000 - true_negatives_2: 346.0000 - false_negatives_2: 45.0000 - val_loss: 0.3830 - val_accuracy: 0.8500 - val_precision_2: 0.8491 - val_recall_2: 0.8654 - val_auc_4: 0.9204 - val_auc_5: 0.9351 - val_true_positives_2: 90.0000 - val_false_positives_2: 16.0000 - val_true_negatives_2: 80.0000 - val_false_negatives_2: 14.0000
# Epoch 3/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.2451 - accuracy: 0.9162 - precision_2: 0.9002 - recall_2: 0.9343 - auc_4: 0.9676 - auc_5: 0.9623 - true_positives_2: 370.0000 - false_positives_2: 41.0000 - true_negatives_2: 363.0000 - false_negatives_2: 26.0000 - val_loss: 0.3901 - val_accuracy: 0.8550 - val_precision_2: 0.9412 - val_recall_2: 0.7692 - val_auc_4: 0.9219 - val_auc_5: 0.9363 - val_true_positives_2: 80.0000 - val_false_positives_2: 5.0000 - val_true_negatives_2: 91.0000 - val_false_negatives_2: 24.0000
# Epoch 4/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.1830 - accuracy: 0.9413 - precision_2: 0.9395 - recall_2: 0.9419 - auc_4: 0.9800 - auc_5: 0.9757 - true_positives_2: 373.0000 - false_positives_2: 24.0000 - true_negatives_2: 380.0000 - false_negatives_2: 23.0000 - val_loss: 0.3404 - val_accuracy: 0.8750 - val_precision_2: 0.8911 - val_recall_2: 0.8654 - val_auc_4: 0.9264 - val_auc_5: 0.9328 - val_true_positives_2: 90.0000 - val_false_positives_2: 11.0000 - val_true_negatives_2: 85.0000 - val_false_negatives_2: 14.0000
# Epoch 5/40
# 25/25 [==============================] - 39s 2s/step - loss: 0.1030 - accuracy: 0.9737 - precision_2: 0.9723 - recall_2: 0.9747 - auc_4: 0.9931 - auc_5: 0.9926 - true_positives_2: 386.0000 - false_positives_2: 11.0000 - true_negatives_2: 393.0000 - false_negatives_2: 10.0000 - val_loss: 0.3771 - val_accuracy: 0.8550 - val_precision_2: 0.8261 - val_recall_2: 0.9135 - val_auc_4: 0.9338 - val_auc_5: 0.9485 - val_true_positives_2: 95.0000 - val_false_positives_2: 20.0000 - val_true_negatives_2: 76.0000 - val_false_negatives_2: 9.0000
# Epoch 6/40
# 25/25 [==============================] - 38s 2s/step - loss: 0.0714 - accuracy: 0.9837 - precision_2: 0.9824 - recall_2: 0.9848 - auc_4: 0.9964 - auc_5: 0.9959 - true_positives_2: 390.0000 - false_positives_2: 7.0000 - true_negatives_2: 397.0000 - false_negatives_2: 6.0000 - val_loss: 0.4099 - val_accuracy: 0.8500 - val_precision_2: 0.8136 - val_recall_2: 0.9231 - val_auc_4: 0.9350 - val_auc_5: 0.9489 - val_true_positives_2: 96.0000 - val_false_positives_2: 22.0000 - val_true_negatives_2: 74.0000 - val_false_negatives_2: 8.0000
# Epoch 7/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9850 - precision_2: 0.9848 - recall_2: 0.9848 - auc_4: 0.9983 - auc_5: 0.9981 - true_positives_2: 390.0000 - false_positives_2: 6.0000 - true_negatives_2: 398.0000 - false_negatives_2: 6.0000Restoring model weights from the end of the best epoch: 4.
# 25/25 [==============================] - 38s 2s/step - loss: 0.0489 - accuracy: 0.9850 - precision_2: 0.9848 - recall_2: 0.9848 - auc_4: 0.9983 - auc_5: 0.9981 - true_positives_2: 390.0000 - false_positives_2: 6.0000 - true_negatives_2: 398.0000 - false_negatives_2: 6.0000 - val_loss: 0.4015 - val_accuracy: 0.8650 - val_precision_2: 0.8889 - val_recall_2: 0.8462 - val_auc_4: 0.9348 - val_auc_5: 0.9456 - val_true_positives_2: 88.0000 - val_false_positives_2: 11.0000 - val_true_negatives_2: 85.0000 - val_false_negatives_2: 16.0000
# Epoch 7: early stopping
# 7/7 [==============================] - 7s 1s/step - loss: 0.3404 - accuracy: 0.8750 - precision_2: 0.8911 - recall_2: 0.8654 - auc_4: 0.9264 - auc_5: 0.9328 - true_positives_2: 90.0000 - false_positives_2: 11.0000 - true_negatives_2: 85.0000 - false_negatives_2: 14.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GRU+DENSE
# Epochs: 7
# Test Accuracy: 0.875
# Test Loss: 0.34041300415992737
# Validation Accuracy: 0.8650000095367432
# Validation Loss: 0.4015118479728699
# Precision: 0.8910891089108911
# Recall: 0.8653846153846154
# AUC-ROC: 0.875400641025641
# AUC-PR: 0.932750940322876
# True Negatives: 85.0
# False Positives: 11.0
# False Negatives: 14.0
# True Positives: 90.0
# Error Rate: 0.125
# F1 Score: 0.8780487804878049
# Cohen's Kappa: 0.7498999599839935
# Matthews Correlation Coefficient: 0.7502379134103481
# Balanced Accuracy: 0.875400641025641
# Time Taken (seconds): 287.7275755405426

# %%
import numpy as np
from tensorflow.keras.layers import GRU, Dense, Reshape, Flatten  # Import Flatten layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import cv2
import pandas as pd
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_train_resized])  # Convert to RGB

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_test_resized])  # Convert to RGB


# Load pre-trained VGG16 model without the top layer
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in VGG16
for layer in vgg_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG16
model = Sequential([
    vgg_base,
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(100, activation='relu'),  # Dense layer with 100 units
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=60, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# End time
end_time = time.time()

# Calculate time taken
time_taken = end_time - start_time

# Additional Metrics
pr_auc = auc_pr
error_rate = (fp + fn) / (tp + tn + fp + fn)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# Model details dictionary
model_details = {
    'Model': 'VGG16+GRU+DENSE',
    'Epochs': len(history.history['loss']),
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("Model6(60)_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model6_60_Epochs Training History")
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  reshape_3 (Reshape)         (None, 1, 25088)          0
#
#  gru_3 (GRU)                 (None, 128)               9683712
#
#  dense_6 (Dense)             (None, 100)               12900
#
#  dense_7 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 24411401 (93.12 MB)
# Trainable params: 9696713 (36.99 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/60
# 25/25 [==============================] - 40s 2s/step - loss: 0.6371 - accuracy: 0.7337 - precision_3: 0.7133 - recall_3: 0.7727 - auc_6: 0.7880 - auc_7: 0.8087 - true_positives_3: 306.0000 - false_positives_3: 123.0000 - true_negatives_3: 281.0000 - false_negatives_3: 90.0000 - val_loss: 0.4730 - val_accuracy: 0.8150 - val_precision_3: 0.9036 - val_recall_3: 0.7212 - val_auc_6: 0.9004 - val_auc_7: 0.9119 - val_true_positives_3: 75.0000 - val_false_positives_3: 8.0000 - val_true_negatives_3: 88.0000 - val_false_negatives_3: 29.0000
# Epoch 2/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.3412 - accuracy: 0.8875 - precision_3: 0.8806 - recall_3: 0.8939 - auc_6: 0.9415 - auc_7: 0.9329 - true_positives_3: 354.0000 - false_positives_3: 48.0000 - true_negatives_3: 356.0000 - false_negatives_3: 42.0000 - val_loss: 0.3680 - val_accuracy: 0.8550 - val_precision_3: 0.8378 - val_recall_3: 0.8942 - val_auc_6: 0.9189 - val_auc_7: 0.9357 - val_true_positives_3: 93.0000 - val_false_positives_3: 18.0000 - val_true_negatives_3: 78.0000 - val_false_negatives_3: 11.0000
# Epoch 3/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.2426 - accuracy: 0.9200 - precision_3: 0.9150 - recall_3: 0.9242 - auc_6: 0.9686 - auc_7: 0.9677 - true_positives_3: 366.0000 - false_positives_3: 34.0000 - true_negatives_3: 370.0000 - false_negatives_3: 30.0000 - val_loss: 0.4642 - val_accuracy: 0.8100 - val_precision_3: 0.7500 - val_recall_3: 0.9519 - val_auc_6: 0.9234 - val_auc_7: 0.9347 - val_true_positives_3: 99.0000 - val_false_positives_3: 33.0000 - val_true_negatives_3: 63.0000 - val_false_negatives_3: 5.0000
# Epoch 4/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.2112 - accuracy: 0.9262 - precision_3: 0.9140 - recall_3: 0.9394 - auc_6: 0.9737 - auc_7: 0.9731 - true_positives_3: 372.0000 - false_positives_3: 35.0000 - true_negatives_3: 369.0000 - false_negatives_3: 24.0000 - val_loss: 0.3349 - val_accuracy: 0.8800 - val_precision_3: 0.9348 - val_recall_3: 0.8269 - val_auc_6: 0.9272 - val_auc_7: 0.9421 - val_true_positives_3: 86.0000 - val_false_positives_3: 6.0000 - val_true_negatives_3: 90.0000 - val_false_negatives_3: 18.0000
# Epoch 5/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.1317 - accuracy: 0.9613 - precision_3: 0.9529 - recall_3: 0.9697 - auc_6: 0.9898 - auc_7: 0.9903 - true_positives_3: 384.0000 - false_positives_3: 19.0000 - true_negatives_3: 385.0000 - false_negatives_3: 12.0000 - val_loss: 0.3307 - val_accuracy: 0.8550 - val_precision_3: 0.8261 - val_recall_3: 0.9135 - val_auc_6: 0.9365 - val_auc_7: 0.9497 - val_true_positives_3: 95.0000 - val_false_positives_3: 20.0000 - val_true_negatives_3: 76.0000 - val_false_negatives_3: 9.0000
# Epoch 6/60
# 25/25 [==============================] - 39s 2s/step - loss: 0.0996 - accuracy: 0.9737 - precision_3: 0.9771 - recall_3: 0.9697 - auc_6: 0.9944 - auc_7: 0.9946 - true_positives_3: 384.0000 - false_positives_3: 9.0000 - true_negatives_3: 395.0000 - false_negatives_3: 12.0000 - val_loss: 0.3585 - val_accuracy: 0.8650 - val_precision_3: 0.8468 - val_recall_3: 0.9038 - val_auc_6: 0.9344 - val_auc_7: 0.9500 - val_true_positives_3: 94.0000 - val_false_positives_3: 17.0000 - val_true_negatives_3: 79.0000 - val_false_negatives_3: 10.0000
# Epoch 7/60
# 25/25 [==============================] - 38s 2s/step - loss: 0.0562 - accuracy: 0.9875 - precision_3: 0.9874 - recall_3: 0.9874 - auc_6: 0.9977 - auc_7: 0.9981 - true_positives_3: 391.0000 - false_positives_3: 5.0000 - true_negatives_3: 399.0000 - false_negatives_3: 5.0000 - val_loss: 0.3847 - val_accuracy: 0.8650 - val_precision_3: 0.8407 - val_recall_3: 0.9135 - val_auc_6: 0.9372 - val_auc_7: 0.9454 - val_true_positives_3: 95.0000 - val_false_positives_3: 18.0000 - val_true_negatives_3: 78.0000 - val_false_negatives_3: 9.0000
# Epoch 8/60
# 25/25 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9925 - precision_3: 0.9924 - recall_3: 0.9924 - auc_6: 0.9987 - auc_7: 0.9988 - true_positives_3: 393.0000 - false_positives_3: 3.0000 - true_negatives_3: 401.0000 - false_negatives_3: 3.0000Restoring model weights from the end of the best epoch: 5.
# 25/25 [==============================] - 39s 2s/step - loss: 0.0430 - accuracy: 0.9925 - precision_3: 0.9924 - recall_3: 0.9924 - auc_6: 0.9987 - auc_7: 0.9988 - true_positives_3: 393.0000 - false_positives_3: 3.0000 - true_negatives_3: 401.0000 - false_negatives_3: 3.0000 - val_loss: 0.3773 - val_accuracy: 0.8600 - val_precision_3: 0.8878 - val_recall_3: 0.8365 - val_auc_6: 0.9347 - val_auc_7: 0.9398 - val_true_positives_3: 87.0000 - val_false_positives_3: 11.0000 - val_true_negatives_3: 85.0000 - val_false_negatives_3: 17.0000
# Epoch 8: early stopping
# 7/7 [==============================] - 7s 1s/step - loss: 0.3307 - accuracy: 0.8550 - precision_3: 0.8261 - recall_3: 0.9135 - auc_6: 0.9365 - auc_7: 0.9497 - true_positives_3: 95.0000 - false_positives_3: 20.0000 - true_negatives_3: 76.0000 - false_negatives_3: 9.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GRU+DENSE
# Epochs: 8
# Test Accuracy: 0.8550000190734863
# Test Loss: 0.3307056427001953
# Validation Accuracy: 0.8600000143051147
# Validation Loss: 0.3772744834423065
# Precision: 0.8260869565217391
# Recall: 0.9134615384615384
# AUC-ROC: 0.8525641025641025
# AUC-PR: 0.9496966600418091
# True Negatives: 76.0
# False Positives: 20.0
# False Negatives: 9.0
# True Positives: 95.0
# Error Rate: 0.145
# F1 Score: 0.867579908675799
# Cohen's Kappa: 0.7082494969818913
# Matthews Correlation Coefficient: 0.712626535744939
# Balanced Accuracy: 0.8525641025641025
# Time Taken (seconds): 325.10570454597473

# %%
import numpy as np
from tensorflow.keras.layers import GRU, Dense, Reshape, Flatten  # Import Flatten layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import cv2
import pandas as pd
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_train_resized])  # Convert to RGB

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_test_resized])  # Convert to RGB


# Load pre-trained VGG16 model without the top layer
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in VGG16
for layer in vgg_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG16
model = Sequential([
    vgg_base,
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(100, activation='relu'),  # Dense layer with 100 units
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=80, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# End time
end_time = time.time()

# Calculate time taken
time_taken = end_time - start_time

# Additional Metrics
pr_auc = auc_pr
error_rate = (fp + fn) / (tp + tn + fp + fn)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# Model details dictionary
model_details = {
    'Model': 'VGG16+GRU+DENSE',
    'Epochs': len(history.history['loss']),
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("Model6(80)_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model6_80_Epochs Training History")
plt.show()
# Out:
# 2024-03-23 14:11:57.581075: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-23 14:11:57.720824: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-23 14:11:57.720843: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-23 14:11:57.721853: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-23 14:11:57.803530: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-23 14:11:58.370150: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  reshape (Reshape)           (None, 1, 25088)          0
#
#  gru (GRU)                   (None, 128)               9683712
#
#  dense (Dense)               (None, 100)               12900
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 24411401 (93.12 MB)
# Trainable params: 9696713 (36.99 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/80
# 25/25 [==============================] - 37s 1s/step - loss: 0.6379 - accuracy: 0.6625 - precision: 0.7086 - recall: 0.5404 - auc: 0.7650 - auc_1: 0.6776 - true_positives: 214.0000 - false_positives: 88.0000 - true_negatives: 316.0000 - false_negatives: 182.0000 - val_loss: 0.4748 - val_accuracy: 0.8350 - val_precision: 0.8515 - val_recall: 0.8269 - val_auc: 0.8960 - val_auc_1: 0.8993 - val_true_positives: 86.0000 - val_false_positives: 15.0000 - val_true_negatives: 81.0000 - val_false_negatives: 18.0000
# Epoch 2/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.3654 - accuracy: 0.8825 - precision: 0.8775 - recall: 0.8864 - auc: 0.9312 - auc_1: 0.9200 - true_positives: 351.0000 - false_positives: 49.0000 - true_negatives: 355.0000 - false_negatives: 45.0000 - val_loss: 0.3891 - val_accuracy: 0.8300 - val_precision: 0.7917 - val_recall: 0.9135 - val_auc: 0.9161 - val_auc_1: 0.9250 - val_true_positives: 95.0000 - val_false_positives: 25.0000 - val_true_negatives: 71.0000 - val_false_negatives: 9.0000
# Epoch 3/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.2449 - accuracy: 0.9200 - precision: 0.9109 - recall: 0.9293 - auc: 0.9661 - auc_1: 0.9664 - true_positives: 368.0000 - false_positives: 36.0000 - true_negatives: 368.0000 - false_negatives: 28.0000 - val_loss: 0.3264 - val_accuracy: 0.8750 - val_precision: 0.8835 - val_recall: 0.8750 - val_auc: 0.9289 - val_auc_1: 0.9404 - val_true_positives: 91.0000 - val_false_positives: 12.0000 - val_true_negatives: 84.0000 - val_false_negatives: 13.0000
# Epoch 4/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.1631 - accuracy: 0.9488 - precision: 0.9449 - recall: 0.9520 - auc: 0.9845 - auc_1: 0.9844 - true_positives: 377.0000 - false_positives: 22.0000 - true_negatives: 382.0000 - false_negatives: 19.0000 - val_loss: 0.3128 - val_accuracy: 0.8650 - val_precision: 0.8667 - val_recall: 0.8750 - val_auc: 0.9376 - val_auc_1: 0.9499 - val_true_positives: 91.0000 - val_false_positives: 14.0000 - val_true_negatives: 82.0000 - val_false_negatives: 13.0000
# Epoch 5/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.1172 - accuracy: 0.9675 - precision: 0.9719 - recall: 0.9621 - auc: 0.9919 - auc_1: 0.9915 - true_positives: 381.0000 - false_positives: 11.0000 - true_negatives: 393.0000 - false_negatives: 15.0000 - val_loss: 0.3470 - val_accuracy: 0.8550 - val_precision: 0.8319 - val_recall: 0.9038 - val_auc: 0.9321 - val_auc_1: 0.9389 - val_true_positives: 94.0000 - val_false_positives: 19.0000 - val_true_negatives: 77.0000 - val_false_negatives: 10.0000
# Epoch 6/80
# 25/25 [==============================] - 38s 2s/step - loss: 0.0658 - accuracy: 0.9850 - precision: 0.9824 - recall: 0.9874 - auc: 0.9980 - auc_1: 0.9980 - true_positives: 391.0000 - false_positives: 7.0000 - true_negatives: 397.0000 - false_negatives: 5.0000 - val_loss: 0.3497 - val_accuracy: 0.8600 - val_precision: 0.9130 - val_recall: 0.8077 - val_auc: 0.9349 - val_auc_1: 0.9455 - val_true_positives: 84.0000 - val_false_positives: 8.0000 - val_true_negatives: 88.0000 - val_false_negatives: 20.0000
# Epoch 7/80
# 25/25 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9937 - precision: 0.9949 - recall: 0.9924 - auc: 0.9994 - auc_1: 0.9994 - true_positives: 393.0000 - false_positives: 2.0000 - true_negatives: 402.0000 - false_negatives: 3.0000Restoring model weights from the end of the best epoch: 4.
# 25/25 [==============================] - 39s 2s/step - loss: 0.0373 - accuracy: 0.9937 - precision: 0.9949 - recall: 0.9924 - auc: 0.9994 - auc_1: 0.9994 - true_positives: 393.0000 - false_positives: 2.0000 - true_negatives: 402.0000 - false_negatives: 3.0000 - val_loss: 0.3652 - val_accuracy: 0.8600 - val_precision: 0.8878 - val_recall: 0.8365 - val_auc: 0.9350 - val_auc_1: 0.9471 - val_true_positives: 87.0000 - val_false_positives: 11.0000 - val_true_negatives: 85.0000 - val_false_negatives: 17.0000
# Epoch 7: early stopping
# 7/7 [==============================] - 7s 1s/step - loss: 0.3128 - accuracy: 0.8650 - precision: 0.8667 - recall: 0.8750 - auc: 0.9376 - auc_1: 0.9499 - true_positives: 91.0000 - false_positives: 14.0000 - true_negatives: 82.0000 - false_negatives: 13.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GRU+DENSE
# Epochs: 7
# Test Accuracy: 0.8650000095367432
# Test Loss: 0.3127802014350891
# Validation Accuracy: 0.8600000143051147
# Validation Loss: 0.3651908040046692
# Precision: 0.8666666666666667
# Recall: 0.875
# AUC-ROC: 0.8645833333333334
# AUC-PR: 0.9499157667160034
# True Negatives: 82.0
# False Positives: 14.0
# False Negatives: 13.0
# True Positives: 91.0
# Error Rate: 0.135
# F1 Score: 0.8708133971291866
# Cohen's Kappa: 0.7294589178356714
# Matthews Correlation Coefficient: 0.7294955398698875
# Balanced Accuracy: 0.8645833333333333
# Time Taken (seconds): 285.1588079929352

# %%
import numpy as np
from tensorflow.keras.layers import GRU, Dense, Reshape, Flatten  # Import Flatten layer
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import cv2
import pandas as pd
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_train_resized])  # Convert to RGB

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.array([cv2.cvtColor(img, cv2.COLOR_GRAY2RGB) for img in X_test_resized])  # Convert to RGB


# Load pre-trained VGG16 model without the top layer
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in VGG16
for layer in vgg_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG16
model = Sequential([
    vgg_base,
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(100, activation='relu'),  # Dense layer with 100 units
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=100, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# End time
end_time = time.time()

# Calculate time taken
time_taken = end_time - start_time

# Additional Metrics
pr_auc = auc_pr
error_rate = (fp + fn) / (tp + tn + fp + fn)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)

# Model details dictionary
model_details = {
    'Model': 'VGG16+GRU+DENSE',
    'Epochs': len(history.history['loss']),
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'AUC-PR': pr_auc,
    'True Negatives': tn,
    'False Positives': fp,
    'False Negatives': fn,
    'True Positives': tp,
    'Error Rate': error_rate,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_accuracy,
    'Time Taken (seconds)': time_taken
}

# Print model details and metrics
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Write model details and metrics to CSV file
df = pd.DataFrame(model_details, index=[0])
df.to_csv("Model6(100)_Metrics.csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("Model6_100_Epochs Training History")
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  reshape_1 (Reshape)         (None, 1, 25088)          0
#
#  gru_1 (GRU)                 (None, 128)               9683712
#
#  dense_2 (Dense)             (None, 100)               12900
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 24411401 (93.12 MB)
# Trainable params: 9696713 (36.99 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 40s 2s/step - loss: 0.5185 - accuracy: 0.7575 - precision_1: 0.7327 - recall_1: 0.8030 - auc_2: 0.8342 - auc_3: 0.8404 - true_positives_1: 318.0000 - false_positives_1: 116.0000 - true_negatives_1: 288.0000 - false_negatives_1: 78.0000 - val_loss: 0.3933 - val_accuracy: 0.8350 - val_precision_1: 0.8817 - val_recall_1: 0.7885 - val_auc_2: 0.9056 - val_auc_3: 0.9052 - val_true_positives_1: 82.0000 - val_false_positives_1: 11.0000 - val_true_negatives_1: 85.0000 - val_false_negatives_1: 22.0000
# Epoch 2/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.2774 - accuracy: 0.9025 - precision_1: 0.8995 - recall_1: 0.9040 - auc_2: 0.9528 - auc_3: 0.9491 - true_positives_1: 358.0000 - false_positives_1: 40.0000 - true_negatives_1: 364.0000 - false_negatives_1: 38.0000 - val_loss: 0.3612 - val_accuracy: 0.8350 - val_precision_1: 0.8198 - val_recall_1: 0.8750 - val_auc_2: 0.9227 - val_auc_3: 0.9364 - val_true_positives_1: 91.0000 - val_false_positives_1: 20.0000 - val_true_negatives_1: 76.0000 - val_false_negatives_1: 13.0000
# Epoch 3/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.2061 - accuracy: 0.9250 - precision_1: 0.9242 - recall_1: 0.9242 - auc_2: 0.9756 - auc_3: 0.9755 - true_positives_1: 366.0000 - false_positives_1: 30.0000 - true_negatives_1: 374.0000 - false_negatives_1: 30.0000 - val_loss: 0.3555 - val_accuracy: 0.8600 - val_precision_1: 0.9222 - val_recall_1: 0.7981 - val_auc_2: 0.9252 - val_auc_3: 0.9403 - val_true_positives_1: 83.0000 - val_false_positives_1: 7.0000 - val_true_negatives_1: 89.0000 - val_false_negatives_1: 21.0000
# Epoch 4/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.1565 - accuracy: 0.9388 - precision_1: 0.9327 - recall_1: 0.9444 - auc_2: 0.9879 - auc_3: 0.9880 - true_positives_1: 374.0000 - false_positives_1: 27.0000 - true_negatives_1: 377.0000 - false_negatives_1: 22.0000 - val_loss: 0.3527 - val_accuracy: 0.8700 - val_precision_1: 0.9239 - val_recall_1: 0.8173 - val_auc_2: 0.9284 - val_auc_3: 0.9413 - val_true_positives_1: 85.0000 - val_false_positives_1: 7.0000 - val_true_negatives_1: 89.0000 - val_false_negatives_1: 19.0000
# Epoch 5/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.0872 - accuracy: 0.9812 - precision_1: 0.9823 - recall_1: 0.9798 - auc_2: 0.9969 - auc_3: 0.9969 - true_positives_1: 388.0000 - false_positives_1: 7.0000 - true_negatives_1: 397.0000 - false_negatives_1: 8.0000 - val_loss: 0.3618 - val_accuracy: 0.8650 - val_precision_1: 0.8532 - val_recall_1: 0.8942 - val_auc_2: 0.9382 - val_auc_3: 0.9483 - val_true_positives_1: 93.0000 - val_false_positives_1: 16.0000 - val_true_negatives_1: 80.0000 - val_false_negatives_1: 11.0000
# Epoch 6/100
# 25/25 [==============================] - 38s 2s/step - loss: 0.0511 - accuracy: 0.9862 - precision_1: 0.9898 - recall_1: 0.9823 - auc_2: 0.9989 - auc_3: 0.9989 - true_positives_1: 389.0000 - false_positives_1: 4.0000 - true_negatives_1: 400.0000 - false_negatives_1: 7.0000 - val_loss: 0.3902 - val_accuracy: 0.8650 - val_precision_1: 0.8598 - val_recall_1: 0.8846 - val_auc_2: 0.9316 - val_auc_3: 0.9411 - val_true_positives_1: 92.0000 - val_false_positives_1: 15.0000 - val_true_negatives_1: 81.0000 - val_false_negatives_1: 12.0000
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9900 - precision_1: 0.9924 - recall_1: 0.9874 - auc_2: 0.9998 - auc_3: 0.9998 - true_positives_1: 391.0000 - false_positives_1: 3.0000 - true_negatives_1: 401.0000 - false_negatives_1: 5.0000Restoring model weights from the end of the best epoch: 4.
# 25/25 [==============================] - 38s 2s/step - loss: 0.0332 - accuracy: 0.9900 - precision_1: 0.9924 - recall_1: 0.9874 - auc_2: 0.9998 - auc_3: 0.9998 - true_positives_1: 391.0000 - false_positives_1: 3.0000 - true_negatives_1: 401.0000 - false_negatives_1: 5.0000 - val_loss: 0.4256 - val_accuracy: 0.8650 - val_precision_1: 0.9053 - val_recall_1: 0.8269 - val_auc_2: 0.9378 - val_auc_3: 0.9377 - val_true_positives_1: 86.0000 - val_false_positives_1: 9.0000 - val_true_negatives_1: 87.0000 - val_false_negatives_1: 18.0000
# Epoch 7: early stopping
# 7/7 [==============================] - 8s 1s/step - loss: 0.3527 - accuracy: 0.8700 - precision_1: 0.9239 - recall_1: 0.8173 - auc_2: 0.9284 - auc_3: 0.9413 - true_positives_1: 85.0000 - false_positives_1: 7.0000 - true_negatives_1: 89.0000 - false_negatives_1: 19.0000
# 7/7 [==============================] - 8s 1s/step
# Model Details:
# Model: VGG16+GRU+DENSE
# Epochs: 7
# Test Accuracy: 0.8700000047683716
# Test Loss: 0.35266736149787903
# Validation Accuracy: 0.8650000095367432
# Validation Loss: 0.4256439208984375
# Precision: 0.9239130434782609
# Recall: 0.8173076923076923
# AUC-ROC: 0.8721955128205129
# AUC-PR: 0.9412928819656372
# True Negatives: 89.0
# False Positives: 7.0
# False Negatives: 19.0
# True Positives: 85.0
# Error Rate: 0.13
# F1 Score: 0.8673469387755102
# Cohen's Kappa: 0.740829346092504
# Matthews Correlation Coefficient: 0.7461869052731072
# Balanced Accuracy: 0.8721955128205128
# Time Taken (seconds): 286.91831493377686

# %% [markdown]
# # vgg16+Attention+Dense

# %%
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, Multiply, Lambda
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import pandas as pd

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)


# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add attention mechanism
x = GlobalAveragePooling2D()(base_model.output)
x = Reshape((1, -1))(x)  # Reshape to 3D tensor for attention mechanism
attention_probs = Dense(np.prod(x.shape[2:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
attention_mul = Lambda(lambda x: K.sum(x, axis=1))(attention_mul)  # Sum along the time axis

# Add dense layers for classification
output = Dense(1, activation='sigmoid')(attention_mul)

# Create the full model
model_attention = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model_attention.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model_attention.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model_attention.fit(X_train_resized, y_train, epochs=20, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model_attention.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model_attention.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")

# Save metrics to CSV
metrics_df = pd.DataFrame({
    'Model': ['VGG16_Attention'],
    'Test Accuracy': [test_accuracy],
    'Test Loss': [test_loss],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1],
    'Cohen\'s Kappa Coefficient': [kappa],
    'Matthews Corr. Coef.': [mcc],
    'Balanced Accuracy': [balanced_acc],
    'AUC Score': [roc_auc],
    'Training Time (s)': [end_time - start_time],
    'Training Loss': [history.history['loss'][-1]],
    'Testing Loss': [test_loss],
    'Training Accuracy': [history.history['accuracy'][-1]],
    'Testing Accuracy': [test_accuracy]
})

metrics_df.to_csv('metrics7(20).csv', index=False)
# Out:
# 2024-03-23 16:08:33.556118: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-23 16:08:33.556955: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-23 16:08:33.603625: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-23 16:08:33.820793: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-23 16:08:34.309096: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 512)    │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_probs     │ (None, 1, 512)    │    262,656 │ reshape[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 512)    │          0 │ reshape[0][0],    │
# │                     │                   │            │ attention_probs[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 512)       │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │        513 │ lambda[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,977,857 (57.14 MB)
#  Trainable params: 263,169 (1.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.4984 - loss: 0.6931 - val_accuracy: 0.4800 - val_loss: 0.6926
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.5064 - loss: 0.6924 - val_accuracy: 0.4800 - val_loss: 0.6905
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.5198 - loss: 0.6895 - val_accuracy: 0.5650 - val_loss: 0.6764
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.6340 - loss: 0.6667 - val_accuracy: 0.6600 - val_loss: 0.6069
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7361 - loss: 0.6049 - val_accuracy: 0.8550 - val_loss: 0.5456
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7983 - loss: 0.5532 - val_accuracy: 0.8550 - val_loss: 0.5027
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8192 - loss: 0.5207 - val_accuracy: 0.8550 - val_loss: 0.4729
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8236 - loss: 0.4969 - val_accuracy: 0.8500 - val_loss: 0.4449
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8232 - loss: 0.4850 - val_accuracy: 0.8650 - val_loss: 0.4245
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8478 - loss: 0.4548 - val_accuracy: 0.8650 - val_loss: 0.4061
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8264 - loss: 0.4633 - val_accuracy: 0.8650 - val_loss: 0.3928
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8366 - loss: 0.4344 - val_accuracy: 0.8650 - val_loss: 0.3816
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8259 - loss: 0.4446 - val_accuracy: 0.8650 - val_loss: 0.3700
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8496 - loss: 0.4170 - val_accuracy: 0.8750 - val_loss: 0.3631
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8244 - loss: 0.4278 - val_accuracy: 0.8700 - val_loss: 0.3528
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8389 - loss: 0.4029 - val_accuracy: 0.8750 - val_loss: 0.3465
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8515 - loss: 0.4161 - val_accuracy: 0.8750 - val_loss: 0.3540
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8417 - loss: 0.3880 - val_accuracy: 0.8800 - val_loss: 0.3359
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8208 - loss: 0.4161 - val_accuracy: 0.8700 - val_loss: 0.3312
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8390 - loss: 0.3984 - val_accuracy: 0.8850 - val_loss: 0.3306
# Restoring model weights from the end of the best epoch: 20.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8953 - loss: 0.3418
# Test Accuracy: 88.50%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# Confusion Matrix:
# [[81 15]
#  [ 8 96]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88        96
#            1       0.86      0.92      0.89       104
#
#     accuracy                           0.89       200
#    macro avg       0.89      0.88      0.88       200
# weighted avg       0.89      0.89      0.88       200
#
# AUC Score: 0.88
#
# Precision: 0.8648648648648649
# Recall: 0.9230769230769231
# F1 Score: 0.8930232558139535
# Cohen's Kappa Coefficient: 0.7689835275210928
# Matthews Correlation Coefficient (MCC): 0.7708913026187127
# Balanced Accuracy: 0.8834134615384616
# Time taken: 746.94 seconds

# %%
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, Multiply, Lambda
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import pandas as pd

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add attention mechanism
x = GlobalAveragePooling2D()(base_model.output)
x = Reshape((1, -1))(x)  # Reshape to 3D tensor for attention mechanism
attention_probs = Dense(np.prod(x.shape[2:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
attention_mul = Lambda(lambda x: K.sum(x, axis=1))(attention_mul)  # Sum along the time axis

# Add dense layers for classification
output = Dense(1, activation='sigmoid')(attention_mul)

# Create the full model
model_attention = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model_attention.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model_attention.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model_attention.fit(X_train_resized, y_train, epochs=40, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model_attention.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model_attention.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")

# Save metrics to CSV
metrics_df = pd.DataFrame({
    'Model': ['VGG16_Attention'],
    'Test Accuracy': [test_accuracy],
    'Test Loss': [test_loss],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1],
    'Cohen\'s Kappa Coefficient': [kappa],
    'Matthews Corr. Coef.': [mcc],
    'Balanced Accuracy': [balanced_acc],
    'AUC Score': [roc_auc],
    'Training Time (s)': [end_time - start_time],
    'Training Loss': [history.history['loss'][-1]],
    'Testing Loss': [test_loss],
    'Training Accuracy': [history.history['accuracy'][-1]],
    'Testing Accuracy': [test_accuracy]
})

metrics_df.to_csv('metrics7(40).csv', index=False)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_lay
40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8436 - loss: 0.3851 - val_accuracy: 0.8850 - val_loss: 0.3120
# Epoch 30/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8608 - loss: 0.3652 - val_accuracy: 0.8800 - val_loss: 0.3079
# Epoch 31/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8611 - loss: 0.3672 - val_accuracy: 0.8850 - val_loss: 0.3067
# Epoch 32/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8588 - loss: 0.3552 - val_accuracy: 0.8700 - val_loss: 0.3305
# Epoch 33/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8489 - loss: 0.3780 - val_accuracy: 0.8800 - val_loss: 0.3027
# Epoch 34/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8828 - loss: 0.3480 - val_accuracy: 0.8800 - val_loss: 0.3002
# Epoch 35/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8867 - loss: 0.3293 - val_accuracy: 0.8800 - val_loss: 0.2996
# Epoch 36/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8570 - loss: 0.3459 - val_accuracy: 0.8750 - val_loss: 0.2973
# Epoch 37/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8693 - loss: 0.3583 - val_accuracy: 0.8900 - val_loss: 0.2967
# Epoch 38/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8643 - loss: 0.3559 - val_accuracy: 0.8900 - val_loss: 0.2956
# Epoch 39/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8719 - loss: 0.3295 - val_accuracy: 0.8900 - val_loss: 0.2976
# Epoch 40/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8641 - loss: 0.3598 - val_accuracy: 0.8900 - val_loss: 0.2930
# Restoring model weights from the end of the best epoch: 40.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8937 - loss: 0.3063
# Test Accuracy: 89.00%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# Confusion Matrix:
# [[86 10]
#  [12 92]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        96
#            1       0.90      0.88      0.89       104
#
#     accuracy                           0.89       200
#    macro avg       0.89      0.89      0.89       200
# weighted avg       0.89      0.89      0.89       200
#
# AUC Score: 0.89
#
# Precision: 0.9019607843137255
# Recall: 0.8846153846153846
# F1 Score: 0.8932038834951457
# Cohen's Kappa Coefficient: 0.7798238590872698
# Matthews Correlation Coefficient (MCC): 0.7799801206576289
# Balanced Accuracy: 0.890224358974359
# Time taken: 1504.20 seconds

# %%
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, Multiply, Lambda
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import pandas as pd

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add attention mechanism
x = GlobalAveragePooling2D()(base_model.output)
x = Reshape((1, -1))(x)  # Reshape to 3D tensor for attention mechanism
attention_probs = Dense(np.prod(x.shape[2:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
attention_mul = Lambda(lambda x: K.sum(x, axis=1))(attention_mul)  # Sum along the time axis

# Add dense layers for classification
output = Dense(1, activation='sigmoid')(attention_mul)

# Create the full model
model_attention = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model_attention.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model_attention.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model_attention.fit(X_train_resized, y_train, epochs=60, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model_attention.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model_attention.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")

# Save metrics to CSV
metrics_df = pd.DataFrame({
    'Model': ['VGG16_Attention'],
    'Test Accuracy': [test_accuracy],
    'Test Loss': [test_loss],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1],
    'Cohen\'s Kappa Coefficient': [kappa],
    'Matthews Corr. Coef.': [mcc],
    'Balanced Accuracy': [balanced_acc],
    'AUC Score': [roc_auc],
    'Training Time (s)': [end_time - start_time],
    'Training Loss': [history.history['loss'][-1]],
    'Testing Loss': [test_loss],
    'Training Accuracy': [history.history['accuracy'][-1]],
    'Testing Accuracy': [test_accuracy]
})

metrics_df.to_csv('metrics7(60).csv', index=False)
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_lay
60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8687 - loss: 0.3519 - val_accuracy: 0.8700 - val_loss: 0.3000
# Epoch 29/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8387 - loss: 0.3692 - val_accuracy: 0.8900 - val_loss: 0.3019
# Epoch 30/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8763 - loss: 0.3459 - val_accuracy: 0.8950 - val_loss: 0.3001
# Epoch 31/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8609 - loss: 0.3525 - val_accuracy: 0.8850 - val_loss: 0.2959
# Epoch 32/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8613 - loss: 0.3595 - val_accuracy: 0.8750 - val_loss: 0.2941
# Epoch 33/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8784 - loss: 0.3335 - val_accuracy: 0.8800 - val_loss: 0.2930
# Epoch 34/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8549 - loss: 0.3556 - val_accuracy: 0.8900 - val_loss: 0.2965
# Epoch 35/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8654 - loss: 0.3480 - val_accuracy: 0.8800 - val_loss: 0.2921
# Epoch 36/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8808 - loss: 0.3347 - val_accuracy: 0.8850 - val_loss: 0.2895
# Epoch 37/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8828 - loss: 0.3282 - val_accuracy: 0.8850 - val_loss: 0.2940
# Epoch 38/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8726 - loss: 0.3351 - val_accuracy: 0.8850 - val_loss: 0.2979
# Epoch 39/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8735 - loss: 0.3413 - val_accuracy: 0.8900 - val_loss: 0.2906
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 36.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8829 - loss: 0.3013
# Test Accuracy: 88.50%
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f5270bbe170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# Confusion Matrix:
# [[85 11]
#  [12 92]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88        96
#            1       0.89      0.88      0.89       104
#
#     accuracy                           0.89       200
#    macro avg       0.88      0.89      0.88       200
# weighted avg       0.89      0.89      0.89       200
#
# AUC Score: 0.89
#
# Precision: 0.8932038834951457
# Recall: 0.8846153846153846
# F1 Score: 0.8888888888888888
# Cohen's Kappa Coefficient: 0.7697236684020825
# Matthews Correlation Coefficient (MCC): 0.7697622500194723
# Balanced Accuracy: 0.8850160256410255
# Time taken: 1457.98 seconds

# %%
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, Multiply, Lambda
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import pandas as pd

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add attention mechanism
x = GlobalAveragePooling2D()(base_model.output)
x = Reshape((1, -1))(x)  # Reshape to 3D tensor for attention mechanism
attention_probs = Dense(np.prod(x.shape[2:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
attention_mul = Lambda(lambda x: K.sum(x, axis=1))(attention_mul)  # Sum along the time axis

# Add dense layers for classification
output = Dense(1, activation='sigmoid')(attention_mul)

# Create the full model
model_attention = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model_attention.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model_attention.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model_attention.fit(X_train_resized, y_train, epochs=80, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model_attention.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model_attention.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")

# Save metrics to CSV
metrics_df = pd.DataFrame({
    'Model': ['VGG16_Attention'],
    'Test Accuracy': [test_accuracy],
    'Test Loss': [test_loss],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1],
    'Cohen\'s Kappa Coefficient': [kappa],
    'Matthews Corr. Coef.': [mcc],
    'Balanced Accuracy': [balanced_acc],
    'AUC Score': [roc_auc],
    'Training Time (s)': [end_time - start_time],
    'Training Loss': [history.history['loss'][-1]],
    'Testing Loss': [test_loss],
    'Training Accuracy': [history.history['accuracy'][-1]],
    'Testing Accuracy': [test_accuracy]
})

metrics_df.to_csv('metrics7(80).csv', index=False)
# Out:
# 2024-03-24 09:30:00.699240: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03
]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        96
#            1       0.91      0.86      0.88       104
#
#     accuracy                           0.88       200
#    macro avg       0.88      0.88      0.88       200
# weighted avg       0.88      0.88      0.88       200
#
# AUC Score: 0.88
#
# Precision: 0.9081632653061225
# Recall: 0.8557692307692307
# F1 Score: 0.8811881188118811
# Cohen's Kappa Coefficient: 0.7601918465227817
# Matthews Correlation Coefficient (MCC): 0.7615616989172537
# Balanced Accuracy: 0.8810096153846154
# Time taken: 964.71 seconds

# %%
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, Multiply, Lambda
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
import pandas as pd

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add attention mechanism
x = GlobalAveragePooling2D()(base_model.output)
x = Reshape((1, -1))(x)  # Reshape to 3D tensor for attention mechanism
attention_probs = Dense(np.prod(x.shape[2:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
attention_mul = Lambda(lambda x: K.sum(x, axis=1))(attention_mul)  # Sum along the time axis

# Add dense layers for classification
output = Dense(1, activation='sigmoid')(attention_mul)

# Create the full model
model_attention = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model_attention.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model_attention.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model_attention.fit(X_train_resized, y_train, epochs=100, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model_attention.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model_attention.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")

# Save metrics to CSV
metrics_df = pd.DataFrame({
    'Model': ['VGG16_Attention'],
    'Test Accuracy': [test_accuracy],
    'Test Loss': [test_loss],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1],
    'Cohen\'s Kappa Coefficient': [kappa],
    'Matthews Corr. Coef.': [mcc],
    'Balanced Accuracy': [balanced_acc],
    'AUC Score': [roc_auc],
    'Training Time (s)': [end_time - start_time],
    'Training Loss': [history.history['loss'][-1]],
    'Testing Loss': [test_loss],
    'Training Accuracy': [history.history['accuracy'][-1]],
    'Testing Accuracy': [test_accuracy]
})

metrics_df.to_csv('metrics7(100).csv', index=False)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer_1[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 512)    │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_probs     │ (None, 1, 512)    │    262,656 │ reshape_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 512)    │          0 │ reshape_1[0][0],  │
# │ (Multiply)          │                   │            │ attention_probs[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 512)       │          0 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        513 │ lambda_1[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,977,857 (57.14 MB)
#  Trainable params: 263,169 (1.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.5025 - loss: 0.6931 - val_accuracy: 0.4850 - val_loss: 0.6927
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.5214 - loss: 0.6923 - val_accuracy: 0.4800 - val_loss: 0.6901
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.5449 - loss: 0.6886 - val_accuracy: 0.7950 - val_loss: 0.6799
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7195 - loss: 0.6739 - val_accuracy: 0.6150 - val_loss: 0.6339
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6196 - loss: 0.6313 - val_accuracy: 0.8400 - val_loss: 0.5897
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8084 - loss: 0.5820 - val_accuracy: 0.8450 - val_loss: 0.5036
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8221 - loss: 0.5227 - val_accuracy: 0.8300 - val_loss: 0.4732
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8219 - loss: 0.4800 - val_accuracy: 0.8650 - val_loss: 0.4464
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8427 - loss: 0.4762 - val_accuracy: 0.8450 - val_loss: 0.4195
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8912 - loss: 0.3133 - val_accuracy: 0.8950 - val_loss: 0.2839
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8841 - loss: 0.3145 - val_accuracy: 0.8950 - val_loss: 0.2844
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8899 - loss: 0.3028 - val_accuracy: 0.9000 - val_loss: 0.2858
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8678 - loss: 0.3439 - val_accuracy: 0.9000 - val_loss: 0.2825
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8911 - loss: 0.3072 - val_accuracy: 0.8850 - val_loss: 0.2954
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9106 - loss: 0.2763 - val_accuracy: 0.8900 - val_loss: 0.2854
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9054 - loss: 0.2935 - val_accuracy: 0.9050 - val_loss: 0.2799
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8949 - loss: 0.2931 - val_accuracy: 0.9050 - val_loss: 0.2799
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8967 - loss: 0.2890 - val_accuracy: 0.8900 - val_loss: 0.2821
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9077 - loss: 0.2858 - val_accuracy: 0.9050 - val_loss: 0.2792
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9151 - loss: 0.2748 - val_accuracy: 0.8950 - val_loss: 0.2817
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9054 - loss: 0.2884 - val_accuracy: 0.9050 - val_loss: 0.2784
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9075 - loss: 0.2767 - val_accuracy: 0.8650 - val_loss: 0.2900
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9079 - loss: 0.2798 - val_accuracy: 0.8950 - val_loss: 0.2821
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9075 - loss: 0.2930 - val_accuracy: 0.8950 - val_loss: 0.2798
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 59.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9083 - loss: 0.2822
# Test Accuracy: 90.50%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# Confusion Matrix:
# [[88  8]
#  [11 93]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90        96
#            1       0.92      0.89      0.91       104
#
#     accuracy                           0.91       200
#    macro avg       0.90      0.91      0.90       200
# weighted avg       0.91      0.91      0.91       200
#
# AUC Score: 0.91
#
# Precision: 0.9207920792079208
# Recall: 0.8942307692307693
# F1 Score: 0.9073170731707317
# Cohen's Kappa Coefficient: 0.8099239695878351
# Matthews Correlation Coefficient (MCC): 0.8102889737153386
# Balanced Accuracy: 0.905448717948718
# Time taken: 2303.25 seconds

# %% [markdown]
# # vgg16+capsulenetwork+Dense

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load VGG16 model
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Define the custom architecture
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=20, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score, Cohen's Kappa
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()

# Define model details
model_details = {
    'Model': 'VGG16 + Capsule Network + Dense',
    'Epochs': 20,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'True Negatives': conf_matrix[0][0],
    'False Positives': conf_matrix[0][1],
    'False Negatives': conf_matrix[1][0],
    'True Positives': conf_matrix[1][1],
    'Error Rate': 1 - test_accuracy,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_acc,
    'Time Taken (seconds)': end_time - start_time
}

# Print model details
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Save model details to a CSV file
import pandas as pd
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16_Model8(20).csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("VGG16 Capsule Network Dense Training History")
plt.show()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer (CapsuleLayer)    │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.5008 - loss: 0.6965 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.5313 - loss: 0.6948 - val_accuracy: 0.5200 - val_loss: 0.6966
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.4869 - loss: 0.6960 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4794 - loss: 0.6940 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.5061 - loss: 0.6931 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4947 - loss: 0.6934 - val_accuracy: 0.4800 - val_loss: 0.6929
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.4932 - loss: 0.6931 - val_accuracy: 0.4400 - val_loss: 0.6817
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.5275 - loss: 0.6778 - val_accuracy: 0.6300 - val_loss: 0.6273
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.6520 - loss: 0.6306 - val_accuracy: 0.6750 - val_loss: 0.6042
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7229 - loss: 0.5847 - val_accuracy: 0.7300 - val_loss: 0.5710
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.6736 - loss: 0.6122 - val_accuracy: 0.7400 - val_loss: 0.5590
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.7169 - loss: 0.5638 - val_accuracy: 0.7300 - val_loss: 0.5317
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7380 - loss: 0.5335 - val_accuracy: 0.7350 - val_loss: 0.5160
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 124s 5s/step - accuracy: 0.7723 - loss: 0.5072 - val_accuracy: 0.7550 - val_loss: 0.4888
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.7611 - loss: 0.5188 - val_accuracy: 0.7500 - val_loss: 0.5397
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7759 - loss: 0.5014 - val_accuracy: 0.7950 - val_loss: 0.4525
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7995 - loss: 0.4459 - val_accuracy: 0.7800 - val_loss: 0.4899
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8005 - loss: 0.4612 - val_accuracy: 0.7300 - val_loss: 0.5637
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7454 - loss: 0.5240 - val_accuracy: 0.8150 - val_loss: 0.4119
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8180 - loss: 0.4268 - val_accuracy: 0.8350 - val_loss: 0.3600
# Restoring model weights from the end of the best epoch: 20.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7824 - loss: 0.4443
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f528811ae60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# Model Details:
# Model: VGG16 + Capsule Network + Dense
# Epochs: 20
# Test Accuracy: 0.8349999785423279
# Test Loss: 0.36003056168556213
# Validation Accuracy: 0.8349999785423279
# Validation Loss: 0.36003056168556213
# Precision: 0.8317757009345794
# Recall: 0.8557692307692307
# AUC-ROC: 0.8341346153846154
# True Negatives: 78
# False Positives: 18
# False Negatives: 15
# True Positives: 89
# Error Rate: 0.16500002145767212
# F1 Score: 0.8436018957345972
# Cohen's Kappa: 0.6690734055354994
# Matthews Correlation Coefficient: 0.6693763874193654
# Balanced Accuracy: 0.8341346153846154
# Time Taken (seconds): 2457.956164598465

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load VGG16 model
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Define the custom architecture
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=40, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score, Cohen's Kappa
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()

# Define model details
model_details = {
    'Model': 'VGG16 + Capsule Network + Dense',
    'Epochs': 40,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'True Negatives': conf_matrix[0][0],
    'False Positives': conf_matrix[0][1],
    'False Negatives': conf_matrix[1][0],
    'True Positives': conf_matrix[1][1],
    'Error Rate': 1 - test_accuracy,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_acc,
    'Time Taken (seconds)': end_time - start_time
}

# Print model details
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Save model details to a CSV file
import pandas as pd
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16_Model8(40).csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("VGG16 Capsule Network Dense Training History")
plt.show()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer_1 (CapsuleLayer)  │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 125s 5s/step - accuracy: 0.4793 - loss: 0.6976 - val_accuracy: 0.5200 - val_loss: 0.6935
# Epoch 2/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.4774 - loss: 0.6938 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 3/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.5134 - loss: 0.6931 - val_accuracy: 0.5200 - val_loss: 0.6933
# Epoch 4/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.4999 - loss: 0.6944 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 5/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.5239 - loss: 0.6933 - val_accuracy: 0.4800 - val_loss: 0.6929
# Epoch 6/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.5224 - loss: 0.6927 - val_accuracy: 0.6050 - val_loss: 0.6864
# Epoch 7/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4811 - loss: 0.6929 - val_accuracy: 0.5200 - val_loss: 0.6948
# Epoch 8/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.5122 - loss: 0.6928 - val_accuracy: 0.4800 - val_loss: 0.6906
# Epoch 9/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 124s 5s/step - accuracy: 0.5618 - loss: 0.6830 - val_accuracy: 0.7200 - val_loss: 0.6112
# Epoch 10/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.6932 - loss: 0.6052 - val_accuracy: 0.5950 - val_loss: 0.6636
# Epoch 11/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.6637 - loss: 0.6081 - val_accuracy: 0.6650 - val_loss: 0.6059
# Epoch 12/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.6979 - loss: 0.5877 - val_accuracy: 0.7200 - val_loss: 0.5683
# Epoch 13/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.6967 - loss: 0.5684 - val_accuracy: 0.7550 - val_loss: 0.5158
# Epoch 14/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7585 - loss: 0.5230 - val_accuracy: 0.7450 - val_loss: 0.5380
# Epoch 15/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.7706 - loss: 0.5161 - val_accuracy: 0.7500 - val_loss: 0.5047
# Epoch 16/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8111 - loss: 0.4432 - val_accuracy: 0.8000 - val_loss: 0.4449
# Epoch 17/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8422 - loss: 0.4178 - val_accuracy: 0.7600 - val_loss: 0.5171
# Epoch 18/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.8165 - loss: 0.4368 - val_accuracy: 0.8350 - val_loss: 0.3977
# Epoch 19/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8371 - loss: 0.3973 - val_accuracy: 0.8100 - val_loss: 0.4154
# Epoch 20/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.8658 - loss: 0.3771 - val_accuracy: 0.8050 - val_loss: 0.4322
# Epoch 21/40
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.8832 - loss: 0.3387 - val_accuracy: 0.8150 - val_loss: 0.4602
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 18.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8267 - loss: 0.4421
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f528811bbe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# Model Details:
# Model: VGG16 + Capsule Network + Dense
# Epochs: 40
# Test Accuracy: 0.8349999785423279
# Test Loss: 0.3977026641368866
# Validation Accuracy: 0.8149999976158142
# Validation Loss: 0.46021923422813416
# Precision: 0.8736842105263158
# Recall: 0.7980769230769231
# AUC-ROC: 0.8365384615384616
# True Negatives: 84
# False Positives: 12
# False Negatives: 21
# True Positives: 83
# Error Rate: 0.16500002145767212
# F1 Score: 0.8341708542713568
# Cohen's Kappa: 0.6706586826347305
# Matthews Correlation Coefficient: 0.6733804983414345
# Balanced Accuracy: 0.8365384615384616
# Time Taken (seconds): 2584.9433691501617

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load VGG16 model
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Define the custom architecture
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=60, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score, Cohen's Kappa
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()

# Define model details
model_details = {
    'Model': 'VGG16 + Capsule Network + Dense',
    'Epochs': 60,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'True Negatives': conf_matrix[0][0],
    'False Positives': conf_matrix[0][1],
    'False Negatives': conf_matrix[1][0],
    'True Positives': conf_matrix[1][1],
    'Error Rate': 1 - test_accuracy,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_acc,
    'Time Taken (seconds)': end_time - start_time
}

# Print model details
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Save model details to a CSV file
import pandas as pd
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16_Model8(60).csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("VGG16 Capsule Network Dense Training History")
plt.show()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_4 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer_2 (CapsuleLayer)  │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4945 - loss: 0.7046 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 2/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.5195 - loss: 0.6939 - val_accuracy: 0.4800 - val_loss: 0.6930
# Epoch 3/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4584 - loss: 0.6950 - val_accuracy: 0.4800 - val_loss: 0.6931
# Epoch 4/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.4973 - loss: 0.6934 - val_accuracy: 0.5200 - val_loss: 0.6933
# Epoch 5/60
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4849 - loss: 0.6935 - val_accuracy: 0.4800 - val_loss: 0.6935
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4602 - loss: 0.6942
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# Model Details:
# Model: VGG16 + Capsule Network + Dense
# Epochs: 60
# Test Accuracy: 0.47999998927116394
# Test Loss: 0.6929896473884583
# Validation Accuracy: 0.47999998927116394
# Validation Loss: 0.6934595704078674
# Precision: 0.0
# Recall: 0.0
# AUC-ROC: 0.5
# True Negatives: 96
# False Positives: 0
# False Negatives: 104
# True Positives: 0
# Error Rate: 0.5200000107288361
# F1 Score: 0.0
# Cohen's Kappa: 0.0
# Matthews Correlation Coefficient: 0.0
# Balanced Accuracy: 0.5
# Time Taken (seconds): 624.0051884651184
# /home/lab5/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load VGG16 model
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Define the custom architecture
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=80, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score, Cohen's Kappa
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()

# Define model details
model_details = {
    'Model': 'VGG16 + Capsule Network + Dense',
    'Epochs': 80,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'True Negatives': conf_matrix[0][0],
    'False Positives': conf_matrix[0][1],
    'False Negatives': conf_matrix[1][0],
    'True Positives': conf_matrix[1][1],
    'Error Rate': 1 - test_accuracy,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_acc,
    'Time Taken (seconds)': end_time - start_time
}

# Print model details
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Save model details to a CSV file
import pandas as pd
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16_Model8(80).csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("VGG16 Capsule Network Dense Training History")
plt.show()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_5 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer_3 (CapsuleLayer)  │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.4740 - loss: 0.7050 - val_accuracy: 0.4800 - val_loss: 0.6934
# Epoch 2/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.4620 - loss: 0.6978 - val_accuracy: 0.4800 - val_loss: 0.6937
# Epoch 3/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.5328 - loss: 0.6929 - val_accuracy: 0.5200 - val_loss: 0.6941
# Epoch 4/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 120s 5s/step - accuracy: 0.4896 - loss: 0.6953 - val_accuracy: 0.5200 - val_loss: 0.6935
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4602 - loss: 0.6975
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# Model Details:
# Model: VGG16 + Capsule Network + Dense
# Epochs: 80
# Test Accuracy: 0.47999998927116394
# Test Loss: 0.6934365034103394
# Validation Accuracy: 0.5199999809265137
# Validation Loss: 0.6934990286827087
# Precision: 0.0
# Recall: 0.0
# AUC-ROC: 0.5
# True Negatives: 96
# False Positives: 0
# False Negatives: 104
# True Positives: 0
# Error Rate: 0.5200000107288361
# F1 Score: 0.0
# Cohen's Kappa: 0.0
# Matthews Correlation Coefficient: 0.0
# Balanced Accuracy: 0.5
# Time Taken (seconds): 499.87066555023193
# /home/lab5/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, GlobalAveragePooling2D, Reshape, Dense, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load VGG16 model
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Define the custom architecture
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 100 epochs
history = model.fit(X_train_resized, y_train, epochs=100, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# Calculate Precision, Recall, F1 Score, Cohen's Kappa
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# End time
end_time = time.time()

# Define model details
model_details = {
    'Model': 'VGG16 + Capsule Network + Dense',
    'Epochs': 100,
    'Test Accuracy': test_accuracy,
    'Test Loss': test_loss,
    'Validation Accuracy': history.history['val_accuracy'][-1],
    'Validation Loss': history.history['val_loss'][-1],
    'Precision': precision,
    'Recall': recall,
    'AUC-ROC': roc_auc,
    'True Negatives': conf_matrix[0][0],
    'False Positives': conf_matrix[0][1],
    'False Negatives': conf_matrix[1][0],
    'True Positives': conf_matrix[1][1],
    'Error Rate': 1 - test_accuracy,
    'F1 Score': f1,
    "Cohen's Kappa": kappa,
    'Matthews Correlation Coefficient': mcc,
    'Balanced Accuracy': balanced_acc,
    'Time Taken (seconds)': end_time - start_time
}

# Print model details
print("Model Details:")
for key, value in model_details.items():
    print(f"{key}: {value}")

# Save model details to a CSV file
import pandas as pd
df = pd.DataFrame(model_details, index=[0])
df.to_csv("VGG16_Model8(100).csv", index=False)

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title("VGG16 Capsule Network Dense Training History")
plt.show()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_6 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer_4 (CapsuleLayer)  │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 125s 5s/step - accuracy: 0.5013 - loss: 0.6975 - val_accuracy: 0.5200 - val_loss: 0.6949
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.4954 - loss: 0.6937 - val_accuracy: 0.6200 - val_loss: 0.6770
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.5940 - loss: 0.6793 - val_accuracy: 0.6600 - val_loss: 0.6339
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.6322 - loss: 0.6477 - val_accuracy: 0.6650 - val_loss: 0.5978
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.6474 - loss: 0.6212 - val_accuracy: 0.7350 - val_loss: 0.5394
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7443 - loss: 0.5531 - val_accuracy: 0.7650 - val_loss: 0.5172
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7341 - loss: 0.5590 - val_accuracy: 0.7850 - val_loss: 0.4916
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7473 - loss: 0.5272 - val_accuracy: 0.7150 - val_loss: 0.5749
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7680 - loss: 0.5161 - val_accuracy: 0.7300 - val_loss: 0.5394
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.7712 - loss: 0.4985 - val_accuracy: 0.7750 - val_loss: 0.4569
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 5s/step - accuracy: 0.7852 - loss: 0.4688 - val_accuracy: 0.7900 - val_loss: 0.4600
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.7819 - loss: 0.4647 - val_accuracy: 0.8100 - val_loss: 0.4410
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.8225 - loss: 0.4166 - val_accuracy: 0.8000 - val_loss: 0.4300
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8319 - loss: 0.4104 - val_accuracy: 0.8200 - val_loss: 0.3879
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.8353 - loss: 0.3814 - val_accuracy: 0.8200 - val_loss: 0.3984
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 122s 5s/step - accuracy: 0.8400 - loss: 0.3831 - val_accuracy: 0.7600 - val_loss: 0.4626
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - accuracy: 0.8167 - loss: 0.3933 - val_accuracy: 0.7950 - val_loss: 0.4142
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8048 - loss: 0.4088
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# Model Details:
# Model: VGG16 + Capsule Network + Dense
# Epochs: 100
# Test Accuracy: 0.8199999928474426
# Test Loss: 0.38791388273239136
# Validation Accuracy: 0.7950000166893005
# Validation Loss: 0.4142220914363861
# Precision: 0.8469387755102041
# Recall: 0.7980769230769231
# AUC-ROC: 0.8209134615384616
# True Negatives: 81
# False Positives: 15
# False Negatives: 21
# True Positives: 83
# Error Rate: 0.18000000715255737
# F1 Score: 0.821782178217822
# Cohen's Kappa: 0.6402877697841727
# Matthews Correlation Coefficient: 0.641441557132198
# Balanced Accuracy: 0.8209134615384616
# Time Taken (seconds): 2096.527957677841
